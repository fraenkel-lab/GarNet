# %% [markdown]
# # Constructing a GarNet file
#
# The goal here is to construct a file in which all of the gene and transcription factor names exist in the same namespace. We use mygene.info's API to map all the gene names to a common namespace. It isn't clear that they have the most "canonical" namespace but at present they correlate best with genecards, and seems to be more consistent than all other namespaces I know of.

# %%
# %pylab inline
import sys
import os
import pickle
import sqlite3
import numpy as np
import pandas as pd

known_genes_file = '../example_data/mm10/mm10_knownGene.txt'
kgXref_file = '../example_data/mm10/mm10_kgXref.txt'
motifs_file = '../example_data/mm10/motifmap.txt'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.append(os.path.abspath('../src'))
from garnet import (parse_known_genes_file, parse_motifs_file, 
                    IntervalTree_from_reference, IntervalTree_from_motifs, group_by_chromosome, 
                    intersection_of_dict_of_intervaltree, save_as_pickled_object)

# %% [markdown]
# # Part I: Constructing a reference file
#
# We use UCSC's [known genes](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=refGene&hgta_regionType=genome&position=chr21%3A33031597-33041570&hgta_outputType=primaryTable&hgta_outFileName=) and [Cross Reference (kgXref) file](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=kgXref&hgta_regionType=genome&position=chr21%3A33%2C031%2C597-33%2C041%2C570&hgta_outputType=primaryTable&hgta_outFileName=) as our foundation.

# %%
reference = parse_known_genes_file(known_genes_file, kgXref_file)
reference
# Out:
#              ucID chrom geneStrand  geneStart   geneEnd  cdsStart    cdsEnd  \
# 0      uc007aet.1  chr1          -    3205903   3215632   3205903   3205903
# 1      uc007aeu.1  chr1          -    3214481   3671498   3216021   3671348
# 2      uc007aev.1  chr1          -    3648310   3658904   3648310   3648310
# 3      uc007aew.1  chr1          -    4290845   4409241   4292980   4409187
# 4      uc007aex.2  chr1          -    4343506   4360314   4344599   4352825
# 5      uc007aey.1  chr1          -    4490927   4493735   4491715   4493406
# 6      uc007aez.2  chr1          -    4490927   4497354   4491715   4493406
# 7      uc007afc.2  chr1          -    4490927   4497354   4491715   4493406
# 8      uc033fhy.1  chr1          -    4490927   4497354   4491715   4495155
# 9      uc007afa.2  chr1          -    4490927   4497354   4491715   4495155
# 10     uc007afb.2  chr1          -    4490927   4497354   4491715   4492591
# 11     uc007afd.3  chr1          -    4773199   4785726   4774451   4785677
# 12     uc007aff.3  chr1          -    4773199   4785726   4776463   4785677
# 13     uc007afe.3  chr1          -    4773199   4785726   4773199   4773199
# 14     uc007afg.1  chr1          +    4807892   4842827   4807928   4841159
# 15     uc007afh.1  chr1          +    4807892   4846735   4807913   4845016
# 16     uc007afi.2  chr1          +    4857693   4897909   4857913   4896364
# 17     uc011wht.1  chr1          +    4857693   4897909   4857913   4896364
# 18     uc011whu.1  chr1          +    4858327   4897909   4858407   4896364
# 19     uc057aty.1  chr1          +    4884321   4887040   4884321   4884321
# 20     uc056ycb.1  chr1          -    4909575   5018734   4910473   4923965
# 21     uc007afk.3  chr1          -    4909575   5019539   4910473   5019379
# 22     uc007afl.2  chr1          -    4909575   5070285   4910473   5070177
# 23     uc007afm.2  chr1          +    5083085   5099777   5084459   5098208
# 24     uc007afn.2  chr1          +    5083085   5162549   5084450   5162165
# 25     uc057atz.1  chr1          +    5083085   5162549   5084450   5162165
# 26     uc007afo.2  chr1          +    5588492   5606133   5589048   5602784
# 27     uc057aua.1  chr1          +    5588492   5606133   5589048   5602871
# 28     uc007afq.2  chr1          +    5596517   5606133   5598599   5602784
# 29     uc011whw.1  chr1          -    5913706   5917398   5916303   5917293
# ...           ...   ...        ...        ...       ...       ...       ...
# 63729  uc029ygk.1  chrY          +   82225214  82251414  82226657  82251223
# 63730  uc029ygl.1  chrY          +   83789753  83927911  83789753  83789753
# 63731  uc012hsq.2  chrY          -   83789753  85529519  85528659  85529343
# 63732  uc029ygm.1  chrY          +   84097278  84123489  84098710  84123298
# 63733  uc029ygn.1  chrY          +   87116820  87142912  87118254  87142720
# 63734  uc009vic.1  chrY          +   87550953  87575686  87552401  87575495
# 63735  uc029ygo.1  chrY          -   87780740  87780787  87780740  87780740
# 63736  uc029ygp.1  chrY          +   88053302  88079489  88054746  88079297
# 63737  uc029ygq.1  chrY          +   89075317  89079014  89075317  89075317
# 63738  uc029ygr.1  chrY          -   89700320  89745342  89700331  89731955
# 63739  uc029ygs.1  chrY          -   89700320  89745342  89700320  89700320
# 63740  uc029ygt.1  chrY          -   89713460  89745550  89713460  89713460
# 63741  uc029ygu.1  chrY          -   90499054  90531635  90499653  90530197
# 63742  uc029ygv.1  chrY          -   90603500  90605864  90603500  90603500
# 63743  uc029ygw.1  chrY          +   90748968  90758560  90748968  90748968
# 63744  uc029ygx.1  chrY          +   90748968  90758560  90748968  90748968
# 63745  uc029ygy.1  chrY          +   90751355  90758560  90751355  90751355
# 63746  uc029ygz.1  chrY          +   90751355  90758560  90751355  90751355
# 63747  uc029yha.1  chrY          +   90751355  90758560  90751355  90751355
# 63748  uc029yhb.1  chrY          +   90753040  90758560  90753040  90753040
# 63749  uc029yhc.1  chrY          +   90784609  90816465  90785670  90816463
# 63750  uc029yhd.1  chrY          +   90785441  90816465  90785670  90816439
# 63751  uc029yhe.1  chrY          +   90785441  90816465  90785557  90816463
# 63752  uc029yhf.1  chrY          +   90785589  90816465  90785589  90785589
# 63753  uc029yhg.1  chrY          +   90833346  90842916  90833346  90833346
# 63754  uc029yhh.1  chrY          +   90833346  90842916  90833346  90833346
# 63755  uc029yhi.1  chrY          +   90835733  90842916  90835733  90835733
# 63756  uc029yhj.1  chrY          +   90835733  90842916  90835733  90835733
# 63757  uc029yhk.1  chrY          +   90835733  90842916  90835733  90835733
# 63758  uc029yhl.1  chrY          +   90837396  90842916  90837396  90837396
#
#        exonCount                                         exonStarts  \
# 0              2                                   3205903,3213438,
# 1              3                           3214481,3421701,3670551,
# 2              2                                   3648310,3658846,
# 3              4                   4290845,4351909,4352201,4409169,
# 4              4                   4343506,4351909,4352201,4360199,
# 5              2                                   4490927,4493099,
# 6              5           4490927,4493099,4493771,4495135,4496290,
# 7              4                   4490927,4493099,4493771,4496290,
# 8              4                   4490927,4493771,4495135,4496290,
# 9              4                   4490927,4493771,4495135,4496290,
# 10             3                           4490927,4493771,4496290,
# 11             5           4773199,4777524,4782567,4783950,4785572,
# 12             5           4773199,4777524,4782567,4783950,4785572,
# 13             4                   4773199,4777524,4782567,4785572,
# 14             8  4807892,4808454,4828583,4830267,4832310,483700...
# 15             9  4807892,4808454,4828583,4830267,4832310,483700...
# 16            10  4857693,4867469,4878026,4886743,4889456,489073...
# 17            10  4857693,4867469,4878026,4886743,4889459,489073...
# 18            10  4858327,4867469,4878026,4886743,4889456,489073...
# 19             1                                           4884321,
# 20             5           4909575,4912313,4916896,4923846,5018575,
# 21             5           4909575,4912313,4916896,4923846,5019310,
# 22             6   4909575,4912313,4916896,4923846,5020737,5070009,
# 23             6   5083085,5084416,5089008,5093362,5095614,5098028,
# 24            14  5083085,5084416,5089008,5093362,5095614,509802...
# 25            13  5083085,5084416,5089008,5093362,5095614,509802...
# 26             4                   5588492,5589034,5598589,5602251,
# 27             5           5588492,5589004,5598589,5602251,5602784,
# 28             2                                   5596517,5602251,
# 29             1                                           5913706,
# ...          ...                                                ...
# 63729         10  82225214,82226634,82232097,82232841,82239895,8...
# 63730          3                        83789753,83852591,83927453,
# 63731          4               83789753,83852591,83927453,85528524,
# 63732         10  84097278,84098687,84104155,84104865,84111922,8...
# 63733         10  87116820,87118231,87123688,87124321,87131378,8...
# 63734          8  87550953,87552375,87557838,87558556,87573498,8...
# 63735          1                                          87780740,
# 63736          8  88053302,88054720,88060190,88060879,88075785,8...
# 63737          4               89075317,89076195,89078335,89078793,
# 63738          8  89700320,89714015,89716123,89716975,89724233,8...
# 63739          8  89700320,89714044,89716123,89716975,89724233,8...
# 63740          8  89713460,89714044,89716123,89716975,89722165,8...
# 63741          8  90499054,90499640,90501763,90502619,90524102,9...
# 63742          4               90603500,90604097,90605009,90605678,
# 63743          4               90748968,90753056,90757300,90758541,
# 63744          3                        90748968,90753056,90758541,
# 63745          5      90751355,90752023,90753056,90757300,90758541,
# 63746          4               90751355,90753056,90757300,90758541,
# 63747          3                        90751355,90753056,90758541,
# 63748          3                        90753040,90757300,90758541,
# 63749          4               90784609,90785589,90793295,90816348,
# 63750          4               90785441,90785859,90793295,90816348,
# 63751          3                        90785441,90793324,90816348,
# 63752          3                        90785589,90793295,90816348,
# 63753          4               90833346,90837412,90841656,90842897,
# 63754          3                        90833346,90837412,90842897,
# 63755          5      90835733,90836401,90837412,90841656,90842897,
# 63756          4               90835733,90837412,90841656,90842897,
# 63757          3                        90835733,90837412,90842897,
# 63758          3                        90837396,90841656,90842897,
#
#                                                 exonEnds ...         kgID  \
# 0                                       3207317,3215632, ...   uc007aet.1
# 1                               3216968,3421901,3671498, ...   uc007aeu.1
# 2                                       3650509,3658904, ...   uc007aev.1
# 3                       4293012,4352081,4352837,4409241, ...   uc007aew.1
# 4                       4350091,4352081,4352837,4360314, ...   uc007aex.2
# 5                                       4492668,4493735, ...   uc007aey.1
# 6               4492668,4493466,4493863,4495942,4497354, ...   uc007aez.2
# 7                       4492668,4493490,4493863,4497354, ...   uc007afc.2
# 8                       4492668,4493863,4495198,4497354, ...   uc033fhy.1
# 9                       4492668,4493863,4495942,4497354, ...   uc007afa.2
# 10                              4492668,4493863,4497354, ...   uc007afb.2
# 11              4774516,4777648,4782733,4784105,4785726, ...   uc007afd.3
# 12              4776801,4777648,4782733,4784105,4785726, ...   uc007aff.3
# 13                      4774516,4777648,4782733,4785726, ...   uc007afe.3
# 14     4807982,4808486,4828649,4830315,4832381,483707... ...   uc007afg.1
# 15     4807982,4808486,4828649,4830315,4832381,483707... ...   uc007afh.1
# 16     4857976,4867532,4878132,4886831,4889602,489079... ...   uc007afi.2
# 17     4857976,4867532,4878132,4886831,4889602,489079... ...   uc011wht.1
# 18     4858503,4867532,4878132,4886831,4889602,489079... ...   uc011whu.1
# 19                                              4887040, ...   uc057aty.1
# 20              4910662,4912548,4916980,4923989,5018734, ...   uc056ycb.1
# 21              4910662,4912548,4916980,4923989,5019539, ...   uc007afk.3
# 22      4910662,4912548,4916980,4923989,5021037,5070285, ...   uc007afl.2
# 23      5083278,5084563,5089111,5093452,5095728,5099777, ...   uc007afm.2
# 24     5083278,5084563,5089111,5093452,5095728,509813... ...   uc007afn.2
# 25     5083278,5084563,5089111,5093452,5095728,509813... ...   uc057atz.1
# 26                      5588663,5589305,5598942,5606133, ...   uc007afo.2
# 27              5588663,5589305,5598942,5602781,5606133, ...   uc057aua.1
# 28                                      5598942,5606133, ...   uc007afq.2
# 29                                              5917398, ...   uc011whw.1
# ...                                                  ... ...          ...
# 63729  82225270,82226766,82232164,82232876,82239962,8... ...   uc029ygk.1
# 63730                        83790098,83852777,83927911, ...   uc029ygl.1
# 63731               83790098,83852777,83927911,85529519, ...   uc012hsq.2
# 63732  84097322,84098819,84104222,84104900,84111989,8... ...   uc029ygm.1
# 63733  87116864,87118363,87123755,87124356,87131445,8... ...   uc029ygn.1
# 63734  87551009,87552510,87557905,87558591,87573616,8... ...   uc009vic.1
# 63735                                          87780787, ...   uc029ygo.1
# 63736  88053358,88054855,88060257,88060914,88075903,8... ...   uc029ygp.1
# 63737               89075437,89076295,89078434,89079014, ...   uc029ygq.1
# 63738  89700376,89714114,89716223,89717093,89724268,8... ...   uc029ygr.1
# 63739  89700376,89714114,89716223,89717093,89724268,8... ...   uc029ygs.1
# 63740  89713657,89714114,89716223,89717093,89722296,8... ...   uc029ygt.1
# 63741  90499281,90499737,90501863,90502737,90524137,9... ...   uc029ygu.1
# 63742               90603569,90604282,90605191,90605864, ...   uc029ygv.1
# 63743               90749000,90753164,90757449,90758560, ...   uc029ygw.1
# 63744                        90749000,90753164,90758560, ...   uc029ygx.1
# 63745      90751403,90752090,90753164,90757449,90758560, ...   uc029ygy.1
# 63746               90751403,90753164,90757449,90758560, ...   uc029ygz.1
# 63747                        90751403,90753164,90758560, ...   uc029yha.1
# 63748                        90753164,90757449,90758560, ...   uc029yhb.1
# 63749               90784678,90785979,90793417,90816465, ...   uc029yhc.1
# 63750               90785859,90785979,90793417,90816465, ...   uc029yhd.1
# 63751                        90785979,90793417,90816465, ...   uc029yhe.1
# 63752                        90785979,90793680,90816465, ...   uc029yhf.1
# 63753               90833378,90837520,90841805,90842916, ...   uc029yhg.1
# 63754                        90833378,90837520,90842916, ...   uc029yhh.1
# 63755      90835781,90836468,90837520,90841805,90842916, ...   uc029yhi.1
# 63756               90835781,90837520,90841805,90842916, ...   uc029yhj.1
# 63757                        90835781,90837520,90842916, ...   uc029yhk.1
# 63758                        90837520,90841805,90842916, ...   uc029yhl.1
#
#                mRNA        spID       spDisplayID   geneName        refseq  \
# 0          AK135172         NaN               NaN   AK135172           NaN
# 1      NM_001011874      Q5GH67        XKR4_MOUSE       Xkr4  NM_001011874
# 2          AK149000         NaN               NaN   AK149000           NaN
# 3      NM_001195662  A0A0A6YXU6  A0A0A6YXU6_MOUSE        Rp1  NM_001195662
# 4         NM_011283      P56716         RP1_MOUSE        Rp1     NM_011283
# 5          BC027687      Q61473       SOX17_MOUSE      Sox17  NM_001289467
# 6         NM_011441      Q61473       SOX17_MOUSE      Sox17     NM_011441
# 7      NM_001289464      Q61473       SOX17_MOUSE      Sox17  NM_001289464
# 8      NM_001289466  A0A0A6YXS3  A0A0A6YXS3_MOUSE      Sox17  NM_001289466
# 9      NM_001289465  A0A0A6YXS3  A0A0A6YXS3_MOUSE      Sox17  NM_001289465
# 10     NM_001289467      Q61473       SOX17_MOUSE      Sox17  NM_001289467
# 11        NM_025300    Q9CPR5-2          Q9CPR5-2     Mrpl15     NM_025300
# 12     NM_001177658      Q9CPR5        RM15_MOUSE     Mrpl15  NM_001177658
# 13        NR_033530         NaN               NaN     Mrpl15     NR_033530
# 14         AK050549    P97823-2          P97823-2     Lypla1     NM_008866
# 15        NM_008866      P97823       LYPA1_MOUSE     Lypla1     NM_008866
# 16        NM_011541      P10711       TCEA1_MOUSE      Tcea1     NM_011541
# 17     NM_001159750      P10711       TCEA1_MOUSE      Tcea1  NM_001159750
# 18     NM_001159751      E9PYD5      E9PYD5_MOUSE      Tcea1  NM_001159751
# 19         AK048564         NaN               NaN   AK048564           NaN
# 20     NM_001290372      Q9QZB1       RGS20_MOUSE      Rgs20  NM_001290372
# 21        NM_021374      Q9QZB1       RGS20_MOUSE      Rgs20     NM_021374
# 22     NM_001177795      E9Q720      E9Q720_MOUSE      Rgs20  NM_001177795
# 23         AK081492  A0A0A6YVU0  A0A0A6YVU0_MOUSE    Atp6v1h  NM_001310442
# 24        NM_133826      Q8BVE3        VATH_MOUSE    Atp6v1h     NM_133826
# 25     NM_001310442  A0A0A6YX18  A0A0A6YX18_MOUSE    Atp6v1h  NM_001310442
# 26        NM_011011      P33534        OPRK_MOUSE      Oprk1     NM_011011
# 27     NM_001318735      P33534        OPRK_MOUSE      Oprk1  NM_001318735
# 28         AK138198      P33534        OPRK_MOUSE      Oprk1     NM_011011
# 29        NM_010342      P49681       NPBW1_MOUSE     Npbwr1     NM_010342
# ...             ...         ...               ...        ...           ...
# 63729      BC049626      Q810R0      Q810R0_MOUSE    Gm20736     NM_201530
# 63730        L04847         NaN               NaN     L04847           NaN
# 63731  NM_001160131      Q62461      Q62461_MOUSE    Gm20854  NM_001160131
# 63732      BC049626  A0A087WR14  A0A087WR14_MOUSE        Sly     NM_201530
# 63733      BC049626      Q810R0      Q810R0_MOUSE        Sly     NM_201530
# 63734      BC100464  A0A087WSR0  A0A087WSR0_MOUSE    Gm20736  NM_001037748
# 63735      AK187783         NaN               NaN   AK187783           NaN
# 63736      BC100464  A0A087WSR0  A0A087WSR0_MOUSE    Gm20736  NM_001037748
# 63737      BC100464         NaN               NaN  LOC380994           NaN
# 63738      FJ541095  A0A087WSS9  A0A087WSS9_MOUSE   Gm21996            NaN
# 63739      FJ541083         NaN               NaN   FJ541083           NaN
# 63740      AK076905         NaN               NaN   AK076905           NaN
# 63741      BC099537  A0A087WSR0  A0A087WSR0_MOUSE       Sly            NaN
# 63742      DQ874391         NaN               NaN   DQ874391           NaN
# 63743      AY540025         NaN               NaN       Mid1           NaN
# 63744      AY540026         NaN               NaN       Mid1           NaN
# 63745      AY540033         NaN               NaN       Mid1           NaN
# 63746      AY540031         NaN               NaN       Mid1           NaN
# 63747      AY540037         NaN               NaN       Mid1           NaN
# 63748      AY540036         NaN               NaN       Mid1           NaN
# 63749      AJ007909      J3QMM0      J3QMM0_MOUSE      Erdr1     NM_133362
# 63750     NM_133362      Q8VEL1      Q8VEL1_MOUSE      Erdr1     NM_133362
# 63751      AK051407         NaN               NaN      Erdr1           NaN
# 63752      BC058113         NaN               NaN      Erdr1           NaN
# 63753      AY540025         NaN               NaN       Mid1           NaN
# 63754      AY540026         NaN               NaN       Mid1           NaN
# 63755      AY540033         NaN               NaN       Mid1           NaN
# 63756      AY540031         NaN               NaN       Mid1           NaN
# 63757      AY540037         NaN               NaN       Mid1           NaN
# 63758      AY540036         NaN               NaN       Mid1           NaN
#
#             protAcc                                        description  na  \
# 0               NaN  Mus musculus 12 days embryo female ovary cDNA,... NaN
# 1      NP_001011874  Mus musculus X-linked Kx blood group related 4... NaN
# 2               NaN  Mus musculus 2 days neonate sympathetic gangli... NaN
# 3      NP_001182591  Mus musculus retinitis pigmentosa 1 (human) (R... NaN
# 4         NP_035413  Mus musculus retinitis pigmentosa 1 (human) (R... NaN
# 5      NP_001276396  Mus musculus SRY (sex determining region Y)-bo... NaN
# 6      NP_001276396  Mus musculus SRY (sex determining region Y)-bo... NaN
# 7      NP_001276393  Mus musculus SRY (sex determining region Y)-bo... NaN
# 8      NP_001276395  Mus musculus SRY (sex determining region Y)-bo... NaN
# 9      NP_001276394  Mus musculus SRY (sex determining region Y)-bo... NaN
# 10     NP_001276396  Mus musculus SRY (sex determining region Y)-bo... NaN
# 11        NP_079576  Mus musculus mitochondrial ribosomal protein L... NaN
# 12     NP_001171129  Mus musculus mitochondrial ribosomal protein L... NaN
# 13              NaN  Mus musculus mitochondrial ribosomal protein L... NaN
# 14        NP_032892   Mus musculus lysophospholipase 1 (Lypla1), mRNA. NaN
# 15        NP_032892   Mus musculus lysophospholipase 1 (Lypla1), mRNA. NaN
# 16        NP_035671  Mus musculus transcription elongation factor A... NaN
# 17     NP_001153222  Mus musculus transcription elongation factor A... NaN
# 18     NP_001153223  Mus musculus transcription elongation factor A... NaN
# 19              NaN  Mus musculus 16 days embryo head cDNA, RIKEN f... NaN
# 20     NP_001277301  Mus musculus regulator of G-protein signaling ... NaN
# 21     NP_001277301  Mus musculus regulator of G-protein signaling ... NaN
# 22     NP_001277301  Mus musculus regulator of G-protein signaling ... NaN
# 23     NP_001297371  Mus musculus ATPase, H+ transporting, lysosoma... NaN
# 24        NP_598587  Mus musculus ATPase, H+ transporting, lysosoma... NaN
# 25     NP_001297371  Mus musculus ATPase, H+ transporting, lysosoma... NaN
# 26        NP_035141  Mus musculus opioid receptor, kappa 1 (Oprk1),... NaN
# 27     NP_001305664  Mus musculus opioid receptor, kappa 1 (Oprk1),... NaN
# 28        NP_035141  Mus musculus opioid receptor, kappa 1 (Oprk1),... NaN
# 29        NP_034472  Mus musculus neuropeptides B/W receptor 1 (Npb... NaN
# ...             ...                                                ...  ..
# 63729     NP_963288  Mus musculus predicted gene, 20736 (Gm20736), ... NaN
# 63730           NaN  Mouse (clone BALB10N) mRNA, complete cds of un... NaN
# 63731  NP_001153603  Mus musculus predicted gene, 20854 (Gm20854), ... NaN
# 63732     NP_963288      Mus musculus Sycp3 like Y-linked (Sly), mRNA. NaN
# 63733     NP_963288      Mus musculus Sycp3 like Y-linked (Sly), mRNA. NaN
# 63734  NP_001032837  Mus musculus predicted gene, 20736 (Gm20736), ... NaN
# 63735           NaN  Mus musculus cDNA, clone:Y0G0143A17, strand:un... NaN
# 63736  NP_001032837  Mus musculus predicted gene, 20736 (Gm20736), ... NaN
# 63737           NaN  Mus musculus similar to Sycp3 like Y-linked, m... NaN
# 63738           NaN                    SubName: Full=Protein Gm21996 ; NaN
# 63739           NaN  Mus musculus piRNA piRY splice variant 9, prec... NaN
# 63740           NaN  Mus musculus adult male testis cDNA, RIKEN ful... NaN
# 63741           NaN  SubName: Full=SAM and SH3 domain-containing pr... NaN
# 63742           NaN  Mus musculus amplified spermatogenic transcrip... NaN
# 63743           NaN  Mus musculus clone MEX2A-1 Mid1 mRNA, partial ... NaN
# 63744           NaN  Mus musculus clone MEX2A-2 Mid1 mRNA, partial ... NaN
# 63745           NaN  Mus musculus clone MEX2B-4 Mid1 mRNA, partial ... NaN
# 63746           NaN  Mus musculus clone MEX2B-2 Mid1 mRNA, partial ... NaN
# 63747           NaN  Mus musculus clone MEX2B-8 Mid1 mRNA, partial ... NaN
# 63748           NaN  Mus musculus clone MEX2B-7 Mid1 mRNA, partial ... NaN
# 63749     NP_579940  Mus musculus erythroid differentiation regulat... NaN
# 63750     NP_579940  Mus musculus erythroid differentiation regulat... NaN
# 63751           NaN  Mus musculus erythroid differentiation regulat... NaN
# 63752           NaN  Mus musculus erythroid differentiation regulat... NaN
# 63753           NaN  Mus musculus clone MEX2A-1 Mid1 mRNA, partial ... NaN
# 63754           NaN  Mus musculus clone MEX2A-2 Mid1 mRNA, partial ... NaN
# 63755           NaN  Mus musculus clone MEX2B-4 Mid1 mRNA, partial ... NaN
# 63756           NaN  Mus musculus clone MEX2B-2 Mid1 mRNA, partial ... NaN
# 63757           NaN  Mus musculus clone MEX2B-8 Mid1 mRNA, partial ... NaN
# 63758           NaN  Mus musculus clone MEX2B-7 Mid1 mRNA, partial ... NaN
#
#        na2
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN
# 10     NaN
# 11     NaN
# 12     NaN
# 13     NaN
# 14     NaN
# 15     NaN
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# 20     NaN
# 21     NaN
# 22     NaN
# 23     NaN
# 24     NaN
# 25     NaN
# 26     NaN
# 27     NaN
# 28     NaN
# 29     NaN
# ...    ...
# 63729  NaN
# 63730  NaN
# 63731  NaN
# 63732  NaN
# 63733  NaN
# 63734  NaN
# 63735  NaN
# 63736  NaN
# 63737  NaN
# 63738  NaN
# 63739  NaN
# 63740  NaN
# 63741  NaN
# 63742  NaN
# 63743  NaN
# 63744  NaN
# 63745  NaN
# 63746  NaN
# 63747  NaN
# 63748  NaN
# 63749  NaN
# 63750  NaN
# 63751  NaN
# 63752  NaN
# 63753  NaN
# 63754  NaN
# 63755  NaN
# 63756  NaN
# 63757  NaN
# 63758  NaN
#
# [63759 rows x 22 columns]

# %%
reference = reference[['geneName', 'ucID', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#    geneName        ucID chrom geneStrand  geneStart  geneEnd
# 0  AK135172  uc007aet.1  chr1          -    3205903  3215632
# 1      Xkr4  uc007aeu.1  chr1          -    3214481  3671498
# 2  AK149000  uc007aev.1  chr1          -    3648310  3658904
# 3       Rp1  uc007aew.1  chr1          -    4290845  4409241
# 4       Rp1  uc007aex.2  chr1          -    4343506  4360314

# %%
reference[reference.geneName.isnull()]
# Out:
# Empty DataFrame
# Columns: [geneName, ucID, chrom, geneStrand, geneStart, geneEnd]
# Index: []

# %% [markdown]
# ### ...Amazing!

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(np.unique(reference.geneName.values).tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="mm10", as_dataframe=True, returnall=True)
df
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df
# Out:
#                 HGNC    symbol
# 4930578C19Rik  25866   CXorf36
# 6D             13348      LY6D
# A1bg               5      A1BG
# A1cf           24086      A1CF
# A2m                7       A2M
# A3galt2        30005   A3GALT2
# A4galt         18149    A4GALT
# A4gnt          17968     A4GNT
# Aaas           13666      AAAS
# Aacs           21298      AACS
# Aadac             17     AADAC
# Aadacl2        24427   AADACL2
# Aadacl3        32037   AADACL3
# Aadat          17929     AADAT
# Aaed1          16881     AAED1
# Aagab          25662     AAGAB
# Aak1           19679      AAK1
# Aamdc          30205     AAMDC
# Aamp              18      AAMP
# Aanat             19     AANAT
# Aar2           15886      AAR2
# Aard           33842      AARD
# Aars              20      AARS
# Aars2          21022     AARS2
# Aarsd1         28417    AARSD1
# Aasdh          23993     AASDH
# Aasdhppt       14235  AASDHPPT
# Aass           17366      AASS
# Aatf           19235      AATF
# Aatk              21      AATK
# ...              ...       ...
# Zscan2         20994    ZSCAN2
# Zscan20        13093   ZSCAN20
# Zscan21        13104   ZSCAN21
# Zscan22         4929   ZSCAN22
# Zscan25        21961   ZSCAN25
# Zscan26        12978   ZSCAN26
# Zscan29        26673   ZSCAN29
# Zscan5b        34246   ZSCAN5B
# Zswim1         16155    ZSWIM1
# Zswim2         30990    ZSWIM2
# Zswim3         16157    ZSWIM3
# Zswim4         25704    ZSWIM4
# Zswim5         29299    ZSWIM5
# Zswim6         29316    ZSWIM6
# Zswim7         26993    ZSWIM7
# Zswim8         23528    ZSWIM8
# Zufsp          21224     ZUFSP
# Zw10           13194      ZW10
# Zwilch         25468    ZWILCH
# Zwint          13195     ZWINT
# Zxda           13198      ZXDA
# Zxdb           13199      ZXDB
# Zxdc           28160      ZXDC
# Zyg11a         32058    ZYG11A
# Zyg11b         25820    ZYG11B
# Zyx            13200       ZYX
# Zzef1          29027     ZZEF1
# Zzz3           24523      ZZZ3
# l7Rn6          26938   HIKESHI
# mannose         7216       MPI
#
# [16506 rows x 2 columns]

# %%
len(df[df.index != df.symbol])
# Out:
# 16490

# %%
missing
# Out:
# ['5330429B09Rik',
#  '5830427D03Rik',
#  'A630005I04Rik',
#  'AB001425',
#  'AB033516',
#  'AB033524',
#  'AB250976',
#  'AB251034',
#  'AB251038',
#  'AB251048',
#  'AB251080',
#  'AB251090',
#  'AB251129',
#  'AB251138',
#  'AB251161',
#  'AB251164',
#  'AB251181',
#  'AB251193',
#  'AB251227',
#  'AB251234',
#  'AB251235',
#  'AB251236',
#  'AB251241',
#  'AB251246',
#  'AB251255',
#  'AB251281',
#  'AB251326',
#  'AB251337',
#  'AB334825',
#  'AB334932',
#  'AB334935',
#  'AB334937',
#  'AB334950',
#  'AB335323',
#  'AB335328',
#  'AB335442',
#  'AB335447',
#  'AB335470',
#  'AB335611',
#  'AB335614',
#  'AB335643',
#  'AB335648',
#  'AB335691',
#  'AB335697',
#  'AB335713',
#  'AB335717',
#  'AB335737',
#  'AB335738',
#  'AB335742',
#  'AB335744',
#  'AB335790',
#  'AB335791',
#  'AB335823',
#  'AB335841',
#  'AB335855',
#  'AB335922',
#  'AB335951',
#  'AB336345',
#  'AB336370',
#  'AB336401',
#  'AB336449',
#  'AB336457',
#  'AB336502',
#  'AB336507',
#  'AB336517',
#  'AB336556',
#  'AB336562',
#  'AB336574',
#  'AB336585',
#  'AB336627',
#  'AB336633',
#  'AB336671',
#  'AB336678',
#  'AB336690',
#  'AB336698',
#  'AB336730',
#  'AB336736',
#  'AB336747',
#  'AB336760',
#  'AB336765',
#  'AB336790',
#  'AB336793',
#  'AB336799',
#  'AB336801',
#  'AB336802',
#  'AB336827',
#  'AB336885',
#  'AB336927',
#  'AB336957',
#  'AB337250',
#  'AB337257',
#  'AB337363',
#  'AB337379',
#  'AB337561',
#  'AB337572',
#  'AB337652',
#  'AB337655',
#  'AB337668',
#  'AB337679',
#  'AB337725',
#  'AB337734',
#  'AB337741',
#  'AB337757',
#  'AB337772',
#  'AB337790',
#  'AB337820',
#  'AB337824',
#  'AB337831',
#  'AB337837',
#  'AB339095',
#  'AB339101',
#  'AB339134',
#  'AB339136',
#  'AB339176',
#  'AB339339',
#  'AB339353',
#  'AB339385',
#  'AB339665',
#  'AB339701',
#  'AB339715',
#  'AB339720',
#  'AB339756',
#  'AB339759',
#  'AB339817',
#  'AB339827',
#  'AB339828',
#  'AB339834',
#  'AB339841',
#  'AB339848',
#  'AB339851',
#  'AB339856',
#  'AB339872',
#  'AB339875',
#  'AB339877',
#  'AB339880',
#  'AB339900',
#  'AB339914',
#  'AB339916',
#  'AB339917',
#  'AB339919',
#  'AB339928',
#  'AB339930',
#  'AB339933',
#  'AB340008',
#  'AB340013',
#  'AB340030',
#  'AB340033',
#  'AB340034',
#  'AB340043',
#  'AB340047',
#  'AB340055',
#  'AB340064',
#  'AB340066',
#  'AB340070',
#  'AB340533',
#  'AB340581',
#  'AB340911',
#  'AB340926',
#  'AB340928',
#  'AB340945',
#  'AB340955',
#  'AB340964',
#  'AB340975',
#  'AB340983',
#  'AB340984',
#  'AB340994',
#  'AB340997',
#  'AB341018',
#  'AB341019',
#  'AB341034',
#  'AB341036',
#  'AB341048',
#  'AB341055',
#  'AB341074',
#  'AB341082',
#  'AB341100',
#  'AB341103',
#  'AB341107',
#  'AB341108',
#  'AB341123',
#  'AB341124',
#  'AB341130',
#  'AB341131',
#  'AB341140',
#  'AB341148',
#  'AB341163',
#  'AB341182',
#  'AB341191',
#  'AB341208',
#  'AB341359',
#  'AB341366',
#  'AB341370',
#  'AB341582',
#  'AB341588',
#  'AB341618',
#  'AB341653',
#  'AB341725',
#  'AB341833',
#  'AB341951',
#  'AB341958',
#  'AB341966',
#  'AB341973',
#  'AB341981',
#  'AB341985',
#  'AB342005',
#  'AB342020',
#  'AB342034',
#  'AB342673',
#  'AB342697',
#  'AB342751',
#  'AB342777',
#  'AB342860',
#  'AB342943',
#  'AB342967',
#  'AB342977',
#  'AB342981',
#  'AB343133',
#  'AB343241',
#  'AB343243',
#  'AB343258',
#  'AB343393',
#  'AB343394',
#  'AB343404',
#  'AB343460',
#  'AB343474',
#  'AB343487',
#  'AB343505',
#  'AB343773',
#  'AB344116',
#  'AB344119',
#  'AB344120',
#  'AB344165',
#  'AB344273',
#  'AB344333',
#  'AB344345',
#  'AB344349',
#  'AB344442',
#  'AB344445',
#  'AB344481',
#  'AB344486',
#  'AB344586',
#  'AB344602',
#  'AB344666',
#  'AB344706',
#  'AB344718',
#  'AB344719',
#  'AB344727',
#  'AB344750',
#  'AB344949',
#  'AB345004',
#  'AB345223',
#  'AB345229',
#  'AB345231',
#  'AB345245',
#  'AB345250',
#  'AB345258',
#  'AB345261',
#  'AB345268',
#  'AB345460',
#  'AB345468',
#  'AB345581',
#  'AB345950',
#  'AB346024',
#  'AB346163',
#  'AB346228',
#  'AB346293',
#  'AB346318',
#  'AB346350',
#  'AB346559',
#  'AB346669',
#  'AB346730',
#  'AB346733',
#  'AB346734',
#  'AB346741',
#  'AB346742',
#  'AB346745',
#  'AB346746',
#  'AB346747',
#  'AB346759',
#  'AB346761',
#  'AB346771',
#  'AB346773',
#  'AB346777',
#  'AB346779',
#  'AB346782',
#  'AB346786',
#  'AB346797',
#  'AB346803',
#  'AB346804',
#  'AB346810',
#  'AB346812',
#  'AB346813',
#  'AB347122',
#  'AB347151',
#  'AB347200',
#  'AB347309',
#  'AB347442',
#  'AB347501',
#  'AB347559',
#  'AB347565',
#  'AB347592',
#  'AB347683',
#  'AB347728',
#  'AB347733',
#  'AB347750',
#  'AB347857',
#  'AB347864',
#  'AB347871',
#  'AB347889',
#  'AB347940',
#  'AB348151',
#  'AB348156',
#  'AB348315',
#  'AB348316',
#  'AB348327',
#  'AB348335',
#  'AB348416',
#  'AB348429',
#  'AB348697',
#  'AB348727',
#  'AB348738',
#  'AB349069',
#  'AB349106',
#  'AB349132',
#  'AB349142',
#  'AB349166',
#  'AB349505',
#  'AB349586',
#  'AB349653',
#  'AB349717',
#  'AB349738',
#  'AB349790',
#  'AB349811',
#  'AB349855',
#  'AB349959',
#  'AB349994',
#  'AB350106',
#  'AB350133',
#  'AB350299',
#  'AB350311',
#  'AB350315',
#  'AB350709',
#  'AB350776',
#  'AB350795',
#  'AB350849',
#  'AB350869',
#  'AB350908',
#  'AB350956',
#  'AB351020',
#  'AB351078',
#  'AB351190',
#  'AB351293',
#  'AB351301',
#  'AB351375',
#  'AB351440',
#  'AB351533',
#  'AB351564',
#  'AB351622',
#  'AB351656',
#  'AB351778',
#  'AB351862',
#  'AB351889',
#  'AB352038',
#  'AB352058',
#  'AB352175',
#  'AB352304',
#  'AB352356',
#  'AB352403',
#  'AB352444',
#  'AB352479',
#  'AB352621',
#  'AB352754',
#  'AB352792',
#  'AB352820',
#  'AB352881',
#  'AB352938',
#  'AB352974',
#  'AB353040',
#  'AB904934',
#  'AF012151',
#  'AF032968',
#  'AF034160',
#  'AF041915',
#  'AF041937',
#  'AF050165',
#  'AF093858',
#  'AF093862',
#  'AF216290',
#  'AF251705',
#  'AF357374',
#  'AF357376',
#  'AF357446',
#  'AF365933',
#  'AF374167',
#  'AF374273',
#  'AF465519',
#  'AF479022',
#  'AK002250',
#  'AK002417',
#  'AK002663',
#  'AK002748',
#  'AK002875',
#  'AK003103',
#  'AK003208',
#  'AK003327',
#  'AK003349',
#  'AK003663',
#  'AK003793',
#  'AK004434',
#  'AK005115',
#  'AK005187',
#  'AK005214',
#  'AK005363',
#  'AK005414',
#  'AK005481',
#  'AK005576',
#  'AK005616',
#  'AK005678',
#  'AK005712',
#  'AK005754',
#  'AK005807',
#  'AK005833',
#  'AK005839',
#  'AK005956',
#  'AK005987',
#  'AK006001',
#  'AK006015',
#  'AK006024',
#  'AK006029',
#  'AK006037',
#  'AK006039',
#  'AK006051',
#  'AK006119',
#  'AK006131',
#  'AK006138',
#  'AK006139',
#  'AK006167',
#  'AK006186',
#  'AK006189',
#  'AK006202',
#  'AK006245',
#  'AK006250',
#  'AK006331',
#  'AK006355',
#  'AK006362',
#  'AK006397',
#  'AK006455',
#  'AK006457',
#  'AK006476',
#  'AK006485',
#  'AK006507',
#  'AK006531',
#  'AK006560',
#  'AK006572',
#  'AK006576',
#  'AK006581',
#  'AK006610',
#  'AK006623',
#  'AK006637',
#  'AK006644',
#  'AK006651',
#  'AK006653',
#  'AK006659',
#  'AK006664',
#  'AK006677',
#  'AK006706',
#  'AK006709',
#  'AK006725',
#  'AK006748',
#  'AK006766',
#  'AK006768',
#  'AK006822',
#  'AK006832',
#  'AK006844',
#  'AK006859',
#  'AK006870',
#  'AK006909',
#  'AK006921',
#  'AK006930',
#  'AK006933',
#  'AK006937',
#  'AK006943',
#  'AK006961',
#  'AK006963',
#  'AK006973',
#  'AK006980',
#  'AK007010',
#  'AK007073',
#  'AK007082',
#  'AK007083',
#  'AK007112',
#  'AK007116',
#  'AK007159',
#  'AK007174',
#  'AK007185',
#  'AK007204',
#  'AK007237',
#  'AK007238',
#  'AK007249',
#  'AK007420',
#  'AK007436',
#  'AK007459',
#  'AK007605',
#  'AK007819',
#  'AK007836',
#  'AK007845',
#  'AK007898',
#  'AK007899',
#  'AK007907',
#  'AK007939',
#  'AK008044',
#  'AK008114',
#  'AK008222',
#  'AK008288',
#  'AK008306',
#  'AK008384',
#  'AK008432',
#  'AK008482',
#  'AK008488',
#  'AK008496',
#  'AK008572',
#  'AK008665',
#  'AK008732',
#  'AK008767',
#  'AK008812',
#  'AK008866',
#  'AK009067',
#  'AK009121',
#  'AK009182',
#  'AK009335',
#  'AK009383',
#  'AK009395',
#  'AK009639',
#  'AK009699',
#  'AK009785',
#  'AK009869',
#  'AK009977',
#  'AK010244',
#  'AK010245',
#  'AK010638',
#  'AK010824',
#  'AK011205',
#  'AK011326',
#  'AK011444',
#  'AK011498',
#  'AK011526',
#  'AK011877',
#  'AK011913',
#  'AK012046',
#  'AK012214',
#  'AK012238',
#  'AK012325',
#  'AK012478',
#  'AK012891',
#  'AK012899',
#  'AK013187',
#  'AK013192',
#  'AK013453',
#  'AK013480',
#  'AK013560',
#  'AK013627',
#  'AK013668',
#  'AK013883',
#  'AK013890',
#  'AK013935',
#  'AK014089',
#  'AK014156',
#  'AK014157',
#  'AK014209',
#  'AK014273',
#  'AK014401',
#  'AK014435',
#  'AK014513',
#  'AK014660',
#  'AK014798',
#  'AK014836',
#  'AK014863',
#  'AK014930',
#  'AK014951',
#  'AK014974',
#  'AK015045',
#  'AK015096',
#  'AK015118',
#  'AK015174',
#  'AK015183',
#  'AK015188',
#  'AK015227',
#  'AK015236',
#  'AK015254',
#  'AK015277',
#  'AK015284',
#  'AK015305',
#  'AK015322',
#  'AK015341',
#  'AK015376',
#  'AK015378',
#  'AK015392',
#  'AK015416',
#  'AK015421',
#  'AK015428',
#  'AK015488',
#  'AK015492',
#  'AK015520',
#  'AK015526',
#  'AK015529',
#  'AK015544',
#  'AK015545',
#  'AK015566',
#  'AK015664',
#  'AK015703',
#  'AK015767',
#  'AK015772',
#  'AK015813',
#  'AK015814',
#  'AK015818',
#  'AK015829',
#  'AK015900',
#  'AK015940',
#  'AK015953',
#  'AK016007',
#  'AK016016',
#  'AK016027',
#  'AK016061',
#  'AK016085',
#  'AK016097',
#  'AK016128',
#  'AK016129',
#  'AK016131',
#  'AK016162',
#  'AK016163',
#  'AK016170',
#  'AK016175',
#  'AK016178',
#  'AK016192',
#  'AK016207',
#  'AK016243',
#  'AK016244',
#  'AK016255',
#  'AK016276',
#  'AK016280',
#  'AK016283',
#  'AK016328',
#  'AK016335',
#  'AK016377',
#  'AK016412',
#  'AK016413',
#  'AK016650',
#  'AK016672',
#  'AK016696',
#  'AK016731',
#  'AK016734',
#  'AK016741',
#  'AK016790',
#  'AK016813',
#  'AK016836',
#  'AK016898',
#  'AK017006',
#  'AK017010',
#  'AK017048',
#  'AK017068',
#  'AK017086',
#  'AK017092',
#  'AK017104',
#  'AK017143',
#  'AK017177',
#  'AK017182',
#  'AK017243',
#  'AK017280',
#  'AK017296',
#  'AK017306',
#  'AK017434',
#  'AK017534',
#  'AK017552',
#  'AK017645',
#  'AK017779',
#  'AK017845',
#  'AK017891',
#  'AK018014',
#  'AK018074',
#  'AK018092',
#  'AK018134',
#  'AK018156',
#  'AK018197',
#  'AK018214',
#  'AK018237',
#  'AK018309',
#  'AK018352',
#  'AK018394',
#  'AK018405',
#  'AK018427',
#  'AK018490',
#  'AK018523',
#  'AK018679',
#  'AK018753',
#  'AK018847',
#  'AK018905',
#  'AK018913',
#  'AK018918',
#  'AK018924',
#  'AK018937',
#  'AK018940',
#  'AK018959',
#  'AK018965',
#  'AK018967',
#  'AK018972',
#  'AK018988',
#  'AK019057',
#  'AK019067',
#  'AK019114',
#  'AK019124',
#  'AK019237',
#  'AK019250',
#  'AK019290',
#  'AK019365',
#  'AK019366',
#  'AK019375',
#  'AK019420',
#  'AK019494',
#  'AK019514',
#  'AK019541',
#  'AK019563',
#  'AK019592',
#  'AK019593',
#  'AK019596',
#  'AK019598',
#  'AK019601',
#  'AK019614',
#  'AK019623',
#  'AK019630',
#  'AK019643',
#  'AK019662',
#  'AK019679',
#  'AK019680',
#  'AK019688',
#  'AK019690',
#  'AK019699',
#  'AK019701',
#  'AK019709',
#  'AK019722',
#  'AK019723',
#  'AK019737',
#  'AK019738',
#  'AK019743',
#  'AK019745',
#  'AK019757',
#  'AK019773',
#  'AK019774',
#  'AK019796',
#  'AK019797',
#  'AK019798',
#  'AK019801',
#  'AK019804',
#  'AK019810',
#  'AK019848',
#  'AK019949',
#  'AK019984',
#  'AK020043',
#  'AK020054',
#  'AK020060',
#  'AK020061',
#  'AK020087',
#  'AK020100',
#  'AK020101',
#  'AK020109',
#  'AK020188',
#  'AK020205',
#  'AK020216',
#  'AK020239',
#  'AK020256',
#  'AK020320',
#  'AK020345',
#  'AK020365',
#  'AK020376',
#  'AK020506',
#  'AK020549',
#  'AK020562',
#  'AK020588',
#  'AK020645',
#  'AK020680',
#  'AK020705',
#  'AK020711',
#  'AK020767',
#  'AK020768',
#  'AK020795',
#  'AK020829',
#  'AK020833',
#  'AK020853',
#  'AK020854',
#  'AK020861',
#  'AK020885',
#  'AK020898',
#  'AK020930',
#  'AK020985',
#  'AK020987',
#  'AK021001',
#  'AK021004',
#  'AK021007',
#  'AK021048',
#  'AK021128',
#  'AK021191',
#  'AK021218',
#  'AK021261',
#  'AK021280',
#  'AK021307',
#  'AK021325',
#  'AK021338',
#  'AK021342',
#  'AK021362',
#  'AK021383',
#  'AK027935',
#  'AK027968',
#  'AK027991',
#  'AK028033',
#  'AK028088',
#  'AK028089',
#  'AK028094',
#  'AK028111',
#  'AK028130',
#  'AK028224',
#  'AK028243',
#  'AK028255',
#  'AK028422',
#  'AK028530',
#  'AK028549',
#  'AK028583',
#  'AK028613',
#  'AK028659',
#  'AK028705',
#  'AK028708',
#  'AK028710',
#  'AK028711',
#  'AK028782',
#  'AK028798',
#  'AK028852',
#  'AK028892',
#  'AK028908',
#  'AK028951',
#  'AK028959',
#  'AK028960',
#  'AK029023',
#  'AK029122',
#  'AK029153',
#  'AK029170',
#  'AK029192',
#  'AK029258',
#  'AK029324',
#  'AK029357',
#  'AK029385',
#  'AK029404',
#  'AK029407',
#  'AK029413',
#  'AK029418',
#  'AK029443',
#  'AK029540',
#  'AK029587',
#  'AK029591',
#  'AK029599',
#  'AK029614',
#  'AK029620',
#  'AK029624',
#  'AK029633',
#  'AK029637',
#  'AK029641',
#  'AK029643',
#  'AK029646',
#  'AK029663',
#  'AK029672',
#  'AK029674',
#  'AK029692',
#  'AK029757',
#  'AK029760',
#  'AK029768',
#  'AK029815',
#  'AK029834',
#  'AK029875',
#  'AK029934',
#  'AK029949',
#  'AK030005',
#  'AK030063',
#  'AK030136',
#  'AK030154',
#  'AK030200',
#  'AK030206',
#  'AK030236',
#  'AK030263',
#  'AK030289',
#  'AK030308',
#  'AK030357',
#  'AK030382',
#  'AK030443',
#  'AK030468',
#  'AK030496',
#  'AK030551',
#  'AK030561',
#  'AK030597',
#  'AK030610',
#  'AK030646',
#  'AK030697',
#  'AK030770',
#  'AK030777',
#  'AK030785',
#  'AK030836',
#  'AK030906',
#  'AK030929',
#  'AK030979',
#  'AK031024',
#  'AK031053',
#  'AK031066',
#  'AK031070',
#  'AK031165',
#  'AK031221',
#  'AK031274',
#  'AK031300',
#  'AK031304',
#  'AK031372',
#  'AK031383',
#  'AK031392',
#  'AK031468',
#  'AK031532',
#  'AK031561',
#  'AK031574',
#  'AK031662',
#  'AK031732',
#  'AK031816',
#  'AK031861',
#  'AK031862',
#  'AK031897',
#  'AK031979',
#  'AK032000',
#  'AK032118',
#  'AK032194',
#  'AK032255',
#  'AK032287',
#  'AK032382',
#  'AK032387',
#  'AK032426',
#  'AK032440',
#  'AK032489',
#  'AK032505',
#  'AK032654',
#  'AK032717',
#  'AK032758',
#  'AK032761',
#  'AK032800',
#  'AK032899',
#  'AK032919',
#  'AK032987',
#  'AK033041',
#  'AK033051',
#  'AK033058',
#  'AK033061',
#  'AK033064',
#  'AK033069',
#  'AK033136',
#  'AK033148',
#  'AK033180',
#  'AK033210',
#  'AK033228',
#  'AK033245',
#  'AK033254',
#  'AK033270',
#  'AK033301',
#  'AK033307',
#  'AK033339',
#  'AK033378',
#  'AK033381',
#  'AK033411',
#  'AK033426',
#  'AK033433',
#  'AK033525',
#  'AK033552',
#  'AK033693',
#  'AK033756',
#  'AK033814',
#  'AK033818',
#  'AK033912',
#  'AK033930',
#  'AK033986',
#  'AK034016',
#  'AK034221',
#  'AK034234',
#  'AK034260',
#  'AK034278',
#  'AK034330',
#  'AK034341',
#  'AK034363',
#  'AK034420',
#  'AK034421',
#  'AK034441',
#  'AK034456',
#  'AK034494',
#  'AK034502',
#  'AK034519',
#  'AK034568',
#  'AK034630',
#  'AK034707',
#  'AK034716',
#  'AK034727',
#  'AK034775',
#  'AK034781',
#  ...]

# %%
reference = reference.merge(df, how='left', left_on='geneName', right_index=True)
reference.head()
# Out:
#    geneName        ucID chrom geneStrand  geneStart  geneEnd   HGNC symbol
# 0  AK135172  uc007aet.1  chr1          -    3205903  3215632    NaN    NaN
# 1      Xkr4  uc007aeu.1  chr1          -    3214481  3671498  29394   XKR4
# 2  AK149000  uc007aev.1  chr1          -    3648310  3658904    NaN    NaN
# 3       Rp1  uc007aew.1  chr1          -    4290845  4409241  10263    RP1
# 4       Rp1  uc007aex.2  chr1          -    4343506  4360314  10263    RP1

# %%
reference.symbol = reference.symbol.fillna(reference.geneName)

# %%
del reference['geneName']
reference.rename(columns={'symbol': 'geneName'}, inplace=True)
reference.head()
# Out:
#          ucID chrom geneStrand  geneStart  geneEnd   HGNC  geneName
# 0  uc007aet.1  chr1          -    3205903  3215632    NaN  AK135172
# 1  uc007aeu.1  chr1          -    3214481  3671498  29394      XKR4
# 2  uc007aev.1  chr1          -    3648310  3658904    NaN  AK149000
# 3  uc007aew.1  chr1          -    4290845  4409241  10263       RP1
# 4  uc007aex.2  chr1          -    4343506  4360314  10263       RP1

# %%
reference = reference[['geneName', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#    geneName chrom geneStrand  geneStart  geneEnd
# 0  AK135172  chr1          -    3205903  3215632
# 1      XKR4  chr1          -    3214481  3671498
# 2  AK149000  chr1          -    3648310  3658904
# 3       RP1  chr1          -    4290845  4409241
# 4       RP1  chr1          -    4343506  4360314

# %%
(len(reference), len(reference.drop_duplicates()))
# Out:
# (63759, 53286)

# %%
reference.drop_duplicates(inplace=True)

# %%
reference.to_csv('../example_data/mm9/reference.normalized.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part II: Constructing a motifs file
#
# Unlike hg19, this file isn't pre-normalized

# %%
motifs = parse_motifs_file(motifs_file)
motifs.head()

# %%
motifs = motifs[['motifName', 'chrom', 'motifStrand', 'motifStart', 'motifEnd', 'motifScore']]
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
(len(motifs), len(motifs.drop_duplicates()))
# Out:
# (24954274, 24892939)

# %%
motifs.drop_duplicates(inplace=True)

# %%
motifs[motifs.motifName.isnull()]
# Out:
# Empty DataFrame
# Columns: [motifName, chrom, motifStrand, motifStart, motifEnd, motifScore]
# Index: []

# %% [markdown]
# ### ...Incredible!

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(np.unique(motifs.motifName.values).tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="mm9", as_dataframe=True, returnall=True)
df
# Out:
# querying 1-518...done.
# Finished.
# 464 input query terms found dup hits:
# 	[('AFP1', 10), ('AIRE', 10), ('ALX-3', 10), ('AML', 5), ('AML1', 10), ('AP-1', 10), ('AP-2', 10), ('
# 56 input query terms found no hit:
# 	['ATF2:c-Jun', 'AhR:Arnt', 'Arnt::Ahr', 'Barhl-1', 'CACCC-binding', 'CHOP:C/EBPalpha', 'CLOCK:BMAL',
# {'dup': [('AFP1', 10),
#   ('AIRE', 10),
#   ('ALX-3', 10),
#   ('AML', 5),
#   ('AML1', 10),
#   ('AP-1', 10),
#   ('AP-2', 10),
#   ('AP-2rep', 3),
#   ('AR', 10),
#   ('ARP-1', 6),
#   ('ATF1', 10),
#   ('ATF2', 10),
#   ('ATF3', 10),
#   ('ATF4', 10),
#   ('AhR', 20),
#   ('Arnt', 20),
#   ('HIF-1', 10),
#   ('Alx-4', 10),
#   ('Arx', 10),
#   ('BCL6', 10),
#   ('BEN', 10),
#   ('Bach1', 10),
#   ('Bach2', 10),
#   ('Barhl2', 10),
#   ('Barx-2', 10),
#   ('Barx1', 10),
#   ('Brachyury', 10),
#   ('Brn-2', 6),
#   ('Brn-3c', 2),
#   ('Brn-4', 3),
#   ('Bsx', 10),
#   ('C/EBP', 10),
#   ('C/EBPalpha', 5),
#   ('C/EBPbeta', 6),
#   ('C/EBPdelta', 2),
#   ('factor', 20),
#   ('CART1', 10),
#   ('CDP', 40),
#   ('CR1', 10),
#   ('CR3', 10),
#   ('HD', 10),
#   ('CHX10', 10),
#   ('COUP', 40),
#   ('direct', 40),
#   ('repeat', 50),
#   ('COUP-TF', 2),
#   ('HNF-4', 20),
#   ('CP2', 10),
#   ('CP2/LBP-1c/LSF', 2),
#   ('CREB', 20),
#   ('ATF', 10),
#   ('CRX', 10),
#   ('CTCF', 10),
#   ('Cart-1', 4),
#   ('Cdx', 10),
#   ('Cdx-1', 10),
#   ('Cdx-2', 10),
#   ('Cphx', 3),
#   ('DBP', 10),
#   ('DEAF1', 10),
#   ('DEC', 10),
#   ('DMRT1', 10),
#   ('DMRT2', 10),
#   ('DMRT3', 10),
#   ('DMRT4', 9),
#   ('DMRT5', 8),
#   ('DMRT7', 3),
#   ('Dax1', 10),
#   ('Dlx-1', 10),
#   ('Dlx-2', 7),
#   ('Dlx7', 3),
#   ('E12', 10),
#   ('E2A', 10),
#   ('E2F', 10),
#   ('E2F-1', 10),
#   ('E2F1', 10),
#   ('E2F6', 10),
#   ('E4F1', 10),
#   ('EAR2', 10),
#   ('EBF', 10),
#   ('EBF1', 10),
#   ('ELF5', 10),
#   ('EMX2', 10),
#   ('ER', 10),
#   ('ERR', 10),
#   ('alpha', 10),
#   ('ERR2', 10),
#   ('(ESRRB)', 7),
#   ('ESE1', 2),
#   ('ETS2', 10),
#   ('Egr-1', 10),
#   ('Egr-2', 3),
#   ('Egr-3', 3),
#   ('Egr1', 10),
#   ('Elf-1', 10),
#   ('Elk-1', 10),
#   ('En-1', 10),
#   ('En-2', 10),
#   ('En1', 10),
#   ('Esrrb', 10),
#   ('Esx1', 10),
#   ('Ets', 10),
#   ('Evi-1', 7),
#   ('Evi1', 10),
#   ('Evx-1', 4),
#   ('Evx2', 10),
#   ('FLI1', 10),
#   ('FOXJ2', 10),
#   ('FOXM1', 10),
#   ('FOXO1', 10),
#   ('FOXO3', 10),
#   ('FOXO3A', 10),
#   ('FOXO4', 10),
#   ('FOXP3', 10),
#   ('FRA1', 10),
#   ('FXR', 20),
#   ('inverted', 10),
#   ('Foxa2', 10),
#   ('Freac-3', 8),
#   ('Freac-4', 2),
#   ('GABP', 10),
#   ('GABPA', 10),
#   ('GAF', 10),
#   ('GATA', 10),
#   ('GATA-1', 10),
#   ('GATA-2', 10),
#   ('GATA-3', 10),
#   ('GATA-4', 10),
#   ('GATA-6', 10),
#   ('GCM', 10),
#   ('GCNF', 10),
#   ('GLI', 10),
#   ('GLI1', 10),
#   ('GLI2', 10),
#   ('GLI3', 10),
#   ('GR', 20),
#   ('GSH2', 10),
#   ('GZF1', 10),
#   ('Gata1', 10),
#   ('Gbx1', 10),
#   ('Gbx2', 10),
#   ('Gfi-1', 10),
#   ('Gfi1', 10),
#   ('Gfi1b', 10),
#   ('Gsc', 10),
#   ('HB24', 4),
#   ('HB9', 9),
#   ('HEB', 5),
#   ('HEN1', 10),
#   ('HES1', 10),
#   ('HFH3', 3),
#   ('(FOXI1)', 6),
#   ('(FOXF1A)', 2),
#   ('HIF1', 8),
#   ('HMG', 10),
#   ('HMGA2', 10),
#   ('HMGIY', 5),
#   ('HMX1', 10),
#   ('HNF-1beta', 4),
#   ('HNF1', 10),
#   ('HNF3', 10),
#   ('HNF3A', 7),
#   ('HNF3beta', 3),
#   ('HNF4', 30),
#   ('HNF4alpha', 6),
#   ('HOXA1', 10),
#   ('HOXA10', 10),
#   ('HOXA11', 10),
#   ('HOXA13', 10),
#   ('HOXA3', 10),
#   ('HOXA4', 10),
#   ('HOXA5', 20),
#   ('HOXA6', 10),
#   ('HOXA7', 10),
#   ('HOXB13', 10),
#   ('HOXB3', 10),
#   ('HOXB4', 10),
#   ('HOXB6', 10),
#   ('HOXB7', 10),
#   ('HOXB8', 10),
#   ('HOXB9', 10),
#   ('HOXC-8', 4),
#   ('HOXC10', 10),
#   ('HOXC11', 10),
#   ('HOXC12', 10),
#   ('HOXC13', 10),
#   ('HOXC4', 10),
#   ('HOXC5', 10),
#   ('HOXC6', 10),
#   ('HOXC9', 10),
#   ('HOXD1', 10),
#   ('HOXD10', 10),
#   ('HOXD11', 10),
#   ('HOXD12', 10),
#   ('HOXD3', 10),
#   ('HOXD8', 10),
#   ('HSF', 10),
#   ('HSF1', 10),
#   ('HSF2', 10),
#   ('HTF', 2),
#   ('Hdx', 10),
#   ('Helios', 10),
#   ('A', 10),
#   ('Hmbox1', 10),
#   ('Hmx3', 10),
#   ('(Nkx5-1)', 7),
#   ('Homez', 10),
#   ('HoxA2', 10),
#   ('HoxB5', 10),
#   ('ICSBP', 5),
#   ('IRF', 10),
#   ('IRF-1', 10),
#   ('IRF-2', 9),
#   ('IRF3', 10),
#   ('IRF8', 10),
#   ('IRX4', 10),
#   ('ISL1', 10),
#   ('Ik-1', 4),
#   ('Ikaros', 10),
#   ('Irx-3', 10),
#   ('Irx2', 10),
#   ('Isl2', 10),
#   ('K-2b', 10),
#   ('KAISO', 10),
#   ('LBP9', 4),
#   ('LEF1', 20),
#   ('TCF1', 10),
#   ('LH-2', 3),
#   ('LRF', 9),
#   ('LRH1', 6),
#   ('LXR', 30),
#   ('PXR', 20),
#   ('CAR', 20),
#   ('RAR', 20),
#   ('Lbx2', 10),
#   ('Lhx2', 10),
#   ('Lhx3', 10),
#   ('Lhx4', 10),
#   ('Lhx5', 10),
#   ('Lhx8', 10),
#   ('Lhx9', 10),
#   ('Lim-1', 10),
#   ('Lmo2', 10),
#   ('complex', 10),
#   ('Lyf-1', 2),
#   ('MAF', 10),
#   ('MAFA', 10),
#   ('MATH1', 4),
#   ('MEF-2', 10),
#   ('MEF2A', 10),
#   ('MRG2', 10),
#   ('MTF-1', 6),
#   ('MTF1', 10),
#   ('MYB', 10),
#   ('MZF1', 10),
#   ('Meis1', 10),
#   ('Meis2', 10),
#   ('Mox1', 8),
#   ('Msx-1', 10),
#   ('Msx-2', 10),
#   ('Msx-3', 10),
#   ('Myc', 10),
#   ('Mycn', 10),
#   ('MyoD', 10),
#   ('N-Myc', 10),
#   ('NF-1', 20),
#   ('NF-AT', 6),
#   ('NF-E2', 10),
#   ('NF-Y', 10),
#   ('NF-kappaB', 20),
#   ('(p65)', 10),
#   ('NFAT2', 5),
#   ('NFAT3', 5),
#   ('NKX6.1', 10),
#   ('NRF-1', 5),
#   ('NRSF', 8),
#   ('NUR77', 7),
#   ('Nanog', 10),
#   ('Ncx', 10),
#   ('NeuroD', 9),
#   ('Nkx1-1', 10),
#   ('Nkx1-2', 10),
#   ('Nkx2-1', 10),
#   ('Nkx2-2', 10),
#   ('Nkx2-3', 10),
#   ('Nkx2-4', 10),
#   ('Nkx2-5', 10),
#   ('Nkx2-6', 10),
#   ('Nkx2-9', 4),
#   ('Nkx3-2', 10),
#   ('Nkx3A', 3),
#   ('Nkx5-1', 7),
#   ('Nkx5-2', 2),
#   ('Nkx6-2', 10),
#   ('Nkx6-3', 10),
#   ('Nobox', 10),
#   ('Nr2e3', 10),
#   ('Nrf-2', 2),
#   ('OG-2', 10),
#   ('OTP', 10),
#   ('OTX', 10),
#   ('Obox1', 2),
#   ('Obox2', 2),
#   ('Obox3', 3),
#   ('Obox5', 2),
#   ('Oct-1', 10),
#   ('Oct-2', 10),
#   ('Oct-4', 10),
#   ('(POU5F1)', 7),
#   ('Oct-6', 6),
#   ('Octamer', 10),
#   ('Olf-1', 3),
#   ('Osf2', 6),
#   ('Otx1', 10),
#   ('Otx2', 10),
#   ('Otx3', 9),
#   ('Ovol1', 10),
#   ('P50:P50', 10),
#   ('P53', 10),
#   ('PEBP', 10),
#   ('PITX2', 10),
#   ('PITX3', 10),
#   ('PKNOX2', 10),
#   ('PLZF', 6),
#   ('PMX2A', 2),
#   ('PMX2B', 3),
#   ('PNR', 10),
#   ('POU2F3', 10),
#   ('POU3F2', 10),
#   ('POU6F1', 10),
#   ('PPAR', 30),
#   ('PPARG', 10),
#   ('PPARgamma', 7),
#   ('PR', 20),
#   ('PREP1', 7),
#   ('PSX1', 3),
#   ('PU.1', 10),
#   ('PU1', 3),
#   ('PUR1', 10),
#   ('Pax', 10),
#   ('Pax-1', 10),
#   ('Pax-2', 10),
#   ('Pax-3', 10),
#   ('Pax-4', 10),
#   ('Pax-5', 10),
#   ('Pax-6', 10),
#   ('Pax-7', 10),
#   ('Pax-8', 10),
#   ('Pax2', 10),
#   ('Pax4', 10),
#   ('Pax5', 10),
#   ('Pbx', 10),
#   ('Pbx-1', 10),
#   ('Pbx1', 10),
#   ('Pdx1', 10),
#   ('Pit-1', 10),
#   ('Pitx1', 10),
#   ('Pou5f1', 10),
#   ('Prop-1', 10),
#   ('RBP-Jkappa', 2),
#   ('REST', 10),
#   ('REX1', 10),
#   ('RFX', 10),
#   ('RFX1', 20),
#   ('(EF-C)', 10),
#   ('RSRFC4', 5),
#   ('Rhox11', 2),
#   ('Roaz', 5),
#   ('S8', 10),
#   ('SATB1', 10),
#   ('SEF-1', 2),
#   ('SF1', 10),
#   ('SMAD', 10),
#   ('SMAD3', 10),
#   ('SMAD4', 10),
#   ('SOX', 10),
#   ('SOX10', 10),
#   ('SOX17', 10),
#   ('SOX2', 10),
#   ('SOX4', 10),
#   ('SOX5', 10),
#   ('SOX9', 10),
#   ('SPI-B', 10),
#   ('SREBP', 10),
#   ('SREBP-1', 9),
#   ('SREBP1', 10),
#   ('SREBP2', 8),
#   ('SRF', 10),
#   ('SRY', 10),
#   ('STAT', 10),
#   ('STAT1', 10),
#   ('STAT1:STAT1', 10),
#   ('STAT3:STAT3', 10),
#   ('STAT4', 10),
#   ('STAT5A', 30),
#   ('(homodimer)', 2),
#   ('STAT5B', 10),
#   ('STAT6', 10),
#   ('Shox2', 10),
#   ('Six-1', 10),
#   ('Six-2', 10),
#   ('Six-3', 10),
#   ('Six-6', 10),
#   ('Sp3', 10),
#   ('Spz1', 10),
#   ('Stat3', 10),
#   ('Stra13', 10),
#   ('T', 10),
#   ('T3R', 2),
#   ('TAL1', 10),
#   ('TATA', 10),
#   ('TBX15', 10),
#   ('TBX18', 10),
#   ('TBX5', 10),
#   ('TEF', 10),
#   ('TEF-1', 10),
#   ('TFE', 8),
#   ('TGIF', 10),
#   ('TGIF1', 10),
#   ('TGIF2', 10),
#   ('TR4', 10),
#   ('TTF-1', 8),
#   ('(Nkx2-1)', 16),
#   ('TTF1', 10),
#   ('Tcfcp2l1', 2),
#   ('Tst-1', 3),
#   ('USF', 10),
#   ('Uncx-4.1', 2),
#   ('VBP', 10),
#   ('VDR', 20),
#   ('Vsx1', 10),
#   ('Whn', 5),
#   ('XBP-1', 10),
#   ('YY1', 10),
#   ('YY2', 10),
#   ('ZBED6', 10),
#   ('ZF5', 4),
#   ('Zec', 2),
#   ('Zic1', 10),
#   ('Zic2', 10),
#   ('Zic3', 10),
#   ('c-Ets-1', 20),
#   ('p54', 10),
#   ('c-Ets-1(p54)', 10),
#   ('c-Ets-2', 10),
#   ('c-Myb', 10),
#   ('c-Myc', 10),
#   ('c-Rel', 10),
#   ('core-binding', 10),
#   ('deltaEF1', 6),
#   ('dlx3', 10),
#   ('dlx5', 10),
#   ('hbp1', 10),
#   ('hoxa9', 10),
#   ('ipf1', 10),
#   ('isx', 10),
#   ('lhx6.1', 2),
#   ('lmx1b', 10),
#   ('myogenin', 20),
#   ('p300', 10),
#   ('p63', 10),
#   ('pax6', 10),
#   ('rax', 10),
#   ('six4', 10)],
#  'missing': ['ATF2:c-Jun',
#   'AhR:Arnt',
#   'Arnt::Ahr',
#   'Barhl-1',
#   'CACCC-binding',
#   'CHOP:C/EBPalpha',
#   'CLOCK:BMAL',
#   'COMP1',
#   '1',
#   'Dobox4',
#   'Dobox5',
#   'Ebox',
#   '1',
#   'FXR/RXR-alpha',
#   'GABP-alpha',
#   'GATA-X',
#   'GTF2IRD1-isoform2',
#   'IY',
#   '1',
#   'Hand1::Tcfe2a',
#   'Hand1:E47',
#   'Ik-2',
#   '(Tcfcp211)',
#   'LMAF',
#   '4',
#   'MEIS1A:HOXA9',
#   'MEIS1B:HOXA9',
#   'NKX22',
#   'NKX25',
#   'NRSE',
#   'OCT-x',
#   '1',
#   'PPARG::RXRA',
#   'PPARalpha:RXRalpha',
#   'PPARgamma:RXRalpha',
#   'PPARgamma:RXRalpha',
#   'RUSH-1alpha',
#   'RXR:LXR-beta',
#   'SMM',
#   'SMM_as_activator',
#   'SMM_as_activator_with_spacer',
#   'SMM_brkOnly',
#   'SMM_from_Brk_Gsb_Bam',
#   'SMM_from_consensus',
#   '(homotetramer)',
#   'STATx',
#   'TCF11:MafG',
#   'TERALPHA',
#   'Tal1::Gata1',
#   'Tax/CREB',
#   'VDR:RXR',
#   'Vax-1',
#   'Vax-2',
#   'aMEF-2',
#   'c-Myc:Max',
#   '/'],
#  'out':         HGNC                 _id     _score notfound        symbol
#  query
#  AFP1     NaN             2847518  73.748085      NaN          afp1
#  AFP1     NaN              843257  69.848260      NaN          AFP1
#  AFP1     NaN           108840814   8.728746      NaN  LOC108840814
#  AFP1     NaN            11440732   5.038149      NaN  MTR_3g025970
#  AFP1     NaN           108827246   4.760823      NaN  LOC108827246
#  AFP1     NaN           109132705   4.577127      NaN  LOC109132705
#  AFP1     NaN           103831324   4.574373      NaN  LOC103831324
#  AFP1     NaN           108202855   4.574373      NaN  LOC108202855
#  AFP1     NaN           100265755   4.569742      NaN  LOC100265755
#  AFP1     NaN            25494667   4.569742      NaN  MTR_5g045370
#  AIRE     360                 326  74.945470      NaN          AIRE
#  AIRE     NaN               11634  66.941760      NaN          Aire
#  AIRE     NaN              294328  59.077710      NaN          Aire
#  AIRE     NaN           103086904  58.191100      NaN          AIRE
#  AIRE     NaN           108239629  58.191100      NaN          aire
#  AIRE     NaN           102263368  58.191100      NaN          AIRE
#  AIRE     NaN           102342265  58.191100      NaN          AIRE
#  AIRE     NaN           107510160  58.191100      NaN          AIRE
#  AIRE     NaN           102859512  58.191100      NaN          AIRE
#  AIRE     NaN           109372106  58.191100      NaN          AIRE
#  ALX-3    449                 257   6.006139      NaN          ALX3
#  ALX-3    NaN              365900   4.262422      NaN          Alx3
#  ALX-3    NaN  ENSRNOG00000018290   4.153141      NaN          Alx3
#  ALX-3    NaN           101979352   4.032034      NaN          Alx3
#  ALX-3    NaN           102065307   4.032034      NaN          ALX3
#  ALX-3    NaN           106946538   4.032034      NaN          alx3
#  ALX-3    NaN              700927   4.032034      NaN          ALX3
#  ALX-3    NaN           102298792   4.032034      NaN          alx3
#  ALX-3    NaN           101932400   4.032034      NaN          ALX3
#  ALX-3    NaN           105531931   4.032034      NaN          ALX3
#  ...      ...                 ...        ...      ...           ...
#  pax6    8620                5080  75.030220      NaN          PAX6
#  pax6     NaN               18508  67.489280      NaN          Pax6
#  pax6     NaN           102967783  59.267002      NaN          PAX6
#  pax6     NaN           105717241  59.267002      NaN          PAX6
#  pax6     NaN           104535095  59.267002      NaN          PAX6
#  pax6     NaN           104166016  59.267002      NaN          PAX6
#  pax6     NaN           101936508  59.267002      NaN          PAX6
#  pax6     NaN           102290754  59.267002      NaN          pax6
#  pax6     NaN           103555272  59.267002      NaN          PAX6
#  pax6     NaN           106498149  59.267002      NaN          PAX6
#  rax    18662               30062  85.361630      NaN           RAX
#  rax      NaN               19434  67.785450      NaN           Rax
#  rax      NaN              114213  58.993546      NaN           Rax
#  rax      NaN           107600943  55.072020      NaN           rax
#  rax      NaN           101519493  55.072020      NaN           RAX
#  rax      NaN           101027736  55.072020      NaN           RAX
#  rax      NaN           101658653  55.072020      NaN           RAX
#  rax      NaN              615339  55.072020      NaN           RAX
#  rax      NaN           100988188  55.072020      NaN           RAX
#  rax      NaN           105073993  55.072020      NaN           RAX
#  six4   10890               51804  87.361370      NaN          SIX4
#  six4     NaN               20474  66.074220      NaN          Six4
#  six4     NaN              299138  60.451546      NaN          Six4
#  six4     NaN           109516052  58.334785      NaN          six4
#  six4     NaN           100221957  58.334785      NaN          SIX4
#  six4     NaN           102265493  58.334785      NaN          SIX4
#  six4     NaN           101612993  58.334785      NaN          Six4
#  six4     NaN              703798  58.334785      NaN          SIX4
#  six4     NaN           109320891  58.334785      NaN          SIX4
#  six4     NaN           108961295  58.334785      NaN          SIX4
#
#  [4590 rows x 5 columns]}

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df
# Out:
#                HGNC  symbol
# AIRE            360    AIRE
# ALX-3           449    ALX3
# AML1          10471   RUNX1
# AP-1           6205    JUNB
# AP-2          11742  TFAP2A
# AP-2rep        6346   KLF12
# AR              644      AR
# ARP-1           304  CRISP1
# ATF1            783    ATF1
# ATF2            784    ATF2
# ATF3            785    ATF3
# ATF4            786    ATF4
# AhR             348     AHR
# Arnt            700    ARNT
# HIF-1          4910   HIF1A
# Alx-4           450    ALX4
# Arx           18060     ARX
# BCL6           1001    BCL6
# BEN           12492   UBE2N
# Bach1           935   BACH1
# Bach2         14078   BACH2
# Barhl2          954  BARHL2
# Barx-2          956   BARX2
# Barx1           955   BARX1
# Brn-2          9215  POU3F2
# Brn-4          9217  POU3F4
# Bsx           20450     BSX
# C/EBP          1833   CEBPA
# CART1         12034   TRAF4
# CDP            2557    CUX1
# ...             ...     ...
# XBP-1         12801    XBP1
# YY1           12856     YY1
# YY2           31684     YY2
# ZBED6         33273   ZBED6
# ZF5           12860  ZBTB14
# Zec           28054  ZNF628
# Zic1          12872    ZIC1
# Zic2          12873    ZIC2
# Zic3          12874    ZIC3
# c-Ets-1        3488    ETS1
# p54           10782  SRSF11
# c-Ets-1(p54)   3488    ETS1
# c-Myb          7545     MYB
# c-Myc          7553     MYC
# c-Rel          9954     REL
# core-binding   1539    CBFB
# deltaEF1      11642    ZEB1
# dlx3           2916    DLX3
# dlx5           2918    DLX5
# hbp1          23200    HBP1
# hoxa9          5109   HOXA9
# isx           28084     ISX
# lhx6.1        21735    LHX6
# lmx1b          6654   LMX1B
# myogenin       7612    MYOG
# p300           3373   EP300
# p63           12640   UVRAG
# pax6           8620    PAX6
# rax           18662     RAX
# six4          10890    SIX4
#
# [366 rows x 2 columns]

# %%
len(df[df.index != df.symbol])
# Out:
# 246

# %%
missing
# Out:
# ['ATF2:c-Jun',
#  'AhR:Arnt',
#  'Arnt::Ahr',
#  'Barhl-1',
#  'CACCC-binding',
#  'CHOP:C/EBPalpha',
#  'CLOCK:BMAL',
#  'COMP1',
#  '1',
#  'Dobox4',
#  'Dobox5',
#  'Ebox',
#  '1',
#  'FXR/RXR-alpha',
#  'GABP-alpha',
#  'GATA-X',
#  'GTF2IRD1-isoform2',
#  'IY',
#  '1',
#  'Hand1::Tcfe2a',
#  'Hand1:E47',
#  'Ik-2',
#  '(Tcfcp211)',
#  'LMAF',
#  '4',
#  'MEIS1A:HOXA9',
#  'MEIS1B:HOXA9',
#  'NKX22',
#  'NKX25',
#  'NRSE',
#  'OCT-x',
#  '1',
#  'PPARG::RXRA',
#  'PPARalpha:RXRalpha',
#  'PPARgamma:RXRalpha',
#  'PPARgamma:RXRalpha',
#  'RUSH-1alpha',
#  'RXR:LXR-beta',
#  'SMM',
#  'SMM_as_activator',
#  'SMM_as_activator_with_spacer',
#  'SMM_brkOnly',
#  'SMM_from_Brk_Gsb_Bam',
#  'SMM_from_consensus',
#  '(homotetramer)',
#  'STATx',
#  'TCF11:MafG',
#  'TERALPHA',
#  'Tal1::Gata1',
#  'Tax/CREB',
#  'VDR:RXR',
#  'Vax-1',
#  'Vax-2',
#  'aMEF-2',
#  'c-Myc:Max',
#  '/']

# %%
motifs = motifs.merge(df, how='left', left_on='motifName', right_index=True)
motifs
# Out:
#          motifName  chrom motifStrand  motifStart   motifEnd  motifScore  \
# 0             ipf1   chr1           +     9199807    9199817         1.0
# 1             ipf1   chr1           +    13140986   13140996         1.0
# 2             ipf1   chr1           -    13352952   13352962         1.0
# 3             ipf1   chr1           -    19764680   19764690         1.0
# 4             ipf1   chr1           +    23167657   23167667         1.0
# 5             ipf1   chr1           +    25983558   25983568         1.0
# 6             ipf1   chr1           +    34351743   34351753         1.0
# 7             ipf1   chr1           +    42779143   42779153         1.0
# 8             ipf1   chr1           +    45549685   45549695         1.0
# 9             ipf1   chr1           +    48337032   48337042         1.0
# 10            ipf1   chr1           -    50972368   50972378         1.0
# 11            ipf1   chr1           +    60142851   60142861         1.0
# 12            ipf1   chr1           +    60975572   60975582         1.0
# 13            ipf1   chr1           -    68483734   68483744         1.0
# 14            ipf1   chr1           +    68708032   68708042         1.0
# 15            ipf1   chr1           -    70786849   70786859         1.0
# 16            ipf1   chr1           +    73323182   73323192         1.0
# 17            ipf1   chr1           +    76733146   76733156         1.0
# 18            ipf1   chr1           +    79256655   79256665         1.0
# 19            ipf1   chr1           -    79672675   79672685         1.0
# 20            ipf1   chr1           +    80394164   80394174         1.0
# 21            ipf1   chr1           +    89743546   89743556         1.0
# 22            ipf1   chr1           +    92649551   92649561         1.0
# 23            ipf1   chr1           +    93958531   93958541         1.0
# 24            ipf1   chr1           -    98286677   98286687         1.0
# 25            ipf1   chr1           +   120341810  120341820         1.0
# 26            ipf1   chr1           -   123189857  123189867         1.0
# 27            ipf1   chr1           +   128581008  128581018         1.0
# 28            ipf1   chr1           -   128467785  128467795         1.0
# 29            ipf1   chr1           -   140657715  140657725         1.0
# ...            ...    ...         ...         ...        ...         ...
# 24892909       Zec   chr7           +    72964449   72964462         1.0
# 24892910       Zec   chr8           +    84926824   84926837         1.0
# 24892911       Zec   chr8           -   121493018  121493031         1.0
# 24892912       Zec   chr9           +    47161277   47161290         1.0
# 24892913       Zec   chr9           -   110634208  110634221         1.0
# 24892914       Zec   chr1           +    77403615   77403628         1.0
# 24892915       Zec  chr11           +     4038827    4038840         1.0
# 24892916       Zec  chr11           -     6894570    6894583         1.0
# 24892917       Zec  chr11           -     7201932    7201945         1.0
# 24892918       Zec  chr11           +    40208256   40208269         1.0
# 24892919       Zec  chr11           +    44699455   44699468         1.0
# 24892920       Zec  chr11           -    68682756   68682769         1.0
# 24892921       Zec  chr11           -    69831175   69831188         1.0
# 24892922       Zec  chr11           +    97826958   97826971         1.0
# 24892923       Zec  chr11           -   121054682  121054695         1.0
# 24892924       Zec  chr12           -    17636491   17636504         1.0
# 24892925       Zec  chr13           -    43178120   43178133         1.0
# 24892926       Zec  chr15           -    98530392   98530405         1.0
# 24892927       Zec   chr2           -   125856328  125856341         1.0
# 24892928       Zec   chr5           +    46413004   46413017         1.0
# 24892929       Zec  chr12           -    91102826   91102839         1.0
# 24892930       Zec  chr13           -    45530405   45530418         1.0
# 24892931       Zec  chr13           -   111309733  111309746         1.0
# 24892932       Zec  chr14           -    71288599   71288612         1.0
# 24892933       Zec  chr17           -    44141039   44141052         1.0
# 24892934       Zec   chr2           +    91239705   91239718         1.0
# 24892935       Zec   chr3           +    12095261   12095274         1.0
# 24892936       Zec   chr3           +    75939196   75939209         1.0
# 24892937       Zec   chr3           -   143326805  143326818         1.0
# 24892938       Zec   chr9           +    85762713   85762726         1.0
#
#            HGNC  symbol
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# 5           NaN     NaN
# 6           NaN     NaN
# 7           NaN     NaN
# 8           NaN     NaN
# 9           NaN     NaN
# 10          NaN     NaN
# 11          NaN     NaN
# 12          NaN     NaN
# 13          NaN     NaN
# 14          NaN     NaN
# 15          NaN     NaN
# 16          NaN     NaN
# 17          NaN     NaN
# 18          NaN     NaN
# 19          NaN     NaN
# 20          NaN     NaN
# 21          NaN     NaN
# 22          NaN     NaN
# 23          NaN     NaN
# 24          NaN     NaN
# 25          NaN     NaN
# 26          NaN     NaN
# 27          NaN     NaN
# 28          NaN     NaN
# 29          NaN     NaN
# ...         ...     ...
# 24892909  28054  ZNF628
# 24892910  28054  ZNF628
# 24892911  28054  ZNF628
# 24892912  28054  ZNF628
# 24892913  28054  ZNF628
# 24892914  28054  ZNF628
# 24892915  28054  ZNF628
# 24892916  28054  ZNF628
# 24892917  28054  ZNF628
# 24892918  28054  ZNF628
# 24892919  28054  ZNF628
# 24892920  28054  ZNF628
# 24892921  28054  ZNF628
# 24892922  28054  ZNF628
# 24892923  28054  ZNF628
# 24892924  28054  ZNF628
# 24892925  28054  ZNF628
# 24892926  28054  ZNF628
# 24892927  28054  ZNF628
# 24892928  28054  ZNF628
# 24892929  28054  ZNF628
# 24892930  28054  ZNF628
# 24892931  28054  ZNF628
# 24892932  28054  ZNF628
# 24892933  28054  ZNF628
# 24892934  28054  ZNF628
# 24892935  28054  ZNF628
# 24892936  28054  ZNF628
# 24892937  28054  ZNF628
# 24892938  28054  ZNF628
#
# [24892939 rows x 8 columns]

# %%
motifs.symbol = motifs.symbol.fillna(motifs.motifName)
del motifs['motifName'], motifs['HGNC']
motifs.rename(columns={'symbol': 'motifName'}, inplace=True)
motifs.head()
# Out:
#   chrom motifStrand  motifStart  motifEnd  motifScore motifName
# 0  chr1           +     9199807   9199817         1.0      ipf1
# 1  chr1           +    13140986  13140996         1.0      ipf1
# 2  chr1           -    13352952  13352962         1.0      ipf1
# 3  chr1           -    19764680  19764690         1.0      ipf1
# 4  chr1           +    23167657  23167667         1.0      ipf1

# %%
motifs = motifs[['motifName', 'chrom', 'motifStrand', 'motifStart', 'motifEnd', 'motifScore']]
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
(len(motifs), len(motifs.drop_duplicates()))
# Out:
# (24892939, 24892939)

# %%
motifs.drop_duplicates(inplace=True)

# %%
motifs.to_csv('../example_data/mm9/mm9_motifmap.normalized.cleaned.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part III: Merging genes and motifs

# %%
reference = pd.read_csv('../example_data/mm9/reference.normalized.tsv', sep='\t')
motifs = pd.read_csv('../example_data/mm9/mm9_motifmap.normalized.cleaned.tsv', sep='\t')

# %%
reference.head()
# Out:
#     geneName chrom geneStrand  geneStart  geneEnd
# 0  mKIAA1889  chr1          -    3195984  3205713
# 1       XKR4  chr1          -    3204562  3661579
# 2   AK149000  chr1          -    3638391  3648985
# 3        RP1  chr1          -    4280926  4399322
# 4        RP1  chr1          -    4333587  4350395

# %%
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
reference = group_by_chromosome(reference)
motifs = group_by_chromosome(motifs)

# %%
options = {'upstream_window': 10000, 'downstream_window': 10000, 'tss': False}
reference = {chrom: IntervalTree_from_reference(genes, options) for chrom, genes in reference.items()}
motifs = {chrom: IntervalTree_from_motifs(chromosome_motifs) for chrom, chromosome_motifs in motifs.items()}

# %%
motifs_with_associated_genes = intersection_of_dict_of_intervaltree(motifs, reference)
# Out:
# 02:51:42 - GarNet: INFO - Computing intersection operation of IntervalTrees for each chromosome...

# %%
motifs_and_genes = [{**motif, **gene} for motif, gene in motifs_with_associated_genes]
motifs_and_genes = pd.DataFrame.from_records(motifs_and_genes)
motifs_and_genes.head()
# Out:
#          chrom  geneEnd geneName  geneStart geneStrand  motifEnd motifName  \
# 0  chrX_random   594813  Gm15093     395346          -    398121     FOSL1
# 1  chrX_random   594813  Gm15093     395346          -    522820     Dbx-2
# 2  chrX_random   594813  Gm15093     395346          -    522820     Msx-3
# 3  chrX_random   594813  Gm15093     395346          -    522820      PAX6
# 4  chrX_random   594813  Gm15093     395346          -    522820      En-1
#
#    motifScore  motifStart motifStrand
# 0    0.442020      398113           +
# 1    0.660888      522804           -
# 2    0.698805      522804           -
# 3    0.732189      522804           +
# 4    0.787059      522804           -

# %%
motifs_and_genes = motifs_and_genes[['chrom','motifName','motifStrand','motifStart','motifEnd','motifScore','geneName','geneStart','geneEnd','geneStrand']]
motifs_and_genes
# Out:
#                 chrom  motifName motifStrand  motifStart   motifEnd  \
# 0         chrX_random      FOSL1           +      398113     398121
# 1         chrX_random      Dbx-2           -      522804     522820
# 2         chrX_random      Msx-3           -      522804     522820
# 3         chrX_random       PAX6           +      522804     522820
# 4         chrX_random       En-1           -      522804     522820
# 5         chrX_random       ipf1           +     1136248    1136254
# 6         chrX_random       ipf1           +     1136248    1136254
# 7         chrX_random       PDX1           -      100524     100530
# 8         chrX_random       MYOG           +      392512     392520
# 9         chrX_random      MYEF2           +       14267      14289
# 10        chrX_random  alpha-CP1           -      537644     537655
# 11        chrX_random       CTCF           -      555230     555250
# 12        chrX_random       CTCF           -      555230     555250
# 13        chrX_random     NKX2-5           -      177819     177826
# 14        chrX_random   Tax/CREB           +      110238     110253
# 15        chrX_random       ipf1           +     1125535    1125541
# 16        chrX_random       ARNT           +      521711     521717
# 17        chrX_random      STAT1           +      111462     111483
# 18        chrX_random      STAT3           +      111462     111483
# 19        chrX_random       ETS2           -     1121961    1121968
# 20        chrX_random         ER           +     1141831    1141850
# 21        chrX_random       ESX1           -     1406311    1406328
# 22        chrX_random       En-2           +     1406311    1406328
# 23        chrX_random       LHX2           +     1406311    1406328
# 24        chrX_random       LH-2           +     1406311    1406328
# 25        chrX_random       EMX2           +     1406311    1406328
# 26        chrX_random      SOX17           +      402974     402980
# 27        chrX_random      STAT6           +      414872     414880
# 28        chrX_random     NKX3-2           +      110168     110174
# 29        chrX_random       ipf1           +     1125976    1125982
# ...               ...        ...         ...         ...        ...
# 33391183         chr4       E2F1           +   102486409  102486417
# 33391184         chr4        CRX           -     3674052    3674058
# 33391185         chr4       HNF4           -   117665732  117665738
# 33391186         chr4       HNF4           -   117665732  117665738
# 33391187         chr4       ipf1           +   106434500  106434506
# 33391188         chr4       ipf1           +   106434500  106434506
# 33391189         chr4         ER           -   153851386  153851397
# 33391190         chr4       IRF8           +   124918518  124918525
# 33391191         chr4       ETS2           -    49421046   49421053
# 33391192         chr4       ipf1           +   110272631  110272637
# 33391193         chr4       ipf1           +   110272631  110272637
# 33391194         chr4       ipf1           +   110272631  110272637
# 33391195         chr4       SPI1           +   110810299  110810307
# 33391196         chr4       SPI1           +   110810299  110810307
# 33391197         chr4       SPI1           +   110810299  110810307
# 33391198         chr4      KLF12           +   101926239  101926246
# 33391199         chr4      KLF12           +   101926239  101926246
# 33391200         chr4      KLF12           +   101926239  101926246
# 33391201         chr4      TEAD3           -    21721019   21721025
# 33391202         chr4      TEAD3           -    21721019   21721025
# 33391203         chr4      TEAD3           -    21721019   21721025
# 33391204         chr4        DBP           +    87871461   87871468
# 33391205         chr4        DBP           +    87871461   87871468
# 33391206         chr4      Obox6           -    84187461   84187476
# 33391207         chr4      Obox6           -    84187461   84187476
# 33391208         chr4      Obox6           -    84187461   84187476
# 33391209         chr4       PDX1           -    36364638   36364644
# 33391210         chr4       PDX1           -    36364638   36364644
# 33391211         chr4       TFEC           +    84214040   84214048
# 33391212         chr4       TFEC           +    84214040   84214048
#
#           motifScore  geneName  geneStart    geneEnd geneStrand
# 0           0.442020   Gm15093     395346     594813          -
# 1           0.660888   Gm15093     395346     594813          -
# 2           0.698805   Gm15093     395346     594813          -
# 3           0.732189   Gm15093     395346     594813          -
# 4           0.787059   Gm15093     395346     594813          -
# 5           0.981493  AK185910    1141891    1144819          -
# 6           0.981493  MIR138-2    1126526    1126597          -
# 7           1.000000     SPRY3     101351     106392          -
# 8           0.159941   Gm15093     395346     594813          -
# 9           0.909253     VAMP7      10737      39148          -
# 10          0.656406   Gm15093     395346     594813          -
# 11          0.068323     RBM15     562213     602417          -
# 12          0.068323   Gm15093     395346     594813          -
# 13          1.000000     TMLHE     159646     334187          +
# 14          1.000000     SPRY3     101351     106392          -
# 15          1.000000  MIR138-2    1126526    1126597          -
# 16          1.000000   Gm15093     395346     594813          -
# 17          0.409076     SPRY3     101351     106392          -
# 18          0.771388     SPRY3     101351     106392          -
# 19          0.202599  MIR138-2    1126526    1126597          -
# 20          0.515583  AK185910    1141891    1144819          -
# 21          0.696372    Gm1993    1375832    1397989          +
# 22          0.626880    Gm1993    1375832    1397989          +
# 23          0.624950    Gm1993    1375832    1397989          +
# 24          0.477562    Gm1993    1375832    1397989          +
# 25          0.561050    Gm1993    1375832    1397989          +
# 26          1.000000   Gm15093     395346     594813          -
# 27          0.712952   Gm15093     395346     594813          -
# 28          1.000000     SPRY3     101351     106392          -
# 29          1.000000  MIR138-2    1126526    1126597          -
# ...              ...       ...        ...        ...        ...
# 33391183    1.000000     SGIP1  102432967  102643782          +
# 33391184    1.000000       LYN    3605267    3718759          +
# 33391185    0.289945   ST3GAL3  117604757  117807495          -
# 33391186    0.289945   ST3GAL3  117604757  117807519          -
# 33391187    1.000000    ACOT11  106417165  106472436          -
# 33391188    1.000000    ACOT11  106417165  106429939          -
# 33391189    0.221129    PRDM16  153690233  154010982          -
# 33391190    0.741554  AK006677  124905840  124919296          +
# 33391191    0.208356    Acnat2   49392716   49421023          -
# 33391192    1.000000     AGBL4  110070395  111239615          +
# 33391193    1.000000     AGBL4  110070395  111330115          +
# 33391194    1.000000     AGBL4  110070395  111335629          +
# 33391195    0.772857     AGBL4  110070395  111239615          +
# 33391196    0.772857     AGBL4  110070395  111330115          +
# 33391197    0.772857     AGBL4  110070395  111335629          +
# 33391198    0.376842     PDE4B  101760345  102230202          +
# 33391199    0.376842     PDE4B  101927346  102279867          +
# 33391200    0.376842     PDE4B  101927346  102228529          +
# 33391201    1.000000     USP45   21703416   21711987          +
# 33391202    1.000000     USP45   21703416   21725527          +
# 33391203    1.000000     USP45   21703416   21765019          +
# 33391204    1.000000  BC057079   87740533   88056915          +
# 33391205    1.000000  BC057079   87767173   88056915          +
# 33391206    1.000000      BNC2   83918445   84320990          -
# 33391207    1.000000      BNC2   84034586   84320990          -
# 33391208    1.000000      BNC2   83918445   84192309          -
# 33391209    1.000000    LINGO2   35653896   36898777          -
# 33391210    1.000000    LINGO2   35653896   36665996          -
# 33391211    0.759370      BNC2   83918445   84320990          -
# 33391212    0.759370      BNC2   84034586   84320990          -
#
# [33391213 rows x 10 columns]

# %%
motifs_and_genes['motif_to_gene_distance'] = motifs_and_genes['motifStart'] - motifs_and_genes['geneStart']
motifs_and_genes.head()
# Out:
#          chrom motifName motifStrand  motifStart  motifEnd  motifScore  \
# 0  chrX_random     FOSL1           +      398113    398121    0.442020
# 1  chrX_random     Dbx-2           -      522804    522820    0.660888
# 2  chrX_random     Msx-3           -      522804    522820    0.698805
# 3  chrX_random      PAX6           +      522804    522820    0.732189
# 4  chrX_random      En-1           -      522804    522820    0.787059
#
#   geneName  geneStart  geneEnd geneStrand  motif_to_gene_distance
# 0  Gm15093     395346   594813          -                    2767
# 1  Gm15093     395346   594813          -                  127458
# 2  Gm15093     395346   594813          -                  127458
# 3  Gm15093     395346   594813          -                  127458
# 4  Gm15093     395346   594813          -                  127458

# %%
motifs_and_genes.to_csv('../example_data/mm9/intersection.tsv', sep='\t', header=True, index=False)

# %% [markdown]
# # Part IV: Building and exporting IntervalTrees: constructing the "GarNet File"

# %%
motifs_and_genes = pd.read_csv('../example_data/mm9/intersection.tsv', sep='\t')

# %%
motifs_and_genes = group_by_chromosome(motifs_and_genes)

# %%
motifs_and_genes = {chrom: IntervalTree_from_motifs(chromosome_motifs_and_genes) for chrom, chromosome_motifs_and_genes in motifs_and_genes.items()}

# %%
save_as_pickled_object(motifs_and_genes, '../example_data/mm9/', 'garnet.pickle')
