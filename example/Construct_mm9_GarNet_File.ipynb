# %% [markdown]
# # Constructing a GarNet file
#
# The goal here is to construct a file in which all of the gene and transcription factor names exist in the same namespace. We use mygene.info's API to map all the gene names to a common namespace. It isn't clear that they have the most "canonical" namespace but at present they correlate best with genecards, and seems to be more consistent than all other namespaces I know of.

# %%
# %pylab inline
import sys
import os
import pickle
import sqlite3
import numpy as np
import pandas as pd

known_genes_file = '../example_data/mm9/mm9_known_genes.txt'
kgXref_file = '../example_data/mm9/mm9_kgXref.txt'
motifs_file = '../example_data/mm9/motifmap.txt'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.append(os.path.abspath('../src'))
from garnet import (parse_known_genes_file, parse_motifs_file, 
                    IntervalTree_from_reference, IntervalTree_from_motifs, group_by_chromosome, 
                    intersection_of_dict_of_intervaltree, save_as_pickled_object)

# %% [markdown]
# # Part I: Constructing a reference file
#
# We use UCSC's [known genes](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=refGene&hgta_regionType=genome&position=chr21%3A33031597-33041570&hgta_outputType=primaryTable&hgta_outFileName=) and [Cross Reference (kgXref) file](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=kgXref&hgta_regionType=genome&position=chr21%3A33%2C031%2C597-33%2C041%2C570&hgta_outputType=primaryTable&hgta_outFileName=) as our foundation.

# %%
reference = parse_known_genes_file(known_genes_file, kgXref_file)
reference.head()
# Out:
#          ucID chrom geneStrand  geneStart  geneEnd  cdsStart   cdsEnd  \
# 0  uc007aet.1  chr1          -    3195984  3205713   3195984  3195984
# 1  uc007aeu.1  chr1          -    3204562  3661579   3206102  3661429
# 2  uc007aev.1  chr1          -    3638391  3648985   3638391  3638391
# 3  uc007aew.1  chr1          -    4280926  4399322   4283061  4399268
# 4  uc007aex.2  chr1          -    4333587  4350395   4334680  4342906
#
#    exonCount                        exonStarts  \
# 0          2                  3195984,3203519,
# 1          3          3204562,3411782,3660632,
# 2          2                  3638391,3648927,
# 3          4  4280926,4341990,4342282,4399250,
# 4          4  4333587,4341990,4342282,4350280,
#
#                            exonEnds     proteinID     alignID        kgID  \
# 0                  3197398,3205713,           NaN  uc007aet.1  uc007aet.1
# 1          3207049,3411982,3661579,        Q5GH67  uc007aeu.1  uc007aeu.1
# 2                  3640590,3648985,           NaN  uc007aev.1  uc007aev.1
# 3  4283093,4342162,4342918,4399322,  NP_001182591  uc007aew.1  uc007aew.1
# 4  4340172,4342162,4342918,4350395,        Q548Q8  uc007aex.2  uc007aex.2
#
#            mRNA    spID   spDisplayID   geneName        refseq       protAcc  \
# 0      AK135172     NaN           NaN  mKIAA1889           NaN           NaN
# 1  NM_001011874  Q5GH67    XKR4_MOUSE       Xkr4  NM_001011874  NP_001011874
# 2      AK149000     NaN           NaN   AK149000           NaN           NaN
# 3  NM_001195662     NaN           NaN        Rp1  NM_001195662  NP_001182591
# 4     NM_011283  Q548Q8  Q548Q8_MOUSE        Rp1     NM_011283     NP_035413
#
#                                          description
# 0  Mus musculus 12 days embryo female ovary cDNA,...
# 1                               XK-related protein 4
# 2  Mus musculus 2 days neonate sympathetic gangli...
# 3               oxygen-regulated protein 1 isoform 2
# 4               oxygen-regulated protein 1 isoform 1

# %%
reference = reference[['geneName', 'ucID', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#     geneName        ucID chrom geneStrand  geneStart  geneEnd
# 0  mKIAA1889  uc007aet.1  chr1          -    3195984  3205713
# 1       Xkr4  uc007aeu.1  chr1          -    3204562  3661579
# 2   AK149000  uc007aev.1  chr1          -    3638391  3648985
# 3        Rp1  uc007aew.1  chr1          -    4280926  4399322
# 4        Rp1  uc007aex.2  chr1          -    4333587  4350395

# %%
reference[reference.geneName.isnull()]
# Out:
# Empty DataFrame
# Columns: [geneName, ucID, chrom, geneStrand, geneStart, geneEnd]
# Index: []

# %% [markdown]
# ### ...Amazing!

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(np.unique(reference.geneName.values).tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="mm9", as_dataframe=True, returnall=True)
df
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 25001-26000...done.
# querying 26001-27000...done.
# querying 27001-28000...done.
# querying 28001-29000...done.
# querying 29001-29955...done.
# Finished.
# 19185 input query terms found dup hits:
# 	[('0610007P14Rik', 2), ('0610009B22Rik', 2), ('0610009O20Rik', 2), ('0610010F05Rik', 2), ('0610012G0
# 7148 input query terms found no hit:
# 	['100039707', '100042579', '100043387', '1110020G09Rik', '1110034A24Rik', '1700045I19Rik', '4831426I
# {'dup': [('0610007P14Rik', 2),
#   ('0610009B22Rik', 2),
#   ('0610009O20Rik', 2),
#   ('0610010F05Rik', 2),
#   ('0610012G03Rik', 2),
#   ('0610031J06Rik', 2),
#   ('0610037L13Rik', 2),
#   ('0610038B21Rik', 2),
#   ('0610039K10Rik', 2),
#   ('0610040B10Rik', 2),
#   ('1110002L01Rik', 2),
#   ('1110004E09Rik', 2),
#   ('1110005A23Rik', 2),
#   ('1110006O24Rik', 2),
#   ('1110008F13Rik', 2),
#   ('1110008L16Rik', 3),
#   ('1110008P14Rik', 2),
#   ('1110020A21Rik', 2),
#   ('1110032A03Rik', 2),
#   ('1110034B05Rik', 2),
#   ('1110037F02Rik', 2),
#   ('1110038B12Rik', 2),
#   ('1110051M20Rik', 2),
#   ('1110059E24Rik', 2),
#   ('1190003K10Rik', 2),
#   ('1190005I06Rik', 3),
#   ('1300002K09Rik', 2),
#   ('1300017J02Rik', 2),
#   ('14-3-3', 10),
#   ('gamma', 20),
#   ('1500004A13Rik', 3),
#   ('1500009C09Rik', 2),
#   ('1500011B03Rik', 2),
#   ('1500011K16Rik', 2),
#   ('1500015A07Rik', 2),
#   ('1500017E21Rik', 2),
#   ('1600002H07Rik', 2),
#   ('1600012P17Rik', 2),
#   ('1600014K23Rik', 2),
#   ('1600029O15Rik', 2),
#   ('1700001C02Rik', 2),
#   ('1700001G17Rik', 2),
#   ('1700001J11Rik', 2),
#   ('1700001L05Rik', 2),
#   ('1700001L19Rik', 2),
#   ('1700003G18Rik', 2),
#   ('1700003H04Rik', 2),
#   ('1700007B14Rik', 2),
#   ('1700007G11Rik', 2),
#   ('1700008J07Rik', 2),
#   ('1700009J07Rik', 2),
#   ('1700010D01Rik', 2),
#   ('1700010H22Rik', 2),
#   ('1700011M02Rik', 2),
#   ('1700012D14Rik', 2),
#   ('1700012P22Rik', 2),
#   ('1700013F07Rik', 2),
#   ('1700016D06Rik', 2),
#   ('1700017B05Rik', 2),
#   ('1700017N19Rik', 2),
#   ('1700018A04Rik', 2),
#   ('1700018A14Rik', 2),
#   ('1700018B24Rik', 2),
#   ('1700018L02Rik', 2),
#   ('1700019B03Rik', 2),
#   ('1700019M22Rik', 2),
#   ('1700020I14Rik', 2),
#   ('1700020L24Rik', 2),
#   ('1700020N01Rik', 3),
#   ('1700020N18Rik', 2),
#   ('1700021F07Rik', 2),
#   ('1700022A21Rik', 2),
#   ('1700024P16Rik', 2),
#   ('1700025C18Rik', 2),
#   ('1700025F22Rik', 2),
#   ('1700025G04Rik', 2),
#   ('1700026D11Rik', 2),
#   ('1700028B04Rik', 2),
#   ('1700028J19Rik', 2),
#   ('1700028K03Rik', 2),
#   ('1700028M03Rik', 2),
#   ('1700028P14Rik', 2),
#   ('1700029M20Rik', 2),
#   ('1700030C10Rik', 3),
#   ('1700030K09Rik', 2),
#   ('1700031F10Rik', 3),
#   ('1700031M16Rik', 3),
#   ('1700034H15Rik', 2),
#   ('1700034I23Rik', 2),
#   ('1700034O15Rik', 2),
#   ('1700037C18Rik', 2),
#   ('1700040F15Rik', 2),
#   ('1700040L02Rik', 2),
#   ('1700041C23Rik', 2),
#   ('1700044K03Rik', 2),
#   ('1700047M11Rik', 2),
#   ('1700048O20Rik', 2),
#   ('1700049E15Rik', 2),
#   ('1700049E17Rik1', 2),
#   ('1700049L16Rik', 2),
#   ('1700052I22Rik', 2),
#   ('1700052K11Rik', 2),
#   ('1700054K19Rik', 2),
#   ('1700058G18Rik', 2),
#   ('1700060C20Rik', 2),
#   ('1700065D16Rik', 2),
#   ('1700066B19Rik', 2),
#   ('1700066O22Rik', 2),
#   ('1700069L16Rik', 3),
#   ('1700071K01Rik', 2),
#   ('1700073E17Rik', 2),
#   ('1700084E18Rik', 2),
#   ('1700084J12Rik', 2),
#   ('1700086L19Rik', 2),
#   ('1700086O06Rik', 2),
#   ('1700088E04Rik', 2),
#   ('1700092M07Rik', 2),
#   ('1700096J18Rik', 2),
#   ('1700096K18Rik', 2),
#   ('1700102P08Rik', 2),
#   ('1700106J16Rik', 2),
#   ('1700108F19Rik', 2),
#   ('1700108J01Rik', 2),
#   ('1700109G14Rik', 2),
#   ('1700109H08Rik', 2),
#   ('1700111N16Rik', 2),
#   ('1700113H08Rik', 2),
#   ('1700120K04Rik', 2),
#   ('1700121N20Rik', 2),
#   ('1700123L14Rik', 2),
#   ('1700123O20Rik', 2),
#   ('1700128F08Rik', 2),
#   ('1810010D01Rik', 2),
#   ('1810013L24Rik', 2),
#   ('1810014B01Rik', 2),
#   ('1810030O07Rik', 2),
#   ('1810032O08Rik', 2),
#   ('1810041L15Rik', 2),
#   ('1810043G02Rik', 2),
#   ('1810058I24Rik', 2),
#   ('1810062O18Rik', 2),
#   ('1810064F22Rik', 2),
#   ('2010016I18Rik', 2),
#   ('2010107G12Rik', 2),
#   ('2010107G23Rik', 2),
#   ('2010109I03Rik', 2),
#   ('2010111I01Rik', 2),
#   ('2010300C02Rik', 2),
#   ('2010317E24Rik', 2),
#   ('2010320M18Rik', 2),
#   ('2210013O21Rik', 2),
#   ('2210016L21Rik', 2),
#   ('2210018M11Rik', 2),
#   ('2210409E12Rik', 2),
#   ('2210417A02Rik', 2),
#   ('2300009A05Rik', 2),
#   ('2310001K24Rik', 2),
#   ('2310003L22Rik', 2),
#   ('2310009B15Rik', 2),
#   ('2310011J03Rik', 2),
#   ('2310015A10Rik', 2),
#   ('2310022A10Rik', 2),
#   ('2310033P09Rik', 2),
#   ('2310035C23Rik', 2),
#   ('2310042D19Rik', 2),
#   ('2310045N01Rik', 2),
#   ('2310061C15Rik', 4),
#   ('2310061I04Rik', 2),
#   ('2310068J16Rik', 2),
#   ('2410006H16Rik', 2),
#   ('2410017I17Rik', 2),
#   ('2410018L13Rik', 2),
#   ('2410022M11Rik', 2),
#   ('2410131K14Rik', 2),
#   ('2510009E07Rik', 2),
#   ('2510039O18Rik', 2),
#   ('2610001J05Rik', 3),
#   ('2610002M06Rik', 3),
#   ('2610020H08Rik', 2),
#   ('2610028E06Rik', 2),
#   ('2610034M16Rik', 3),
#   ('2610035D17Rik', 2),
#   ('2610203C20Rik', 2),
#   ('2610203C22Rik', 2),
#   ('2610301B20Rik', 2),
#   ('2610306M01Rik', 2),
#   ('2610507B11Rik', 2),
#   ('2700029M09Rik', 2),
#   ('2700046A07Rik', 2),
#   ('2700046G09Rik', 2),
#   ('2700049A03Rik', 2),
#   ('2700062C07Rik', 2),
#   ('2700097O09Rik', 2),
#   ('2700099C18Rik', 2),
#   ('2810001G20Rik', 2),
#   ('2810002D19Rik', 2),
#   ('2810004N23Rik', 2),
#   ('2810025M15Rik', 2),
#   ('2810032G03Rik', 2),
#   ('2810047C21Rik1', 2),
#   ('2810403A07Rik', 2),
#   ('2810403D21Rik', 2),
#   ('2810405F15Rik', 2),
#   ('2810408M09Rik', 2),
#   ('2810410L24Rik', 2),
#   ('2810428I15Rik', 2),
#   ('2810429I04Rik', 2),
#   ('2810433D01Rik', 2),
#   ('2810454H06Rik', 2),
#   ('2900005J15Rik', 2),
#   ('2900011O08Rik', 2),
#   ('2900041M22Rik', 2),
#   ('2900052N01Rik', 2),
#   ('2900060B14Rik', 2),
#   ('2900079G21Rik', 2),
#   ('2900092C05Rik', 2),
#   ('2900097C17Rik', 3),
#   ('2b4', 10),
#   ('3000002C10Rik', 2),
#   ('3110002H16Rik', 2),
#   ('3110009E18Rik', 2),
#   ('3110039M20Rik', 2),
#   ('3110070M22Rik', 2),
#   ('3110082I17Rik', 2),
#   ('3110099E03Rik', 2),
#   ('3300002A11Rik', 2),
#   ('3632451O06Rik', 3),
#   ('3830406C13Rik', 2),
#   ('3830408C21Rik', 2),
#   ('3930401K13Rik', 2),
#   ('3930402G23Rik', 2),
#   ('4430402I18Rik', 2),
#   ('4631405J19Rik', 2),
#   ('4632415L05Rik', 2),
#   ('4632427E13Rik', 2),
#   ('4632428C04Rik', 2),
#   ('4731419I09Rik', 2),
#   ('4732416N19Rik', 2),
#   ('4732471J01Rik', 2),
#   ('4831440E17Rik', 2),
#   ('4833418N02Rik', 2),
#   ('4833420G17Rik', 3),
#   ('4833422C13Rik', 2),
#   ('4833427G06Rik', 2),
#   ('4833439L19Rik', 2),
#   ('4921511C20Rik', 2),
#   ('4921524J17Rik', 2),
#   ('4921531C22Rik', 2),
#   ('4921536K21Rik', 3),
#   ('4930402H24Rik', 2),
#   ('4930404I05Rik', 2),
#   ('4930404N11Rik', 2),
#   ('4930412C18Rik', 2),
#   ('4930412O13Rik', 2),
#   ('4930415F15Rik', 2),
#   ('4930417O13Rik', 2),
#   ('4930426L09Rik', 2),
#   ('4930427A07Rik', 2),
#   ('4930430F08Rik', 2),
#   ('4930432E11Rik', 2),
#   ('4930433N12Rik', 2),
#   ('4930442L01Rik', 2),
#   ('4930447C04Rik', 2),
#   ('4930448K20Rik', 2),
#   ('4930449A18Rik', 2),
#   ('4930449E01Rik', 2),
#   ('4930451C15Rik', 2),
#   ('4930452B06Rik', 2),
#   ('4930453N24Rik', 2),
#   ('4930465K10Rik', 2),
#   ('4930469G21Rik', 2),
#   ('4930470P17Rik', 2),
#   ('4930481A15Rik', 2),
#   ('4930483J18Rik', 2),
#   ('4930488L21Rik', 2),
#   ('4930503H13Rik', 2),
#   ('4930503L19Rik', 2),
#   ('4930505A04Rik', 2),
#   ('4930507D05Rik', 2),
#   ('4930511M06Rik', 2),
#   ('4930512B01Rik', 2),
#   ('4930513N10Rik', 2),
#   ('4930515G01Rik', 2),
#   ('4930515G16Rik', 2),
#   ('4930519F09Rik', 2),
#   ('4930519F16Rik', 2),
#   ('4930529C04Rik', 2),
#   ('4930539J05Rik', 2),
#   ('4930544D05Rik', 2),
#   ('4930550C14Rik', 2),
#   ('4930550L24Rik', 2),
#   ('4930558C23Rik', 2),
#   ('4930562F07Rik', 2),
#   ('4930563D23Rik', 2),
#   ('4930563E22Rik', 2),
#   ('4930567H12Rik', 2),
#   ('4930571K23Rik', 2),
#   ('4930578C19Rik', 3),
#   ('4930578G10Rik', 2),
#   ('4930578I06Rik', 3),
#   ('4930579K19Rik', 2),
#   ('4930581F22Rik', 2),
#   ('4930583K01Rik', 2),
#   ('4930584F24Rik', 2),
#   ('4930590J08Rik', 2),
#   ('4930594C11Rik', 2),
#   ('4930596D02Rik', 2),
#   ('4931406C07Rik', 2),
#   ('4931406P16Rik', 2),
#   ('4931409K22Rik', 2),
#   ('4931414P19Rik', 2),
#   ('4931428F04Rik', 2),
#   ('4931428L18Rik', 2),
#   ('4931440P22Rik', 2),
#   ('4932414J04Rik', 2),
#   ('4932415M13Rik', 2),
#   ('4932435O22Rik', 2),
#   ('4932438A13Rik', 2),
#   ('4932441J04Rik', 2),
#   ('4933400A11Rik', 2),
#   ('4933400F21Rik', 2),
#   ('4933401B06Rik', 2),
#   ('4933402N03Rik', 2),
#   ('4933404O12Rik', 2),
#   ('4933406F09Rik', 2),
#   ('4933406I18Rik', 2),
#   ('4933406K04Rik', 2),
#   ('4933407K13Rik', 2),
#   ('4933407L21Rik', 2),
#   ('4933415F23Rik', 2),
#   ('4933416C03Rik', 2),
#   ('4933416I08Rik', 2),
#   ('4933417G07Rik', 2),
#   ('4933421O10Rik', 2),
#   ('4933427D06Rik', 2),
#   ('4933427D14Rik', 3),
#   ('4933427E11Rik', 2),
#   ('4933427G17Rik', 2),
#   ('4933430I17Rik', 2),
#   ('4933431E20Rik', 2),
#   ('4933436I01Rik', 2),
#   ('4933439C10Rik', 2),
#   ('4F2', 10),
#   ('lc', 10),
#   ('5031425F14Rik', 2),
#   ('5031434O11Rik', 2),
#   ('5031439G07Rik', 2),
#   ('5033404E19Rik', 2),
#   ('5330413P13Rik', 2),
#   ('5330417C22Rik', 2),
#   ('5330434G04Rik', 2),
#   ('5330439B14Rik', 2),
#   ('53BP1', 3),
#   ('5430402O13Rik', 2),
#   ('5430405H02Rik', 2),
#   ('5430416N02Rik', 2),
#   ('5430421N21Rik', 2),
#   ('5430435G22Rik', 2),
#   ('5530601H04Rik', 2),
#   ('5730416F02Rik', 2),
#   ('5730422E09Rik', 2),
#   ('5730455P16Rik', 2),
#   ('5730494N06Rik', 2),
#   ('5730508B09Rik', 2),
#   ('5730522E02Rik', 2),
#   ('5730559C18Rik', 2),
#   ('5830405F06Rik', 2),
#   ('5830417I10Rik', 2),
#   ('5830432E09Rik', 2),
#   ('5930412G12Rik', 2),
#   ('6030408B16Rik', 2),
#   ('6030468B19Rik', 2),
#   ('6230400D17Rik', 2),
#   ('6330403K07Rik', 2),
#   ('6330408A02Rik', 2),
#   ('6330549D23Rik', 2),
#   ('6330578E17Rik', 2),
#   ('6430411K18Rik', 2),
#   ('6430531B16Rik', 2),
#   ('6430562O15Rik', 2),
#   ('6430573F11Rik', 2),
#   ('6530411M01Rik', 2),
#   ('6820431F20Rik', 2),
#   ('6D', 10),
#   ('7420426K07Rik', 2),
#   ('8030462N17Rik', 2),
#   ('8430429K09Rik', 2),
#   ('9030612E09Rik', 2),
#   ('9030619P08Rik', 2),
#   ('9030624J02Rik', 2),
#   ('9130011E15Rik', 3),
#   ('9130019P16Rik', 2),
#   ('9130024F11Rik', 2),
#   ('9130221H12Rik', 2),
#   ('9130230L23Rik', 2),
#   ('9230019H11Rik', 2),
#   ('9230109A22Rik', 2),
#   ('9230114K14Rik', 2),
#   ('9230116N13Rik', 2),
#   ('9330020H09Rik', 2),
#   ('9330111N05Rik', 2),
#   ('9330151L19Rik', 2),
#   ('9330158H04Rik', 2),
#   ('9330171B17Rik', 2),
#   ('9330175E14Rik', 2),
#   ('9430015G10Rik', 2),
#   ('9430021M05Rik', 2),
#   ('9430041J12Rik', 2),
#   ('9430060I03Rik', 2),
#   ('9430069I07Rik', 2),
#   ('9530026P05Rik', 2),
#   ('9530036O11Rik', 3),
#   ('9530059O14Rik', 2),
#   ('9530068E07Rik', 2),
#   ('9530077C05Rik', 2),
#   ('9530082P21Rik', 2),
#   ('9630028B13Rik', 2),
#   ('9630028H03Rik', 2),
#   ('9930012K11Rik', 2),
#   ('9930014A18Rik', 2),
#   ('9930022D16Rik', 2),
#   ('9930104L06Rik', 2),
#   ('A1bg', 10),
#   ('A1cf', 10),
#   ('A230020J21Rik', 2),
#   ('A230056P14Rik', 2),
#   ('A230057D06Rik', 4),
#   ('A230072C01Rik', 2),
#   ('A230072E10Rik', 2),
#   ('A230083G16Rik', 2),
#   ('A2ld1', 10),
#   ('A2m', 10),
#   ('A330008L17Rik', 2),
#   ('A330023F24Rik', 2),
#   ('A330035P11Rik', 2),
#   ('A330040F15Rik', 2),
#   ('A330069E16Rik', 2),
#   ('A330076H08Rik', 2),
#   ('A3galt2', 10),
#   ('A430005L14Rik', 2),
#   ('A430093F15Rik', 2),
#   ('A4galt', 10),
#   ('A4gnt', 10),
#   ('A530013C23Rik', 2),
#   ('A530021J07Rik', 2),
#   ('A530053G22Rik', 2),
#   ('A530058N18Rik', 3),
#   ('A530095I07Rik', 2),
#   ('A530099J19Rik', 2),
#   ('A630010A05Rik', 3),
#   ('A630012P03Rik', 2),
#   ('A630052C17Rik', 2),
#   ('A630072M18Rik', 2),
#   ('A630075F10Rik', 2),
#   ('A630091E08Rik', 2),
#   ('A730008H23Rik', 2),
#   ('A730017L22Rik', 2),
#   ('A730018C14Rik', 2),
#   ('A730020M07Rik', 2),
#   ('A830018L16Rik', 2),
#   ('A830019P07Rik', 2),
#   ('A830080D01Rik', 2),
#   ('A930003A15Rik', 3),
#   ('A930003O13Rik', 2),
#   ('A930004D18Rik', 2),
#   ('A930005H10Rik', 2),
#   ('A930007I19Rik', 2),
#   ('A930012L18Rik', 2),
#   ('A930015D03Rik', 2),
#   ('A930017M01Rik', 2),
#   ('A930018M24Rik', 3),
#   ('AA465934', 2),
#   ('AA467197', 2),
#   ('AA543186', 2),
#   ('AA545190', 2),
#   ('AA619741', 2),
#   ('AA881470', 2),
#   ('AA986860', 2),
#   ('AASDH', 10),
#   ('ABCR', 6),
#   ('ABLIM2', 10),
#   ('ACRP', 5),
#   ('ADAM22', 10),
#   ('ADD1', 10),
#   ('AF357425', 2),
#   ('AF529169', 2),
#   ('AI314180', 2),
#   ('AI413582', 2),
#   ('AI427809', 2),
#   ('AI481877', 2),
#   ('AI504432', 2),
#   ('AI506816', 2),
#   ('AI507597', 2),
#   ('AI597479', 2),
#   ('AI606181', 2),
#   ('AI661453', 2),
#   ('AI662270', 2),
#   ('AI854703', 2),
#   ('AI894139', 2),
#   ('AKAP95', 4),
#   ('APG16L', 6),
#   ('APMAP', 10),
#   ('ASK2', 5),
#   ('AU015228', 2),
#   ('AU015836', 2),
#   ('AU018091', 2),
#   ('AU019823', 2),
#   ('AU019990', 2),
#   ('AU040320', 2),
#   ('AW011738', 2),
#   ('AW112010', 2),
#   ('AW209491', 3),
#   ('AW549877', 2),
#   ('AW554918', 2),
#   ('AY358078', 2),
#   ('AY512915', 2),
#   ('AY512931', 2),
#   ('AZ2', 6),
#   ('Aaas', 10),
#   ('Aacs', 10),
#   ('Aadac', 10),
#   ('Aadacl2', 10),
#   ('Aadacl3', 10),
#   ('Aadat', 10),
#   ('Aagab', 10),
#   ('Aak1', 10),
#   ('Aamp', 10),
#   ('Aanat', 10),
#   ('Aard', 10),
#   ('Aars', 10),
#   ('Aars2', 10),
#   ('Aarsd1', 10),
#   ('Aasdh', 10),
#   ('Aasdhppt', 10),
#   ('Aass', 10),
#   ('Aat1', 10),
#   ('Aatf', 10),
#   ('Aatk', 10),
#   ('Abat', 10),
#   ('Abca1', 10),
#   ('Abca12', 10),
#   ('Abca13', 10),
#   ('Abca14', 3),
#   ('Abca15', 3),
#   ('Abca16', 2),
#   ('Abca17', 3),
#   ('Abca2', 10),
#   ('Abca3', 10),
#   ('Abca4', 10),
#   ('Abca5', 10),
#   ('Abca6', 10),
#   ('Abca7', 10),
#   ('Abca8a', 3),
#   ('Abca8b', 3),
#   ('Abca9', 10),
#   ('Abcb10', 10),
#   ('Abcb11', 10),
#   ('Abcb1a', 5),
#   ('Abcb1b', 5),
#   ('Abcb4', 10),
#   ('Abcb5', 10),
#   ('Abcb6', 10),
#   ('Abcb7', 10),
#   ('Abcb8', 10),
#   ('Abcb9', 10),
#   ('Abcc1', 10),
#   ('Abcc10', 10),
#   ('Abcc12', 10),
#   ('Abcc2', 10),
#   ('Abcc3', 10),
#   ('Abcc4', 10),
#   ('Abcc5', 10),
#   ('Abcc6', 10),
#   ('Abcc8', 10),
#   ('Abcc9', 10),
#   ('Abcd1', 10),
#   ('Abcd2', 10),
#   ('Abcd3', 10),
#   ('Abcd4', 10),
#   ('Abce1', 10),
#   ('Abcf1', 10),
#   ('Abcf2', 10),
#   ('Abcf3', 10),
#   ('Abcg1', 10),
#   ('Abcg2', 10),
#   ('Abcg3', 10),
#   ('Abcg4', 10),
#   ('Abcg5', 10),
#   ('Abcg8', 10),
#   ('Abhd1', 10),
#   ('Abhd10', 10),
#   ('Abhd11', 10),
#   ('Abhd12', 10),
#   ('Abhd12b', 10),
#   ('Abhd13', 10),
#   ('Abhd14a', 10),
#   ('Abhd14b', 10),
#   ('Abhd15', 10),
#   ('Abhd16a', 10),
#   ('Abhd16b', 10),
#   ('Abhd2', 10),
#   ('Abhd3', 10),
#   ('Abhd4', 10),
#   ('Abhd5', 10),
#   ('Abhd6', 10),
#   ('Abhd8', 10),
#   ('Abi1', 10),
#   ('Abi2', 10),
#   ('Abi3', 10),
#   ('Abi3bp', 10),
#   ('Abl1', 10),
#   ('Abl2', 10),
#   ('Ablim1', 10),
#   ('Ablim2', 10),
#   ('Ablim3', 10),
#   ('Abo', 10),
#   ('Abp1', 10),
#   ('Abpa', 10),
#   ('Abpb', 2),
#   ('Abpd', 4),
#   ('Abpz', 2),
#   ('Abr', 10),
#   ('Abra', 10),
#   ('Abt1', 10),
#   ('Abtb1', 10),
#   ('Abtb2', 10),
#   ('Acaa1a', 4),
#   ('Acaa1b', 2),
#   ('Acaa2', 10),
#   ('Acaca', 10),
#   ('Acacb', 10),
#   ('Acad10', 10),
#   ('Acad11', 10),
#   ('Acad8', 10),
#   ('Acad9', 10),
#   ('Acadl', 10),
#   ('Acadm', 10),
#   ('Acads', 10),
#   ('Acadsb', 10),
#   ('Acadvl', 10),
#   ('Acan', 10),
#   ('Acap1', 10),
#   ('Acap2', 10),
#   ('Acap3', 10),
#   ('Acat1', 10),
#   ('Acat2', 10),
#   ('Acat3', 2),
#   ('Acbd3', 10),
#   ('Acbd4', 10),
#   ('Acbd5', 10),
#   ('Acbd6', 10),
#   ('Acbd7', 10),
#   ('Accn1', 10),
#   ('Accn2', 10),
#   ('Accn3', 10),
#   ('Accn4', 10),
#   ('Accn5', 10),
#   ('Accs', 10),
#   ('Accsl', 10),
#   ('Acd', 10),
#   ('Acdp3', 2),
#   ('Ace', 10),
#   ('Ace2', 10),
#   ('Ace3', 7),
#   ('Acer1', 10),
#   ('Acer2', 10),
#   ('Acer3', 10),
#   ('Ache', 10),
#   ('Acin1', 10),
#   ('Acly', 10),
#   ('Acmsd', 10),
#   ('Acn9', 10),
#   ('Acnat1', 2),
#   ('Acnat2', 2),
#   ('Aco1', 10),
#   ('Aco2', 10),
#   ('Acot1', 10),
#   ('Acot10', 2),
#   ('Acot11', 10),
#   ('Acot12', 10),
#   ('Acot13', 10),
#   ('Acot2', 10),
#   ('Acot3', 3),
#   ('Acot4', 10),
#   ('Acot5', 3),
#   ('Acot6', 10),
#   ('Acot7', 10),
#   ('Acot8', 10),
#   ('Acot9', 10),
#   ('Acox1', 10),
#   ('Acox2', 10),
#   ('Acox3', 10),
#   ('Acoxl', 10),
#   ('Acp1', 10),
#   ('Acp2', 10),
#   ('Acp5', 10),
#   ('Acp6', 10),
#   ('Acpl2', 10),
#   ('Acpp', 10),
#   ('Acpt', 10),
#   ('Acr', 10),
#   ('Acrbp', 10),
#   ('Acrv1', 10),
#   ('Acsbg1', 10),
#   ('Acsbg2', 10),
#   ('Acsf2', 10),
#   ('Acsf3', 10),
#   ('Acsl1', 10),
#   ('Acsl3', 10),
#   ('Acsl4', 10),
#   ('Acsl5', 10),
#   ('Acsl6', 10),
#   ('Acsm1', 10),
#   ('Acsm2', 10),
#   ('Acsm3', 10),
#   ('Acsm4', 10),
#   ('Acsm5', 10),
#   ('Acss1', 10),
#   ('Acss2', 10),
#   ('Acss3', 10),
#   ('Acta1', 10),
#   ('Acta2', 10),
#   ('Actb', 10),
#   ('Actbl2', 10),
#   ('Actc1', 10),
#   ('Actg1', 10),
#   ('Actg2', 10),
#   ('Actl6a', 10),
#   ('Actl6b', 10),
#   ('Actl7a', 10),
#   ('Actl7b', 10),
#   ('Actl9', 10),
#   ('Actn1', 10),
#   ('Actn2', 10),
#   ('Actn3', 10),
#   ('Actn4', 10),
#   ('Actr10', 10),
#   ('Actr1a', 10),
#   ('Actr1b', 10),
#   ('Actr2', 10),
#   ('Actr3', 10),
#   ('Actr3b', 10),
#   ('Actr5', 10),
#   ('Actr6', 10),
#   ('Actr8', 10),
#   ('Actrt1', 10),
#   ('Actrt2', 10),
#   ('Acvr1', 10),
#   ('Acvr1b', 10),
#   ('Acvr1c', 10),
#   ('Acvr2a', 10),
#   ('Acvr2b', 10),
#   ('Acvrl1', 10),
#   ('Acy1', 10),
#   ('Acy3', 10),
#   ('Acyp1', 10),
#   ('Acyp2', 10),
#   ('Ada', 10),
#   ('Adad1', 10),
#   ('Adad2', 10),
#   ('Adal', 10),
#   ('Adam10', 10),
#   ('Adam11', 10),
#   ('Adam12', 10),
#   ('Adam15', 10),
#   ('Adam17', 10),
#   ('Adam18', 10),
#   ('Adam19', 10),
#   ('Adam1a', 8),
#   ('Adam1b', 5),
#   ('Adam2', 10),
#   ('Adam21', 10),
#   ('Adam22', 10),
#   ('Adam23', 10),
#   ('Adam24', 3),
#   ('Adam25', 2),
#   ('Adam26a', 2),
#   ('Adam26b', 2),
#   ('Adam28', 10),
#   ('Adam29', 10),
#   ('Adam3', 4),
#   ('Adam30', 10),
#   ('Adam32', 10),
#   ('Adam33', 10),
#   ('Adam34', 2),
#   ('Adam4', 3),
#   ('Adam5', 10),
#   ('Adam6a', 2),
#   ('Adam7', 10),
#   ('Adam8', 10),
#   ('Adam9', 10),
#   ('Adamdec1', 10),
#   ('Adamts1', 10),
#   ('Adamts10', 10),
#   ('Adamts12', 10),
#   ('Adamts13', 10),
#   ('Adamts14', 10),
#   ('Adamts15', 10),
#   ('Adamts16', 10),
#   ('Adamts17', 10),
#   ('Adamts18', 10),
#   ('Adamts19', 10),
#   ('Adamts2', 10),
#   ('Adamts20', 10),
#   ('Adamts3', 10),
#   ('Adamts4', 10),
#   ('Adamts5', 10),
#   ('Adamts6', 10),
#   ('Adamts7', 10),
#   ('Adamts8', 10),
#   ('Adamts9', 10),
#   ('Adamtsl1', 10),
#   ('Adamtsl2', 10),
#   ('Adamtsl3', 10),
#   ('Adamtsl4', 10),
#   ('Adamtsl5', 10),
#   ('Adap1', 10),
#   ('Adap2', 10),
#   ('Adar', 10),
#   ('Adar3', 3),
#   ('Adarb1', 10),
#   ('Adarb2', 10),
#   ('Adat1', 10),
#   ('Adat2', 10),
#   ('Adat3', 10),
#   ('Adc', 10),
#   ('Adck1', 10),
#   ('Adck2', 10),
#   ('Adck3', 10),
#   ('Adck4', 10),
#   ('Adck5', 10),
#   ('Adcy1', 10),
#   ('Adcy10', 10),
#   ('Adcy2', 10),
#   ('Adcy3', 10),
#   ('Adcy4', 10),
#   ('Adcy5', 10),
#   ('Adcy6', 10),
#   ('Adcy7', 10),
#   ('Adcy8', 10),
#   ('Adcy9', 10),
#   ('Adcyap1', 10),
#   ('Adcyap1r1', 10),
#   ('Add1', 10),
#   ('Add2', 10),
#   ('Add3', 10),
#   ('Adh1', 10),
#   ('Adh4', 10),
#   ('Adh5', 10),
#   ('Adh6-ps1', 2),
#   ('Adh6a', 2),
#   ('Adh7', 10),
#   ('Adhfe1', 10),
#   ('Adi1', 10),
#   ('Adig', 10),
#   ('Adipoq', 10),
#   ('Adipor1', 10),
#   ('Adipor2', 10),
#   ('Adk', 10),
#   ('Adm', 10),
#   ('Adm2', 10),
#   ('Adnp', 10),
#   ('Adnp2', 10),
#   ('Ado', 10),
#   ('Adora1', 10),
#   ('Adora2a', 10),
#   ('Adora2b', 10),
#   ('Adora3', 10),
#   ('Adpgk', 10),
#   ('Adprh', 10),
#   ('Adprhl1', 10),
#   ('Adprhl2', 10),
#   ('Adprt3', 4),
#   ('Adra1a', 10),
#   ('Adra1b', 10),
#   ('Adra1d', 10),
#   ('Adra2a', 10),
#   ('Adra2b', 10),
#   ('Adra2c', 10),
#   ('Adrb1', 10),
#   ('Adrb2', 10),
#   ('Adrb3', 10),
#   ('Adrbk1', 10),
#   ('Adrbk2', 10),
#   ('Adrm1', 10),
#   ('Adsl', 10),
#   ('Adss', 10),
#   ('Adssl1', 10),
#   ('Aebp1', 10),
#   ('Aebp2', 10),
#   ('Aen', 10),
#   ('Aes', 10),
#   ('Afap1', 10),
#   ('Afap1l1', 10),
#   ('Afap1l2', 10),
#   ('Aff1', 10),
#   ('Aff2', 10),
#   ('Aff3', 10),
#   ('Aff4', 10),
#   ('Afg3l1', 7),
#   ('Afg3l2', 10),
#   ('Afm', 10),
#   ('Afmid', 10),
#   ('Afp', 10),
#   ('Aftph', 10),
#   ('Aga', 10),
#   ('Agap1', 10),
#   ('Agap2', 10),
#   ('Agap3', 10),
#   ('Agbl1', 10),
#   ('Agbl2', 10),
#   ('Agbl3', 10),
#   ('Agbl4', 10),
#   ('Agbl5', 10),
#   ('Ager', 10),
#   ('Agfg1', 10),
#   ('Agfg2', 10),
#   ('Aggf1', 10),
#   ('Agk', 10),
#   ('Agl', 10),
#   ('Agmat', 10),
#   ('Agpat1', 10),
#   ('Agpat2', 10),
#   ('Agpat3', 10),
#   ('Agpat4', 10),
#   ('Agpat5', 10),
#   ('Agpat6', 10),
#   ('Agpat9', 10),
#   ('Agphd1', 10),
#   ('Agps', 10),
#   ('Agr2', 10),
#   ('Agr3', 10),
#   ('Agrn', 10),
#   ('Agrp', 10),
#   ('Agt', 10),
#   ('Agtpbp1', 10),
#   ('Agtr1a', 4),
#   ('Agtr1b', 9),
#   ('Agtr2', 10),
#   ('Agtrap', 10),
#   ('Agxt', 10),
#   ('Agxt2', 10),
#   ('Agxt2l1', 10),
#   ('Agxt2l2', 10),
#   ('Ahctf1', 10),
#   ('Ahcy', 10),
#   ('Ahcyl1', 10),
#   ('Ahcyl2', 10),
#   ('Ahdc1', 10),
#   ('Ahi-1', 6),
#   ('Ahi1', 10),
#   ('Ahnak', 10),
#   ('Ahnak2', 10),
#   ('Ahr', 10),
#   ('Ahrr', 10),
#   ('Ahsa1', 10),
#   ('Ahsa2', 10),
#   ('Ahsg', 10),
#   ('Aicda', 10),
#   ('Aida', 10),
#   ('Aif1', 10),
#   ('Aif1l', 10),
#   ('Aifm1', 10),
#   ('Aifm2', 10),
#   ('Aifm3', 10),
#   ('Aig1', 10),
#   ('Aim1', 10),
#   ('Aim1l', 10),
#   ('Aim2', 10),
#   ('Aimp1', 10),
#   ('Aimp2', 10),
#   ('Aip', 10),
#   ('Aipl1', 10),
#   ('Aire', 10),
#   ('Airn', 4),
#   ('Ajap1', 10),
#   ('Ak1', 10),
#   ('Ak2', 10),
#   ('Ak3', 10),
#   ('Ak4', 10),
#   ('Ak5', 10),
#   ('Ak7', 10),
#   ('Ak8', 10),
#   ('Akap1', 10),
#   ('Akap10', 10),
#   ('Akap11', 10),
#   ('Akap12', 10),
#   ('Akap13', 10),
#   ('Akap14', 10),
#   ('Akap17b', 5),
#   ('Akap2', 10),
#   ('Akap3', 10),
#   ('Akap4', 10),
#   ('Akap5', 10),
#   ('Akap6', 10),
#   ('Akap7', 10),
#   ('Akap8', 10),
#   ('Akap8l', 10),
#   ('Akap9', 10),
#   ('Akd2', 7),
#   ...],
#  'missing': ['100039707',
#   '100042579',
#   '100043387',
#   '1110020G09Rik',
#   '1110034A24Rik',
#   '1700045I19Rik',
#   '4831426I19Rik',
#   '5330429B09Rik',
#   '544988',
#   '547127',
#   '5830427D03Rik',
#   'A230073K19Rik',
#   'A630005I04Rik',
#   'A630036L10Rik',
#   'AA987161',
#   'AB013468',
#   'AB033515',
#   'AB033524',
#   'AB056442',
#   'AB099516',
#   'AB251060',
#   'AB251100',
#   'AB251138',
#   'AB251164',
#   'AB251181',
#   'AB251235',
#   'AB251236',
#   'AB335823',
#   'AB336517',
#   'AB336562',
#   'AB336647',
#   'AB336678',
#   'AB336697',
#   'AB336723',
#   'AB336785',
#   'AB336794',
#   'AB336801',
#   'AB336819',
#   'AB336885',
#   'AB336927',
#   'AB337358',
#   'AB337665',
#   'AB337734',
#   'AB338584',
#   'AB338586',
#   'AB338600',
#   'AB339176',
#   'AB339387',
#   'AB339827',
#   'AB339850',
#   'AB339928',
#   'AB339929',
#   'AB339931',
#   'AB340012',
#   'AB340047',
#   'AB340065',
#   'AB340534',
#   'AB340928',
#   'AB340940',
#   'AB340976',
#   'AB340990',
#   'AB341001',
#   'AB341018',
#   'AB341028',
#   'AB341074',
#   'AB341098',
#   'AB341100',
#   'AB341111',
#   'AB341135',
#   'AB341138',
#   'AB341166',
#   'AB341180',
#   'AB341191',
#   'AB341556',
#   'AB341580',
#   'AB341590',
#   'AB341597',
#   'AB341654',
#   'AB341946',
#   'AB341979',
#   'AB341994',
#   'AB341998',
#   'AB342013',
#   'AB342034',
#   'AB342727',
#   'AB342860',
#   'AB342872',
#   'AB342896',
#   'AB342953',
#   'AB343394',
#   'AB345949',
#   'AB345950',
#   'AB346227',
#   'AB347565',
#   'AB349192',
#   'AB349505',
#   'AB349556',
#   'AB349586',
#   'AB349695',
#   'AB349790',
#   'AB349855',
#   'AB349959',
#   'AB350188',
#   'AB350257',
#   'AB350538',
#   'AB350566',
#   'AB350908',
#   'AB350970',
#   'AB351078',
#   'AB351165',
#   'AB351921',
#   'AB352058',
#   'AB352175',
#   'AB352403',
#   'AB352479',
#   'AB352701',
#   'AB352881',
#   'AB352963',
#   'AB352980',
#   'AF032968',
#   'AF217545',
#   'AF251705',
#   'AF332090',
#   'AF357374',
#   'AF357376',
#   'AF365933',
#   'AF401983',
#   'AF479018',
#   'AI324046',
#   'AJ308964',
#   'AJ311366',
#   'AK002250',
#   'AK002390',
#   'AK002417',
#   'AK002663',
#   'AK002708',
#   'AK002723',
#   'AK002733',
#   'AK002748',
#   'AK002805',
#   'AK002838',
#   'AK002860',
#   'AK002866',
#   'AK002929',
#   'AK003103',
#   'AK003136',
#   'AK003327',
#   'AK003663',
#   'AK003793',
#   'AK003812',
#   'AK003943',
#   'AK004186',
#   'AK004221',
#   'AK004226',
#   'AK004252',
#   'AK004434',
#   'AK004585',
#   'AK004850',
#   'AK005115',
#   'AK005214',
#   'AK005305',
#   'AK005306',
#   'AK005363',
#   'AK005410',
#   'AK005414',
#   'AK005418',
#   'AK005477',
#   'AK005481',
#   'AK005503',
#   'AK005538',
#   'AK005539',
#   'AK005576',
#   'AK005578',
#   'AK005580',
#   'AK005589',
#   'AK005591',
#   'AK005608',
#   'AK005616',
#   'AK005629',
#   'AK005634',
#   'AK005635',
#   'AK005641',
#   'AK005643',
#   'AK005649',
#   'AK005651',
#   'AK005653',
#   'AK005657',
#   'AK005667',
#   'AK005677',
#   'AK005678',
#   'AK005686',
#   'AK005707',
#   'AK005712',
#   'AK005722',
#   'AK005744',
#   'AK005754',
#   'AK005780',
#   'AK005792',
#   'AK005793',
#   'AK005807',
#   'AK005828',
#   'AK005833',
#   'AK005834',
#   'AK005838',
#   'AK005839',
#   'AK005849',
#   'AK005856',
#   'AK005895',
#   'AK005897',
#   'AK005905',
#   'AK005912',
#   'AK005951',
#   'AK005956',
#   'AK005958',
#   'AK005967',
#   'AK005987',
#   'AK006001',
#   'AK006015',
#   'AK006022',
#   'AK006024',
#   'AK006029',
#   'AK006031',
#   'AK006037',
#   'AK006039',
#   'AK006045',
#   'AK006051',
#   'AK006052',
#   'AK006070',
#   'AK006071',
#   'AK006087',
#   'AK006108',
#   'AK006114',
#   'AK006119',
#   'AK006121',
#   'AK006131',
#   'AK006138',
#   'AK006139',
#   'AK006160',
#   'AK006167',
#   'AK006173',
#   'AK006186',
#   'AK006189',
#   'AK006202',
#   'AK006231',
#   'AK006239',
#   'AK006240',
#   'AK006245',
#   'AK006250',
#   'AK006264',
#   'AK006272',
#   'AK006282',
#   'AK006293',
#   'AK006304',
#   'AK006308',
#   'AK006310',
#   'AK006321',
#   'AK006331',
#   'AK006334',
#   'AK006343',
#   'AK006348',
#   'AK006355',
#   'AK006359',
#   'AK006362',
#   'AK006380',
#   'AK006389',
#   'AK006397',
#   'AK006409',
#   'AK006412',
#   'AK006413',
#   'AK006426',
#   'AK006434',
#   'AK006451',
#   'AK006454',
#   'AK006455',
#   'AK006457',
#   'AK006461',
#   'AK006470',
#   'AK006474',
#   'AK006485',
#   'AK006486',
#   'AK006507',
#   'AK006512',
#   'AK006531',
#   'AK006540',
#   'AK006560',
#   'AK006561',
#   'AK006563',
#   'AK006568',
#   'AK006570',
#   'AK006572',
#   'AK006576',
#   'AK006581',
#   'AK006587',
#   'AK006593',
#   'AK006607',
#   'AK006610',
#   'AK006623',
#   'AK006633',
#   'AK006637',
#   'AK006644',
#   'AK006651',
#   'AK006653',
#   'AK006659',
#   'AK006664',
#   'AK006677',
#   'AK006690',
#   'AK006701',
#   'AK006702',
#   'AK006706',
#   'AK006709',
#   'AK006712',
#   'AK006725',
#   'AK006730',
#   'AK006738',
#   'AK006748',
#   'AK006752',
#   'AK006766',
#   'AK006768',
#   'AK006812',
#   'AK006824',
#   'AK006844',
#   'AK006852',
#   'AK006859',
#   'AK006870',
#   'AK006884',
#   'AK006889',
#   'AK006894',
#   'AK006895',
#   'AK006896',
#   'AK006899',
#   'AK006909',
#   'AK006921',
#   'AK006930',
#   'AK006933',
#   'AK006934',
#   'AK006937',
#   'AK006942',
#   'AK006943',
#   'AK006947',
#   'AK006958',
#   'AK006961',
#   'AK006968',
#   'AK006971',
#   'AK006973',
#   'AK006980',
#   'AK006991',
#   'AK006996',
#   'AK006997',
#   'AK007006',
#   'AK007011',
#   'AK007025',
#   'AK007038',
#   'AK007041',
#   'AK007042',
#   'AK007067',
#   'AK007073',
#   'AK007082',
#   'AK007083',
#   'AK007084',
#   'AK007095',
#   'AK007100',
#   'AK007102',
#   'AK007110',
#   'AK007112',
#   'AK007116',
#   'AK007118',
#   'AK007137',
#   'AK007151',
#   'AK007154',
#   'AK007159',
#   'AK007162',
#   'AK007174',
#   'AK007185',
#   'AK007191',
#   'AK007204',
#   'AK007205',
#   'AK007210',
#   'AK007214',
#   'AK007216',
#   'AK007223',
#   'AK007237',
#   'AK007238',
#   'AK007249',
#   'AK007255',
#   'AK007260',
#   'AK007274',
#   'AK007280',
#   'AK007290',
#   'AK007305',
#   'AK007349',
#   'AK007376',
#   'AK007436',
#   'AK007459',
#   'AK007460',
#   'AK007531',
#   'AK007545',
#   'AK007571',
#   'AK007605',
#   'AK007719',
#   'AK007770',
#   'AK007818',
#   'AK007819',
#   'AK007836',
#   'AK007845',
#   'AK007854',
#   'AK007898',
#   'AK007899',
#   'AK007907',
#   'AK007947',
#   'AK007998',
#   'AK008044',
#   'AK008077',
#   'AK008166',
#   'AK008222',
#   'AK008288',
#   'AK008306',
#   'AK008334',
#   'AK008384',
#   'AK008417',
#   'AK008432',
#   'AK008482',
#   'AK008488',
#   'AK008491',
#   'AK008496',
#   'AK008545',
#   'AK008560',
#   'AK008572',
#   'AK008665',
#   'AK008705',
#   'AK008755',
#   'AK008767',
#   'AK008826',
#   'AK008833',
#   'AK008852',
#   'AK008857',
#   'AK008866',
#   'AK008921',
#   'AK008969',
#   'AK009064',
#   'AK009067',
#   'AK009121',
#   'AK009188',
#   'AK009335',
#   'AK009351',
#   'AK009383',
#   'AK009395',
#   'AK009597',
#   'AK009639',
#   'AK009699',
#   'AK009724',
#   'AK009784',
#   'AK009785',
#   'AK009813',
#   'AK009869',
#   'AK009977',
#   'AK010044',
#   'AK010122',
#   'AK010129',
#   'AK010245',
#   'AK010368',
#   'AK010390',
#   'AK010403',
#   'AK010638',
#   'AK010767',
#   'AK010770',
#   'AK010774',
#   'AK010793',
#   'AK010804',
#   'AK010824',
#   'AK010870',
#   'AK010894',
#   'AK010897',
#   'AK011205',
#   'AK011326',
#   'AK011408',
#   'AK011444',
#   'AK011460',
#   'AK011479',
#   'AK011482',
#   'AK011498',
#   'AK011568',
#   'AK011684',
#   'AK011877',
#   'AK011885',
#   'AK011897',
#   'AK011913',
#   'AK012007',
#   'AK012035',
#   'AK012142',
#   'AK012157',
#   'AK012214',
#   'AK012238',
#   'AK012325',
#   'AK012387',
#   'AK012506',
#   'AK012547',
#   'AK012595',
#   'AK012713',
#   'AK012841',
#   'AK012972',
#   'AK013046',
#   'AK013187',
#   'AK013290',
#   'AK013293',
#   'AK013372',
#   'AK013453',
#   'AK013480',
#   'AK013506',
#   'AK013593',
#   'AK013627',
#   'AK013668',
#   'AK013680',
#   'AK013712',
#   'AK013794',
#   'AK013876',
#   'AK013883',
#   'AK014028',
#   'AK014032',
#   'AK014089',
#   'AK014119',
#   'AK014147',
#   'AK014177',
#   'AK014209',
#   'AK014224',
#   'AK014273',
#   'AK014378',
#   'AK014435',
#   'AK014513',
#   'AK014660',
#   'AK014677',
#   'AK014683',
#   'AK014704',
#   'AK014726',
#   'AK014752',
#   'AK014786',
#   'AK014798',
#   'AK014841',
#   'AK014857',
#   'AK014882',
#   'AK014951',
#   'AK014957',
#   'AK014964',
#   'AK014969',
#   'AK014974',
#   'AK014986',
#   'AK014992',
#   'AK014999',
#   'AK015004',
#   'AK015045',
#   'AK015072',
#   'AK015092',
#   'AK015094',
#   'AK015096',
#   'AK015099',
#   'AK015105',
#   'AK015118',
#   'AK015174',
#   'AK015183',
#   'AK015188',
#   'AK015191',
#   'AK015200',
#   'AK015203',
#   'AK015219',
#   'AK015227',
#   'AK015236',
#   'AK015257',
#   'AK015277',
#   'AK015279',
#   'AK015284',
#   'AK015289',
#   'AK015316',
#   'AK015322',
#   'AK015324',
#   'AK015336',
#   'AK015341',
#   'AK015347',
#   'AK015360',
#   'AK015363',
#   'AK015373',
#   'AK015376',
#   'AK015378',
#   'AK015384',
#   'AK015392',
#   'AK015395',
#   'AK015404',
#   'AK015409',
#   'AK015413',
#   'AK015421',
#   'AK015423',
#   'AK015428',
#   'AK015444',
#   'AK015458',
#   'AK015459',
#   'AK015463',
#   'AK015470',
#   'AK015475',
#   'AK015482',
#   'AK015488',
#   'AK015492',
#   'AK015493',
#   'AK015518',
#   'AK015520',
#   'AK015526',
#   'AK015529',
#   'AK015544',
#   'AK015545',
#   'AK015552',
#   'AK015560',
#   'AK015562',
#   'AK015566',
#   'AK015581',
#   'AK015607',
#   'AK015608',
#   'AK015610',
#   'AK015657',
#   'AK015664',
#   'AK015665',
#   'AK015677',
#   'AK015682',
#   'AK015703',
#   'AK015712',
#   'AK015714',
#   'AK015741',
#   'AK015744',
#   'AK015749',
#   'AK015772',
#   'AK015773',
#   'AK015782',
#   'AK015813',
#   'AK015814',
#   'AK015818',
#   'AK015844',
#   'AK015855',
#   'AK015877',
#   'AK015891',
#   'AK015892',
#   'AK015900',
#   'AK015914',
#   'AK015937',
#   'AK015940',
#   'AK015944',
#   'AK015950',
#   'AK015953',
#   'AK015956',
#   'AK015958',
#   'AK015969',
#   'AK016002',
#   'AK016007',
#   'AK016016',
#   'AK016027',
#   'AK016028',
#   'AK016032',
#   'AK016040',
#   'AK016046',
#   'AK016054',
#   'AK016061',
#   'AK016071',
#   'AK016077',
#   'AK016085',
#   'AK016097',
#   'AK016100',
#   'AK016107',
#   'AK016120',
#   'AK016126',
#   'AK016128',
#   'AK016129',
#   'AK016131',
#   'AK016150',
#   'AK016162',
#   'AK016163',
#   'AK016172',
#   'AK016177',
#   'AK016178',
#   'AK016179',
#   'AK016192',
#   'AK016207',
#   'AK016225',
#   'AK016243',
#   'AK016244',
#   'AK016251',
#   'AK016265',
#   'AK016276',
#   'AK016280',
#   'AK016281',
#   'AK016283',
#   'AK016284',
#   'AK016307',
#   'AK016328',
#   'AK016335',
#   'AK016345',
#   'AK016361',
#   'AK016372',
#   'AK016377',
#   'AK016383',
#   'AK016388',
#   'AK016393',
#   'AK016399',
#   'AK016412',
#   'AK016413',
#   'AK016417',
#   'AK016427',
#   'AK016444',
#   'AK016486',
#   'AK016496',
#   'AK016511',
#   'AK016521',
#   'AK016549',
#   'AK016591',
#   'AK016594',
#   'AK016605',
#   'AK016650',
#   'AK016658',
#   'AK016661',
#   'AK016682',
#   'AK016696',
#   'AK016731',
#   'AK016734',
#   'AK016752',
#   'AK016772',
#   'AK016788',
#   'AK016790',
#   'AK016808',
#   'AK016813',
#   'AK016836',
#   'AK016837',
#   'AK016841',
#   'AK016887',
#   'AK016893',
#   'AK016898',
#   'AK016914',
#   'AK016926',
#   'AK016948',
#   'AK016961',
#   'AK017006',
#   'AK017010',
#   'AK017025',
#   'AK017040',
#   'AK017048',
#   'AK017068',
#   'AK017086',
#   'AK017092',
#   'AK017104',
#   'AK017106',
#   'AK017111',
#   'AK017125',
#   'AK017137',
#   'AK017143',
#   'AK017148',
#   'AK017177',
#   'AK017199',
#   'AK017220',
#   'AK017239',
#   'AK017243',
#   'AK017296',
#   'AK017306',
#   'AK017331',
#   'AK017337',
#   'AK017339',
#   'AK017349',
#   'AK017368',
#   'AK017404',
#   'AK017409',
#   'AK017430',
#   'AK017500',
#   'AK017534',
#   'AK017586',
#   'AK017620',
#   'AK017645',
#   'AK017706',
#   'AK017779',
#   'AK017883',
#   'AK017891',
#   'AK017893',
#   'AK017924',
#   'AK018014',
#   'AK018074',
#   'AK018134',
#   'AK018156',
#   'AK018214',
#   'AK018302',
#   'AK018309',
#   'AK018352',
#   'AK018376',
#   'AK018427',
#   'AK018450',
#   'AK018484',
#   'AK018490',
#   'AK018513',
#   'AK018584',
#   'AK018624',
#   'AK018679',
#   'AK018699',
#   'AK018753',
#   'AK018772',
#   'AK018841',
#   'AK018847',
#   'AK018858',
#   'AK018866',
#   'AK018879',
#   'AK018891',
#   'AK018902',
#   'AK018905',
#   'AK018911',
#   'AK018913',
#   'AK018918',
#   'AK018924',
#   'AK018929',
#   'AK018937',
#   'AK018940',
#   'AK018946',
#   'AK018948',
#   'AK018959',
#   'AK018965',
#   'AK018967',
#   'AK018968',
#   'AK018972',
#   'AK018976',
#   'AK018977',
#   'AK018984',
#   'AK018988',
#   'AK018990',
#   'AK018991',
#   'AK018996',
#   'AK019031',
#   'AK019036',
#   'AK019053',
#   'AK019057',
#   'AK019067',
#   'AK019082',
#   'AK019114',
#   'AK019124',
#   'AK019125',
#   'AK019137',
#   'AK019237',
#   'AK019250',
#   'AK019262',
#   'AK019290',
#   'AK019365',
#   'AK019366',
#   'AK019375',
#   'AK019420',
#   'AK019455',
#   'AK019514',
#   'AK019541',
#   'AK019561',
#   'AK019563',
#   'AK019573',
#   'AK019585',
#   'AK019592',
#   'AK019593',
#   'AK019596',
#   'AK019598',
#   'AK019601',
#   'AK019604',
#   'AK019614',
#   'AK019620',
#   'AK019623',
#   'AK019626',
#   'AK019628',
#   'AK019630',
#   'AK019631',
#   'AK019641',
#   'AK019643',
#   'AK019657',
#   'AK019662',
#   'AK019667',
#   'AK019672',
#   'AK019679',
#   'AK019680',
#   'AK019688',
#   'AK019690',
#   'AK019691',
#   'AK019697',
#   'AK019699',
#   'AK019701',
#   'AK019704',
#   'AK019709',
#   'AK019710',
#   'AK019711',
#   'AK019719',
#   'AK019722',
#   'AK019723',
#   'AK019729',
#   'AK019730',
#   'AK019731',
#   'AK019737',
#   'AK019738',
#   'AK019743',
#   'AK019745',
#   'AK019751',
#   'AK019757',
#   'AK019772',
#   'AK019773',
#   'AK019774',
#   'AK019781',
#   'AK019785',
#   'AK019789',
#   'AK019790',
#   'AK019792',
#   'AK019796',
#   'AK019797',
#   'AK019798',
#   'AK019801',
#   'AK019804',
#   'AK019810',
#   'AK019812',
#   'AK019818',
#   'AK019836',
#   'AK019838',
#   'AK019844',
#   'AK019889',
#   'AK019949',
#   'AK019984',
#   'AK020043',
#   'AK020054',
#   'AK020061',
#   'AK020087',
#   'AK020095',
#   'AK020100',
#   'AK020101',
#   'AK020188',
#   'AK020190',
#   'AK020205',
#   'AK020235',
#   'AK020236',
#   'AK020256',
#   'AK020309',
#   'AK020320',
#   'AK020351',
#   'AK020388',
#   'AK020398',
#   'AK020406',
#   'AK020476',
#   'AK020496',
#   'AK020506',
#   'AK020517',
#   'AK020549',
#   'AK020556',
#   'AK020565',
#   'AK020577',
#   'AK020588',
#   'AK020619',
#   'AK020645',
#   'AK020680',
#   'AK020705',
#   'AK020722',
#   'AK020728',
#   'AK020764',
#   'AK020767',
#   'AK020768',
#   'AK020793',
#   'AK020795',
#   'AK020829',
#   'AK020834',
#   'AK020854',
#   'AK020861',
#   'AK020867',
#   'AK020885',
#   'AK020898',
#   'AK020914',
#   'AK020930',
#   'AK020948',
#   'AK020962',
#   'AK021003',
#   'AK021004',
#   'AK021007',
#   'AK021048',
#   'AK021075',
#   'AK021093',
#   'AK021127',
#   'AK021128',
#   'AK021178',
#   'AK021191',
#   'AK021192',
#   'AK021197',
#   'AK021198',
#   'AK021199',
#   'AK021218',
#   'AK021232',
#   'AK021262',
#   'AK021280',
#   'AK021299',
#   'AK021307',
#   'AK021325',
#   'AK021342',
#   'AK021368',
#   'AK021371',
#   'AK021377',
#   'AK027935',
#   'AK027957',
#   'AK027968',
#   'AK027991',
#   'AK028005',
#   'AK028012',
#   'AK028033',
#   'AK028088',
#   'AK028089',
#   'AK028094',
#   'AK028111',
#   'AK028130',
#   ...],
#  'out':                 HGNC                 _id     _score notfound  \
#  query
#  0610007C21Rik    NaN              381629   7.942669      NaN
#  0610007L01Rik    NaN               71667   8.726240      NaN
#  0610007P08Rik    NaN               76251   7.938171      NaN
#  0610007P14Rik    NaN           100312958   8.724561      NaN
#  0610007P14Rik    NaN               58520   8.380354      NaN
#  0610007P22Rik    NaN               68327   8.736149      NaN
#  0610008F07Rik    NaN               68314  19.157450      NaN
#  0610009B22Rik    NaN               66050  90.778960      NaN
#  0610009B22Rik    NaN  ENSDORG00000009343  69.746620      NaN
#  0610009D07Rik    NaN               66055   9.082966      NaN
#  0610009O20Rik    NaN               66839  87.290215      NaN
#  0610009O20Rik    NaN  ENSDORG00000010853  69.801476      NaN
#  0610010B08Rik    NaN           100039060  95.660540      NaN
#  0610010F05Rik    NaN               71675  90.721970      NaN
#  0610010F05Rik    NaN  ENSDORG00000011221  69.831180      NaN
#  0610010K06Rik    NaN               71678  18.139143      NaN
#  0610010K14Rik    NaN              104457  87.460170      NaN
#  0610010O12Rik    NaN               66060  17.461496      NaN
#  0610011F06Rik    NaN               68347  17.454214      NaN
#  0610011L14Rik    NaN               68295  18.139143      NaN
#  0610012G03Rik    NaN  ENSMUSG00000107002  90.818180      NaN
#  0610012G03Rik    NaN              106264  90.654884      NaN
#  0610012H03Rik    NaN               74088  17.498302      NaN
#  0610030E20Rik    NaN               68364  90.935290      NaN
#  0610031J06Rik    NaN              295231   8.549832      NaN
#  0610031J06Rik    NaN               56700   8.083477      NaN
#  0610037D15Rik    NaN               68394  11.342739      NaN
#  0610037L13Rik    NaN               74098  90.683280      NaN
#  0610037L13Rik    NaN  ENSDORG00000015653  67.301170      NaN
#  0610037P05Rik    NaN               66086  18.187057      NaN
#  ...              ...                 ...        ...      ...
#  wdr4           12756               10785  73.242430      NaN
#  wdr4             NaN               57773  66.465580      NaN
#  wdr4             NaN           104379879  54.892190      NaN
#  wdr4             NaN           104636611  54.892190      NaN
#  wdr4             NaN           106904186  54.892190      NaN
#  wdr4             NaN           105305385  54.892190      NaN
#  wdr4             NaN           109454750  54.892190      NaN
#  wdr4             NaN           104678003  54.892190      NaN
#  wdr4             NaN           101034519  54.892190      NaN
#  wdr4             NaN           109256933  54.892190      NaN
#  wiz            30917               58525  88.448020      NaN
#  wiz              NaN               22404  65.379524      NaN
#  wiz              NaN           101473641  59.805965      NaN
#  wiz              NaN           104378614  59.805965      NaN
#  wiz              NaN           101546747  59.805965      NaN
#  wiz              NaN           104661019  59.805965      NaN
#  wiz              NaN           103234073  59.805965      NaN
#  wiz              NaN              455796  59.805965      NaN
#  wiz              NaN           101276538  59.805965      NaN
#  wiz              NaN           101323166  59.805965      NaN
#  zap              NaN           100415778  13.429382      NaN
#  zap              NaN               56531   9.068720      NaN
#  zap              NaN              252832   8.247991      NaN
#  zap              NaN               22637   7.637394      NaN
#  zap              NaN              299199   7.391710      NaN
#  zap              NaN               78781   7.183096      NaN
#  zap            23721               56829   6.973300      NaN
#  zap            12858                7535   5.811084      NaN
#  zap              NaN            18105814   4.663246      NaN
#  zap              NaN           100910302   3.786170      NaN
#
#                            symbol
#  query
#  0610007C21Rik             Atraid
#  0610007L01Rik            Tmem248
#  0610007P08Rik            Ercc6l2
#  0610007P14Rik              ERG28
#  0610007P14Rik              Erg28
#  0610007P22Rik               Tsr3
#  0610008F07Rik            Hnf4aos
#  0610009B22Rik      0610009B22Rik
#  0610009B22Rik      0610009B22Rik
#  0610009D07Rik              Sf3b6
#  0610009O20Rik      0610009O20Rik
#  0610009O20Rik      0610009O20Rik
#  0610010B08Rik      0610010B08Rik
#  0610010F05Rik      0610010F05Rik
#  0610010F05Rik      0610010F05Rik
#  0610010K06Rik               Brox
#  0610010K14Rik      0610010K14Rik
#  0610010O12Rik             Cystm1
#  0610011F06Rik            Mettl26
#  0610011L14Rik               Aar2
#  0610012G03Rik      0610012G03Rik
#  0610012G03Rik      0610012G03Rik
#  0610012H03Rik              Them7
#  0610030E20Rik      0610030E20Rik
#  0610031J06Rik               Glmp
#  0610031J06Rik               Glmp
#  0610037D15Rik            Ccdc163
#  0610037L13Rik      0610037L13Rik
#  0610037L13Rik      0610037L13Rik
#  0610037P05Rik              Fopnl
#  ...                          ...
#  wdr4                        WDR4
#  wdr4                        Wdr4
#  wdr4                        WDR4
#  wdr4                        WDR4
#  wdr4                        wdr4
#  wdr4                        WDR4
#  wdr4                        WDR4
#  wdr4                        WDR4
#  wdr4                        WDR4
#  wdr4                        WDR4
#  wiz                          WIZ
#  wiz                          Wiz
#  wiz                          wiz
#  wiz                          WIZ
#  wiz                          WIZ
#  wiz                          WIZ
#  wiz                          WIZ
#  wiz                          WIZ
#  wiz                          WIZ
#  wiz                          WIZ
#  zap                      ZC3HAV1
#  zap                        Ylpm1
#  zap                      Zc3hav1
#  zap                        Zap70
#  zap                        Ylpm1
#  zap                      Zc3hav1
#  zap                      ZC3HAV1
#  zap                        ZAP70
#  zap            POPTR_0015s07580g
#  zap                 LOC100910302
#
#  [179828 rows x 5 columns]}

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df
# Out:
#                 HGNC   symbol
# 14-3-3         12854    YWHAQ
# gamma          24844  DNAJC5G
# 2310061C15Rik  24447     CMC2
# 2b4            18171    CD244
# 4930578C19Rik  25866  CXorf36
# 4F2            11026   SLC3A2
# 53BP1          11999  TP53BP1
# 6330578E17Rik  33848     COA5
# 6D             13348     LY6D
# A1bg               5     A1BG
# A1cf           24086     A1CF
# A2ld1          25100    GGACT
# A2m                7      A2M
# A3galt2        30005  A3GALT2
# A4galt         18149   A4GALT
# A4gnt          17968    A4GNT
# AASDH          23993    AASDH
# ABCR              34    ABCA4
# ABLIM2         19195   ABLIM2
# ACRP           11216    SPAG7
# ADAM22           201   ADAM22
# ADD1             243     ADD1
# AKAP95           378    AKAP8
# APG16L         21498  ATG16L1
# APMAP          13238    APMAP
# ASK2            6858   MAP3K6
# AZ2             8096     OAZ2
# Aaas           13666     AAAS
# Aacs           21298     AACS
# Aadac             17    AADAC
# ...              ...      ...
# rp9            10288      RP9
# rsk3           10431  RPS6KA2
# s11-6          36693  RPS11P6
# scmh1          19003    SCMH1
# sco-spondin    21998     SSPO
# sgigsf          5951    CADM1
# slc18a2        10935  SLC18A2
# slc26a6        14472  SLC26A6
# slc43a2        23087  SLC43A2
# slp1           15584    SYTL1
# smoc2          20323    SMOC2
# svct2          10973  SLC23A2
# syt            11340     SS18
# sytXIV         23143    SYT14
# tagL           30013  PGLYRP2
# ten-m1          8117    TENM1
# ten-m2         29943    TENM2
# ten-m3         29944    TENM3
# ten-m4         29945    TENM4
# trp3           12335    TRPC3
# tspan-3        17752   TSPAN3
# tubg1          12417    TUBG1
# ubin            1237   UBQLN4
# variable       12667      VCX
# of             20473    BRIP1
# f...           11252    SPON1
# vesl-2         17513   HOMER2
# wdr4           12756     WDR4
# wiz            30917      WIZ
# zap            23721  ZC3HAV1
#
# [16008 rows x 2 columns]

# %%
len(df[df.index != df.symbol])
# Out:
# 15950

# %%
missing
# Out:
# ['100039707',
#  '100042579',
#  '100043387',
#  '1110020G09Rik',
#  '1110034A24Rik',
#  '1700045I19Rik',
#  '4831426I19Rik',
#  '5330429B09Rik',
#  '544988',
#  '547127',
#  '5830427D03Rik',
#  'A230073K19Rik',
#  'A630005I04Rik',
#  'A630036L10Rik',
#  'AA987161',
#  'AB013468',
#  'AB033515',
#  'AB033524',
#  'AB056442',
#  'AB099516',
#  'AB251060',
#  'AB251100',
#  'AB251138',
#  'AB251164',
#  'AB251181',
#  'AB251235',
#  'AB251236',
#  'AB335823',
#  'AB336517',
#  'AB336562',
#  'AB336647',
#  'AB336678',
#  'AB336697',
#  'AB336723',
#  'AB336785',
#  'AB336794',
#  'AB336801',
#  'AB336819',
#  'AB336885',
#  'AB336927',
#  'AB337358',
#  'AB337665',
#  'AB337734',
#  'AB338584',
#  'AB338586',
#  'AB338600',
#  'AB339176',
#  'AB339387',
#  'AB339827',
#  'AB339850',
#  'AB339928',
#  'AB339929',
#  'AB339931',
#  'AB340012',
#  'AB340047',
#  'AB340065',
#  'AB340534',
#  'AB340928',
#  'AB340940',
#  'AB340976',
#  'AB340990',
#  'AB341001',
#  'AB341018',
#  'AB341028',
#  'AB341074',
#  'AB341098',
#  'AB341100',
#  'AB341111',
#  'AB341135',
#  'AB341138',
#  'AB341166',
#  'AB341180',
#  'AB341191',
#  'AB341556',
#  'AB341580',
#  'AB341590',
#  'AB341597',
#  'AB341654',
#  'AB341946',
#  'AB341979',
#  'AB341994',
#  'AB341998',
#  'AB342013',
#  'AB342034',
#  'AB342727',
#  'AB342860',
#  'AB342872',
#  'AB342896',
#  'AB342953',
#  'AB343394',
#  'AB345949',
#  'AB345950',
#  'AB346227',
#  'AB347565',
#  'AB349192',
#  'AB349505',
#  'AB349556',
#  'AB349586',
#  'AB349695',
#  'AB349790',
#  'AB349855',
#  'AB349959',
#  'AB350188',
#  'AB350257',
#  'AB350538',
#  'AB350566',
#  'AB350908',
#  'AB350970',
#  'AB351078',
#  'AB351165',
#  'AB351921',
#  'AB352058',
#  'AB352175',
#  'AB352403',
#  'AB352479',
#  'AB352701',
#  'AB352881',
#  'AB352963',
#  'AB352980',
#  'AF032968',
#  'AF217545',
#  'AF251705',
#  'AF332090',
#  'AF357374',
#  'AF357376',
#  'AF365933',
#  'AF401983',
#  'AF479018',
#  'AI324046',
#  'AJ308964',
#  'AJ311366',
#  'AK002250',
#  'AK002390',
#  'AK002417',
#  'AK002663',
#  'AK002708',
#  'AK002723',
#  'AK002733',
#  'AK002748',
#  'AK002805',
#  'AK002838',
#  'AK002860',
#  'AK002866',
#  'AK002929',
#  'AK003103',
#  'AK003136',
#  'AK003327',
#  'AK003663',
#  'AK003793',
#  'AK003812',
#  'AK003943',
#  'AK004186',
#  'AK004221',
#  'AK004226',
#  'AK004252',
#  'AK004434',
#  'AK004585',
#  'AK004850',
#  'AK005115',
#  'AK005214',
#  'AK005305',
#  'AK005306',
#  'AK005363',
#  'AK005410',
#  'AK005414',
#  'AK005418',
#  'AK005477',
#  'AK005481',
#  'AK005503',
#  'AK005538',
#  'AK005539',
#  'AK005576',
#  'AK005578',
#  'AK005580',
#  'AK005589',
#  'AK005591',
#  'AK005608',
#  'AK005616',
#  'AK005629',
#  'AK005634',
#  'AK005635',
#  'AK005641',
#  'AK005643',
#  'AK005649',
#  'AK005651',
#  'AK005653',
#  'AK005657',
#  'AK005667',
#  'AK005677',
#  'AK005678',
#  'AK005686',
#  'AK005707',
#  'AK005712',
#  'AK005722',
#  'AK005744',
#  'AK005754',
#  'AK005780',
#  'AK005792',
#  'AK005793',
#  'AK005807',
#  'AK005828',
#  'AK005833',
#  'AK005834',
#  'AK005838',
#  'AK005839',
#  'AK005849',
#  'AK005856',
#  'AK005895',
#  'AK005897',
#  'AK005905',
#  'AK005912',
#  'AK005951',
#  'AK005956',
#  'AK005958',
#  'AK005967',
#  'AK005987',
#  'AK006001',
#  'AK006015',
#  'AK006022',
#  'AK006024',
#  'AK006029',
#  'AK006031',
#  'AK006037',
#  'AK006039',
#  'AK006045',
#  'AK006051',
#  'AK006052',
#  'AK006070',
#  'AK006071',
#  'AK006087',
#  'AK006108',
#  'AK006114',
#  'AK006119',
#  'AK006121',
#  'AK006131',
#  'AK006138',
#  'AK006139',
#  'AK006160',
#  'AK006167',
#  'AK006173',
#  'AK006186',
#  'AK006189',
#  'AK006202',
#  'AK006231',
#  'AK006239',
#  'AK006240',
#  'AK006245',
#  'AK006250',
#  'AK006264',
#  'AK006272',
#  'AK006282',
#  'AK006293',
#  'AK006304',
#  'AK006308',
#  'AK006310',
#  'AK006321',
#  'AK006331',
#  'AK006334',
#  'AK006343',
#  'AK006348',
#  'AK006355',
#  'AK006359',
#  'AK006362',
#  'AK006380',
#  'AK006389',
#  'AK006397',
#  'AK006409',
#  'AK006412',
#  'AK006413',
#  'AK006426',
#  'AK006434',
#  'AK006451',
#  'AK006454',
#  'AK006455',
#  'AK006457',
#  'AK006461',
#  'AK006470',
#  'AK006474',
#  'AK006485',
#  'AK006486',
#  'AK006507',
#  'AK006512',
#  'AK006531',
#  'AK006540',
#  'AK006560',
#  'AK006561',
#  'AK006563',
#  'AK006568',
#  'AK006570',
#  'AK006572',
#  'AK006576',
#  'AK006581',
#  'AK006587',
#  'AK006593',
#  'AK006607',
#  'AK006610',
#  'AK006623',
#  'AK006633',
#  'AK006637',
#  'AK006644',
#  'AK006651',
#  'AK006653',
#  'AK006659',
#  'AK006664',
#  'AK006677',
#  'AK006690',
#  'AK006701',
#  'AK006702',
#  'AK006706',
#  'AK006709',
#  'AK006712',
#  'AK006725',
#  'AK006730',
#  'AK006738',
#  'AK006748',
#  'AK006752',
#  'AK006766',
#  'AK006768',
#  'AK006812',
#  'AK006824',
#  'AK006844',
#  'AK006852',
#  'AK006859',
#  'AK006870',
#  'AK006884',
#  'AK006889',
#  'AK006894',
#  'AK006895',
#  'AK006896',
#  'AK006899',
#  'AK006909',
#  'AK006921',
#  'AK006930',
#  'AK006933',
#  'AK006934',
#  'AK006937',
#  'AK006942',
#  'AK006943',
#  'AK006947',
#  'AK006958',
#  'AK006961',
#  'AK006968',
#  'AK006971',
#  'AK006973',
#  'AK006980',
#  'AK006991',
#  'AK006996',
#  'AK006997',
#  'AK007006',
#  'AK007011',
#  'AK007025',
#  'AK007038',
#  'AK007041',
#  'AK007042',
#  'AK007067',
#  'AK007073',
#  'AK007082',
#  'AK007083',
#  'AK007084',
#  'AK007095',
#  'AK007100',
#  'AK007102',
#  'AK007110',
#  'AK007112',
#  'AK007116',
#  'AK007118',
#  'AK007137',
#  'AK007151',
#  'AK007154',
#  'AK007159',
#  'AK007162',
#  'AK007174',
#  'AK007185',
#  'AK007191',
#  'AK007204',
#  'AK007205',
#  'AK007210',
#  'AK007214',
#  'AK007216',
#  'AK007223',
#  'AK007237',
#  'AK007238',
#  'AK007249',
#  'AK007255',
#  'AK007260',
#  'AK007274',
#  'AK007280',
#  'AK007290',
#  'AK007305',
#  'AK007349',
#  'AK007376',
#  'AK007436',
#  'AK007459',
#  'AK007460',
#  'AK007531',
#  'AK007545',
#  'AK007571',
#  'AK007605',
#  'AK007719',
#  'AK007770',
#  'AK007818',
#  'AK007819',
#  'AK007836',
#  'AK007845',
#  'AK007854',
#  'AK007898',
#  'AK007899',
#  'AK007907',
#  'AK007947',
#  'AK007998',
#  'AK008044',
#  'AK008077',
#  'AK008166',
#  'AK008222',
#  'AK008288',
#  'AK008306',
#  'AK008334',
#  'AK008384',
#  'AK008417',
#  'AK008432',
#  'AK008482',
#  'AK008488',
#  'AK008491',
#  'AK008496',
#  'AK008545',
#  'AK008560',
#  'AK008572',
#  'AK008665',
#  'AK008705',
#  'AK008755',
#  'AK008767',
#  'AK008826',
#  'AK008833',
#  'AK008852',
#  'AK008857',
#  'AK008866',
#  'AK008921',
#  'AK008969',
#  'AK009064',
#  'AK009067',
#  'AK009121',
#  'AK009188',
#  'AK009335',
#  'AK009351',
#  'AK009383',
#  'AK009395',
#  'AK009597',
#  'AK009639',
#  'AK009699',
#  'AK009724',
#  'AK009784',
#  'AK009785',
#  'AK009813',
#  'AK009869',
#  'AK009977',
#  'AK010044',
#  'AK010122',
#  'AK010129',
#  'AK010245',
#  'AK010368',
#  'AK010390',
#  'AK010403',
#  'AK010638',
#  'AK010767',
#  'AK010770',
#  'AK010774',
#  'AK010793',
#  'AK010804',
#  'AK010824',
#  'AK010870',
#  'AK010894',
#  'AK010897',
#  'AK011205',
#  'AK011326',
#  'AK011408',
#  'AK011444',
#  'AK011460',
#  'AK011479',
#  'AK011482',
#  'AK011498',
#  'AK011568',
#  'AK011684',
#  'AK011877',
#  'AK011885',
#  'AK011897',
#  'AK011913',
#  'AK012007',
#  'AK012035',
#  'AK012142',
#  'AK012157',
#  'AK012214',
#  'AK012238',
#  'AK012325',
#  'AK012387',
#  'AK012506',
#  'AK012547',
#  'AK012595',
#  'AK012713',
#  'AK012841',
#  'AK012972',
#  'AK013046',
#  'AK013187',
#  'AK013290',
#  'AK013293',
#  'AK013372',
#  'AK013453',
#  'AK013480',
#  'AK013506',
#  'AK013593',
#  'AK013627',
#  'AK013668',
#  'AK013680',
#  'AK013712',
#  'AK013794',
#  'AK013876',
#  'AK013883',
#  'AK014028',
#  'AK014032',
#  'AK014089',
#  'AK014119',
#  'AK014147',
#  'AK014177',
#  'AK014209',
#  'AK014224',
#  'AK014273',
#  'AK014378',
#  'AK014435',
#  'AK014513',
#  'AK014660',
#  'AK014677',
#  'AK014683',
#  'AK014704',
#  'AK014726',
#  'AK014752',
#  'AK014786',
#  'AK014798',
#  'AK014841',
#  'AK014857',
#  'AK014882',
#  'AK014951',
#  'AK014957',
#  'AK014964',
#  'AK014969',
#  'AK014974',
#  'AK014986',
#  'AK014992',
#  'AK014999',
#  'AK015004',
#  'AK015045',
#  'AK015072',
#  'AK015092',
#  'AK015094',
#  'AK015096',
#  'AK015099',
#  'AK015105',
#  'AK015118',
#  'AK015174',
#  'AK015183',
#  'AK015188',
#  'AK015191',
#  'AK015200',
#  'AK015203',
#  'AK015219',
#  'AK015227',
#  'AK015236',
#  'AK015257',
#  'AK015277',
#  'AK015279',
#  'AK015284',
#  'AK015289',
#  'AK015316',
#  'AK015322',
#  'AK015324',
#  'AK015336',
#  'AK015341',
#  'AK015347',
#  'AK015360',
#  'AK015363',
#  'AK015373',
#  'AK015376',
#  'AK015378',
#  'AK015384',
#  'AK015392',
#  'AK015395',
#  'AK015404',
#  'AK015409',
#  'AK015413',
#  'AK015421',
#  'AK015423',
#  'AK015428',
#  'AK015444',
#  'AK015458',
#  'AK015459',
#  'AK015463',
#  'AK015470',
#  'AK015475',
#  'AK015482',
#  'AK015488',
#  'AK015492',
#  'AK015493',
#  'AK015518',
#  'AK015520',
#  'AK015526',
#  'AK015529',
#  'AK015544',
#  'AK015545',
#  'AK015552',
#  'AK015560',
#  'AK015562',
#  'AK015566',
#  'AK015581',
#  'AK015607',
#  'AK015608',
#  'AK015610',
#  'AK015657',
#  'AK015664',
#  'AK015665',
#  'AK015677',
#  'AK015682',
#  'AK015703',
#  'AK015712',
#  'AK015714',
#  'AK015741',
#  'AK015744',
#  'AK015749',
#  'AK015772',
#  'AK015773',
#  'AK015782',
#  'AK015813',
#  'AK015814',
#  'AK015818',
#  'AK015844',
#  'AK015855',
#  'AK015877',
#  'AK015891',
#  'AK015892',
#  'AK015900',
#  'AK015914',
#  'AK015937',
#  'AK015940',
#  'AK015944',
#  'AK015950',
#  'AK015953',
#  'AK015956',
#  'AK015958',
#  'AK015969',
#  'AK016002',
#  'AK016007',
#  'AK016016',
#  'AK016027',
#  'AK016028',
#  'AK016032',
#  'AK016040',
#  'AK016046',
#  'AK016054',
#  'AK016061',
#  'AK016071',
#  'AK016077',
#  'AK016085',
#  'AK016097',
#  'AK016100',
#  'AK016107',
#  'AK016120',
#  'AK016126',
#  'AK016128',
#  'AK016129',
#  'AK016131',
#  'AK016150',
#  'AK016162',
#  'AK016163',
#  'AK016172',
#  'AK016177',
#  'AK016178',
#  'AK016179',
#  'AK016192',
#  'AK016207',
#  'AK016225',
#  'AK016243',
#  'AK016244',
#  'AK016251',
#  'AK016265',
#  'AK016276',
#  'AK016280',
#  'AK016281',
#  'AK016283',
#  'AK016284',
#  'AK016307',
#  'AK016328',
#  'AK016335',
#  'AK016345',
#  'AK016361',
#  'AK016372',
#  'AK016377',
#  'AK016383',
#  'AK016388',
#  'AK016393',
#  'AK016399',
#  'AK016412',
#  'AK016413',
#  'AK016417',
#  'AK016427',
#  'AK016444',
#  'AK016486',
#  'AK016496',
#  'AK016511',
#  'AK016521',
#  'AK016549',
#  'AK016591',
#  'AK016594',
#  'AK016605',
#  'AK016650',
#  'AK016658',
#  'AK016661',
#  'AK016682',
#  'AK016696',
#  'AK016731',
#  'AK016734',
#  'AK016752',
#  'AK016772',
#  'AK016788',
#  'AK016790',
#  'AK016808',
#  'AK016813',
#  'AK016836',
#  'AK016837',
#  'AK016841',
#  'AK016887',
#  'AK016893',
#  'AK016898',
#  'AK016914',
#  'AK016926',
#  'AK016948',
#  'AK016961',
#  'AK017006',
#  'AK017010',
#  'AK017025',
#  'AK017040',
#  'AK017048',
#  'AK017068',
#  'AK017086',
#  'AK017092',
#  'AK017104',
#  'AK017106',
#  'AK017111',
#  'AK017125',
#  'AK017137',
#  'AK017143',
#  'AK017148',
#  'AK017177',
#  'AK017199',
#  'AK017220',
#  'AK017239',
#  'AK017243',
#  'AK017296',
#  'AK017306',
#  'AK017331',
#  'AK017337',
#  'AK017339',
#  'AK017349',
#  'AK017368',
#  'AK017404',
#  'AK017409',
#  'AK017430',
#  'AK017500',
#  'AK017534',
#  'AK017586',
#  'AK017620',
#  'AK017645',
#  'AK017706',
#  'AK017779',
#  'AK017883',
#  'AK017891',
#  'AK017893',
#  'AK017924',
#  'AK018014',
#  'AK018074',
#  'AK018134',
#  'AK018156',
#  'AK018214',
#  'AK018302',
#  'AK018309',
#  'AK018352',
#  'AK018376',
#  'AK018427',
#  'AK018450',
#  'AK018484',
#  'AK018490',
#  'AK018513',
#  'AK018584',
#  'AK018624',
#  'AK018679',
#  'AK018699',
#  'AK018753',
#  'AK018772',
#  'AK018841',
#  'AK018847',
#  'AK018858',
#  'AK018866',
#  'AK018879',
#  'AK018891',
#  'AK018902',
#  'AK018905',
#  'AK018911',
#  'AK018913',
#  'AK018918',
#  'AK018924',
#  'AK018929',
#  'AK018937',
#  'AK018940',
#  'AK018946',
#  'AK018948',
#  'AK018959',
#  'AK018965',
#  'AK018967',
#  'AK018968',
#  'AK018972',
#  'AK018976',
#  'AK018977',
#  'AK018984',
#  'AK018988',
#  'AK018990',
#  'AK018991',
#  'AK018996',
#  'AK019031',
#  'AK019036',
#  'AK019053',
#  'AK019057',
#  'AK019067',
#  'AK019082',
#  'AK019114',
#  'AK019124',
#  'AK019125',
#  'AK019137',
#  'AK019237',
#  'AK019250',
#  'AK019262',
#  'AK019290',
#  'AK019365',
#  'AK019366',
#  'AK019375',
#  'AK019420',
#  'AK019455',
#  'AK019514',
#  'AK019541',
#  'AK019561',
#  'AK019563',
#  'AK019573',
#  'AK019585',
#  'AK019592',
#  'AK019593',
#  'AK019596',
#  'AK019598',
#  'AK019601',
#  'AK019604',
#  'AK019614',
#  'AK019620',
#  'AK019623',
#  'AK019626',
#  'AK019628',
#  'AK019630',
#  'AK019631',
#  'AK019641',
#  'AK019643',
#  'AK019657',
#  'AK019662',
#  'AK019667',
#  'AK019672',
#  'AK019679',
#  'AK019680',
#  'AK019688',
#  'AK019690',
#  'AK019691',
#  'AK019697',
#  'AK019699',
#  'AK019701',
#  'AK019704',
#  'AK019709',
#  'AK019710',
#  'AK019711',
#  'AK019719',
#  'AK019722',
#  'AK019723',
#  'AK019729',
#  'AK019730',
#  'AK019731',
#  'AK019737',
#  'AK019738',
#  'AK019743',
#  'AK019745',
#  'AK019751',
#  'AK019757',
#  'AK019772',
#  'AK019773',
#  'AK019774',
#  'AK019781',
#  'AK019785',
#  'AK019789',
#  'AK019790',
#  'AK019792',
#  'AK019796',
#  'AK019797',
#  'AK019798',
#  'AK019801',
#  'AK019804',
#  'AK019810',
#  'AK019812',
#  'AK019818',
#  'AK019836',
#  'AK019838',
#  'AK019844',
#  'AK019889',
#  'AK019949',
#  'AK019984',
#  'AK020043',
#  'AK020054',
#  'AK020061',
#  'AK020087',
#  'AK020095',
#  'AK020100',
#  'AK020101',
#  'AK020188',
#  'AK020190',
#  'AK020205',
#  'AK020235',
#  'AK020236',
#  'AK020256',
#  'AK020309',
#  'AK020320',
#  'AK020351',
#  'AK020388',
#  'AK020398',
#  'AK020406',
#  'AK020476',
#  'AK020496',
#  'AK020506',
#  'AK020517',
#  'AK020549',
#  'AK020556',
#  'AK020565',
#  'AK020577',
#  'AK020588',
#  'AK020619',
#  'AK020645',
#  'AK020680',
#  'AK020705',
#  'AK020722',
#  'AK020728',
#  'AK020764',
#  'AK020767',
#  'AK020768',
#  'AK020793',
#  'AK020795',
#  'AK020829',
#  'AK020834',
#  'AK020854',
#  'AK020861',
#  'AK020867',
#  'AK020885',
#  'AK020898',
#  'AK020914',
#  'AK020930',
#  'AK020948',
#  'AK020962',
#  'AK021003',
#  'AK021004',
#  'AK021007',
#  'AK021048',
#  'AK021075',
#  'AK021093',
#  'AK021127',
#  'AK021128',
#  'AK021178',
#  'AK021191',
#  'AK021192',
#  'AK021197',
#  'AK021198',
#  'AK021199',
#  'AK021218',
#  'AK021232',
#  'AK021262',
#  'AK021280',
#  'AK021299',
#  'AK021307',
#  'AK021325',
#  'AK021342',
#  'AK021368',
#  'AK021371',
#  'AK021377',
#  'AK027935',
#  'AK027957',
#  'AK027968',
#  'AK027991',
#  'AK028005',
#  'AK028012',
#  'AK028033',
#  'AK028088',
#  'AK028089',
#  'AK028094',
#  'AK028111',
#  'AK028130',
#  ...]

# %%
reference = reference.merge(df, how='left', left_on='geneName', right_index=True)
reference.head()
# Out:
#     geneName        ucID chrom geneStrand  geneStart  geneEnd   HGNC symbol
# 0  mKIAA1889  uc007aet.1  chr1          -    3195984  3205713    NaN    NaN
# 1       Xkr4  uc007aeu.1  chr1          -    3204562  3661579  29394   XKR4
# 2   AK149000  uc007aev.1  chr1          -    3638391  3648985    NaN    NaN
# 3        Rp1  uc007aew.1  chr1          -    4280926  4399322  10263    RP1
# 4        Rp1  uc007aex.2  chr1          -    4333587  4350395  10263    RP1

# %%
reference.symbol = reference.symbol.fillna(reference.geneName)

# %%
del reference['geneName']
reference.rename(columns={'symbol': 'geneName'}, inplace=True)
reference.head()
# Out:
#          ucID chrom geneStrand  geneStart  geneEnd   HGNC   geneName
# 0  uc007aet.1  chr1          -    3195984  3205713    NaN  mKIAA1889
# 1  uc007aeu.1  chr1          -    3204562  3661579  29394       XKR4
# 2  uc007aev.1  chr1          -    3638391  3648985    NaN   AK149000
# 3  uc007aew.1  chr1          -    4280926  4399322  10263        RP1
# 4  uc007aex.2  chr1          -    4333587  4350395  10263        RP1

# %%
reference = reference[['geneName', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#     geneName chrom geneStrand  geneStart  geneEnd
# 0  mKIAA1889  chr1          -    3195984  3205713
# 1       XKR4  chr1          -    3204562  3661579
# 2   AK149000  chr1          -    3638391  3648985
# 3        RP1  chr1          -    4280926  4399322
# 4        RP1  chr1          -    4333587  4350395

# %%
(len(reference), len(reference.drop_duplicates()))
# Out:
# (55419, 46984)

# %%
reference.drop_duplicates(inplace=True)

# %%
reference.to_csv('../example_data/mm9/reference.normalized.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part II: Constructing a motifs file
#
# Unlike hg19, this file isn't pre-normalized

# %%
motifs = parse_motifs_file(motifs_file)
motifs.head()
# Out:
#      ZScore      BBLS  motifScore  motifEnd     FDR.1 motifStrand       BLS  \
# 0  4.994866  0.160657         1.0   9199817  1.000000           +  0.160657
# 1  4.994866  2.888778         1.0  13140996  0.795455           +  2.888778
# 2  4.994866  0.851333         1.0  13352962  1.000000           -  1.407219
# 3  4.994866  0.832397         1.0  19764690  1.000000           -  2.066103
# 4  4.994866  0.062484         1.0  23167667  1.000000           +  0.805291
#
#   accession     FDR.2  cid  medianhits  motifStart motifName  orientation  \
# 0    M01236  0.686545    1       894.5     9199807      ipf1            1
# 1    M01236  0.000000    2        17.5    13140986      ipf1            1
# 2    M01236  0.411960    3       152.0    13352952      ipf1           -1
# 3    M01236  0.409045    4       155.0    19764680      ipf1           -1
# 4    M01236  0.598924    5       932.0    23167657      ipf1            1
#
#   chrom   stdevhits        LOD  NLOD  realhits
# 0  chr1  514.154218  16.691998   1.0       554
# 1  chr1   20.367867  16.691998   1.0        22
# 2  chr1  106.272480  16.691998   1.0       111
# 3  chr1  107.550732  16.691998   1.0       116
# 4  chr1  535.512287  16.691998   1.0       662

# %%
motifs = motifs[['motifName', 'chrom', 'motifStrand', 'motifStart', 'motifEnd', 'motifScore']]
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
(len(motifs), len(motifs.drop_duplicates()))
# Out:
# (24954274, 24892939)

# %%
motifs.drop_duplicates(inplace=True)

# %%
motifs[motifs.motifName.isnull()]
# Out:
# Empty DataFrame
# Columns: [motifName, chrom, motifStrand, motifStart, motifEnd, motifScore]
# Index: []

# %% [markdown]
# ### ...Incredible!

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(np.unique(motifs.motifName.values).tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="mm9", as_dataframe=True, returnall=True)
df
# Out:
# querying 1-518...done.
# Finished.
# 464 input query terms found dup hits:
# 	[('AFP1', 10), ('AIRE', 10), ('ALX-3', 10), ('AML', 5), ('AML1', 10), ('AP-1', 10), ('AP-2', 10), ('
# 56 input query terms found no hit:
# 	['ATF2:c-Jun', 'AhR:Arnt', 'Arnt::Ahr', 'Barhl-1', 'CACCC-binding', 'CHOP:C/EBPalpha', 'CLOCK:BMAL',
# {'dup': [('AFP1', 10),
#   ('AIRE', 10),
#   ('ALX-3', 10),
#   ('AML', 5),
#   ('AML1', 10),
#   ('AP-1', 10),
#   ('AP-2', 10),
#   ('AP-2rep', 3),
#   ('AR', 10),
#   ('ARP-1', 6),
#   ('ATF1', 10),
#   ('ATF2', 10),
#   ('ATF3', 10),
#   ('ATF4', 10),
#   ('AhR', 20),
#   ('Arnt', 20),
#   ('HIF-1', 10),
#   ('Alx-4', 10),
#   ('Arx', 10),
#   ('BCL6', 10),
#   ('BEN', 10),
#   ('Bach1', 10),
#   ('Bach2', 10),
#   ('Barhl2', 10),
#   ('Barx-2', 10),
#   ('Barx1', 10),
#   ('Brachyury', 10),
#   ('Brn-2', 6),
#   ('Brn-3c', 2),
#   ('Brn-4', 3),
#   ('Bsx', 10),
#   ('C/EBP', 10),
#   ('C/EBPalpha', 5),
#   ('C/EBPbeta', 6),
#   ('C/EBPdelta', 2),
#   ('factor', 20),
#   ('CART1', 10),
#   ('CDP', 40),
#   ('CR1', 10),
#   ('CR3', 10),
#   ('HD', 10),
#   ('CHX10', 10),
#   ('COUP', 40),
#   ('direct', 40),
#   ('repeat', 50),
#   ('COUP-TF', 2),
#   ('HNF-4', 20),
#   ('CP2', 10),
#   ('CP2/LBP-1c/LSF', 2),
#   ('CREB', 20),
#   ('ATF', 10),
#   ('CRX', 10),
#   ('CTCF', 10),
#   ('Cart-1', 4),
#   ('Cdx', 10),
#   ('Cdx-1', 10),
#   ('Cdx-2', 10),
#   ('Cphx', 3),
#   ('DBP', 10),
#   ('DEAF1', 10),
#   ('DEC', 10),
#   ('DMRT1', 10),
#   ('DMRT2', 10),
#   ('DMRT3', 10),
#   ('DMRT4', 9),
#   ('DMRT5', 8),
#   ('DMRT7', 3),
#   ('Dax1', 10),
#   ('Dlx-1', 10),
#   ('Dlx-2', 7),
#   ('Dlx7', 3),
#   ('E12', 10),
#   ('E2A', 10),
#   ('E2F', 10),
#   ('E2F-1', 10),
#   ('E2F1', 10),
#   ('E2F6', 10),
#   ('E4F1', 10),
#   ('EAR2', 10),
#   ('EBF', 10),
#   ('EBF1', 10),
#   ('ELF5', 10),
#   ('EMX2', 10),
#   ('ER', 10),
#   ('ERR', 10),
#   ('alpha', 10),
#   ('ERR2', 10),
#   ('(ESRRB)', 7),
#   ('ESE1', 2),
#   ('ETS2', 10),
#   ('Egr-1', 10),
#   ('Egr-2', 3),
#   ('Egr-3', 3),
#   ('Egr1', 10),
#   ('Elf-1', 10),
#   ('Elk-1', 10),
#   ('En-1', 10),
#   ('En-2', 10),
#   ('En1', 10),
#   ('Esrrb', 10),
#   ('Esx1', 10),
#   ('Ets', 10),
#   ('Evi-1', 7),
#   ('Evi1', 10),
#   ('Evx-1', 4),
#   ('Evx2', 10),
#   ('FLI1', 10),
#   ('FOXJ2', 10),
#   ('FOXM1', 10),
#   ('FOXO1', 10),
#   ('FOXO3', 10),
#   ('FOXO3A', 10),
#   ('FOXO4', 10),
#   ('FOXP3', 10),
#   ('FRA1', 10),
#   ('FXR', 20),
#   ('inverted', 10),
#   ('Foxa2', 10),
#   ('Freac-3', 8),
#   ('Freac-4', 2),
#   ('GABP', 10),
#   ('GABPA', 10),
#   ('GAF', 10),
#   ('GATA', 10),
#   ('GATA-1', 10),
#   ('GATA-2', 10),
#   ('GATA-3', 10),
#   ('GATA-4', 10),
#   ('GATA-6', 10),
#   ('GCM', 10),
#   ('GCNF', 10),
#   ('GLI', 10),
#   ('GLI1', 10),
#   ('GLI2', 10),
#   ('GLI3', 10),
#   ('GR', 20),
#   ('GSH2', 10),
#   ('GZF1', 10),
#   ('Gata1', 10),
#   ('Gbx1', 10),
#   ('Gbx2', 10),
#   ('Gfi-1', 10),
#   ('Gfi1', 10),
#   ('Gfi1b', 10),
#   ('Gsc', 10),
#   ('HB24', 4),
#   ('HB9', 9),
#   ('HEB', 5),
#   ('HEN1', 10),
#   ('HES1', 10),
#   ('HFH3', 3),
#   ('(FOXI1)', 6),
#   ('(FOXF1A)', 2),
#   ('HIF1', 8),
#   ('HMG', 10),
#   ('HMGA2', 10),
#   ('HMGIY', 5),
#   ('HMX1', 10),
#   ('HNF-1beta', 4),
#   ('HNF1', 10),
#   ('HNF3', 10),
#   ('HNF3A', 7),
#   ('HNF3beta', 3),
#   ('HNF4', 30),
#   ('HNF4alpha', 6),
#   ('HOXA1', 10),
#   ('HOXA10', 10),
#   ('HOXA11', 10),
#   ('HOXA13', 10),
#   ('HOXA3', 10),
#   ('HOXA4', 10),
#   ('HOXA5', 20),
#   ('HOXA6', 10),
#   ('HOXA7', 10),
#   ('HOXB13', 10),
#   ('HOXB3', 10),
#   ('HOXB4', 10),
#   ('HOXB6', 10),
#   ('HOXB7', 10),
#   ('HOXB8', 10),
#   ('HOXB9', 10),
#   ('HOXC-8', 4),
#   ('HOXC10', 10),
#   ('HOXC11', 10),
#   ('HOXC12', 10),
#   ('HOXC13', 10),
#   ('HOXC4', 10),
#   ('HOXC5', 10),
#   ('HOXC6', 10),
#   ('HOXC9', 10),
#   ('HOXD1', 10),
#   ('HOXD10', 10),
#   ('HOXD11', 10),
#   ('HOXD12', 10),
#   ('HOXD3', 10),
#   ('HOXD8', 10),
#   ('HSF', 10),
#   ('HSF1', 10),
#   ('HSF2', 10),
#   ('HTF', 2),
#   ('Hdx', 10),
#   ('Helios', 10),
#   ('A', 10),
#   ('Hmbox1', 10),
#   ('Hmx3', 10),
#   ('(Nkx5-1)', 7),
#   ('Homez', 10),
#   ('HoxA2', 10),
#   ('HoxB5', 10),
#   ('ICSBP', 5),
#   ('IRF', 10),
#   ('IRF-1', 10),
#   ('IRF-2', 9),
#   ('IRF3', 10),
#   ('IRF8', 10),
#   ('IRX4', 10),
#   ('ISL1', 10),
#   ('Ik-1', 4),
#   ('Ikaros', 10),
#   ('Irx-3', 10),
#   ('Irx2', 10),
#   ('Isl2', 10),
#   ('K-2b', 10),
#   ('KAISO', 10),
#   ('LBP9', 4),
#   ('LEF1', 20),
#   ('TCF1', 10),
#   ('LH-2', 3),
#   ('LRF', 9),
#   ('LRH1', 6),
#   ('LXR', 30),
#   ('PXR', 20),
#   ('CAR', 20),
#   ('RAR', 20),
#   ('Lbx2', 10),
#   ('Lhx2', 10),
#   ('Lhx3', 10),
#   ('Lhx4', 10),
#   ('Lhx5', 10),
#   ('Lhx8', 10),
#   ('Lhx9', 10),
#   ('Lim-1', 10),
#   ('Lmo2', 10),
#   ('complex', 10),
#   ('Lyf-1', 2),
#   ('MAF', 10),
#   ('MAFA', 10),
#   ('MATH1', 4),
#   ('MEF-2', 10),
#   ('MEF2A', 10),
#   ('MRG2', 10),
#   ('MTF-1', 6),
#   ('MTF1', 10),
#   ('MYB', 10),
#   ('MZF1', 10),
#   ('Meis1', 10),
#   ('Meis2', 10),
#   ('Mox1', 8),
#   ('Msx-1', 10),
#   ('Msx-2', 10),
#   ('Msx-3', 10),
#   ('Myc', 10),
#   ('Mycn', 10),
#   ('MyoD', 10),
#   ('N-Myc', 10),
#   ('NF-1', 20),
#   ('NF-AT', 6),
#   ('NF-E2', 10),
#   ('NF-Y', 10),
#   ('NF-kappaB', 20),
#   ('(p65)', 10),
#   ('NFAT2', 5),
#   ('NFAT3', 5),
#   ('NKX6.1', 10),
#   ('NRF-1', 5),
#   ('NRSF', 8),
#   ('NUR77', 7),
#   ('Nanog', 10),
#   ('Ncx', 10),
#   ('NeuroD', 9),
#   ('Nkx1-1', 10),
#   ('Nkx1-2', 10),
#   ('Nkx2-1', 10),
#   ('Nkx2-2', 10),
#   ('Nkx2-3', 10),
#   ('Nkx2-4', 10),
#   ('Nkx2-5', 10),
#   ('Nkx2-6', 10),
#   ('Nkx2-9', 4),
#   ('Nkx3-2', 10),
#   ('Nkx3A', 3),
#   ('Nkx5-1', 7),
#   ('Nkx5-2', 2),
#   ('Nkx6-2', 10),
#   ('Nkx6-3', 10),
#   ('Nobox', 10),
#   ('Nr2e3', 10),
#   ('Nrf-2', 2),
#   ('OG-2', 10),
#   ('OTP', 10),
#   ('OTX', 10),
#   ('Obox1', 2),
#   ('Obox2', 2),
#   ('Obox3', 3),
#   ('Obox5', 2),
#   ('Oct-1', 10),
#   ('Oct-2', 10),
#   ('Oct-4', 10),
#   ('(POU5F1)', 7),
#   ('Oct-6', 6),
#   ('Octamer', 10),
#   ('Olf-1', 3),
#   ('Osf2', 6),
#   ('Otx1', 10),
#   ('Otx2', 10),
#   ('Otx3', 9),
#   ('Ovol1', 10),
#   ('P50:P50', 10),
#   ('P53', 10),
#   ('PEBP', 10),
#   ('PITX2', 10),
#   ('PITX3', 10),
#   ('PKNOX2', 10),
#   ('PLZF', 6),
#   ('PMX2A', 2),
#   ('PMX2B', 3),
#   ('PNR', 10),
#   ('POU2F3', 10),
#   ('POU3F2', 10),
#   ('POU6F1', 10),
#   ('PPAR', 30),
#   ('PPARG', 10),
#   ('PPARgamma', 7),
#   ('PR', 20),
#   ('PREP1', 7),
#   ('PSX1', 3),
#   ('PU.1', 10),
#   ('PU1', 3),
#   ('PUR1', 10),
#   ('Pax', 10),
#   ('Pax-1', 10),
#   ('Pax-2', 10),
#   ('Pax-3', 10),
#   ('Pax-4', 10),
#   ('Pax-5', 10),
#   ('Pax-6', 10),
#   ('Pax-7', 10),
#   ('Pax-8', 10),
#   ('Pax2', 10),
#   ('Pax4', 10),
#   ('Pax5', 10),
#   ('Pbx', 10),
#   ('Pbx-1', 10),
#   ('Pbx1', 10),
#   ('Pdx1', 10),
#   ('Pit-1', 10),
#   ('Pitx1', 10),
#   ('Pou5f1', 10),
#   ('Prop-1', 10),
#   ('RBP-Jkappa', 2),
#   ('REST', 10),
#   ('REX1', 10),
#   ('RFX', 10),
#   ('RFX1', 20),
#   ('(EF-C)', 10),
#   ('RSRFC4', 5),
#   ('Rhox11', 2),
#   ('Roaz', 5),
#   ('S8', 10),
#   ('SATB1', 10),
#   ('SEF-1', 2),
#   ('SF1', 10),
#   ('SMAD', 10),
#   ('SMAD3', 10),
#   ('SMAD4', 10),
#   ('SOX', 10),
#   ('SOX10', 10),
#   ('SOX17', 10),
#   ('SOX2', 10),
#   ('SOX4', 10),
#   ('SOX5', 10),
#   ('SOX9', 10),
#   ('SPI-B', 10),
#   ('SREBP', 10),
#   ('SREBP-1', 9),
#   ('SREBP1', 10),
#   ('SREBP2', 8),
#   ('SRF', 10),
#   ('SRY', 10),
#   ('STAT', 10),
#   ('STAT1', 10),
#   ('STAT1:STAT1', 10),
#   ('STAT3:STAT3', 10),
#   ('STAT4', 10),
#   ('STAT5A', 30),
#   ('(homodimer)', 2),
#   ('STAT5B', 10),
#   ('STAT6', 10),
#   ('Shox2', 10),
#   ('Six-1', 10),
#   ('Six-2', 10),
#   ('Six-3', 10),
#   ('Six-6', 10),
#   ('Sp3', 10),
#   ('Spz1', 10),
#   ('Stat3', 10),
#   ('Stra13', 10),
#   ('T', 10),
#   ('T3R', 2),
#   ('TAL1', 10),
#   ('TATA', 10),
#   ('TBX15', 10),
#   ('TBX18', 10),
#   ('TBX5', 10),
#   ('TEF', 10),
#   ('TEF-1', 10),
#   ('TFE', 8),
#   ('TGIF', 10),
#   ('TGIF1', 10),
#   ('TGIF2', 10),
#   ('TR4', 10),
#   ('TTF-1', 8),
#   ('(Nkx2-1)', 16),
#   ('TTF1', 10),
#   ('Tcfcp2l1', 2),
#   ('Tst-1', 3),
#   ('USF', 10),
#   ('Uncx-4.1', 2),
#   ('VBP', 10),
#   ('VDR', 20),
#   ('Vsx1', 10),
#   ('Whn', 5),
#   ('XBP-1', 10),
#   ('YY1', 10),
#   ('YY2', 10),
#   ('ZBED6', 10),
#   ('ZF5', 4),
#   ('Zec', 2),
#   ('Zic1', 10),
#   ('Zic2', 10),
#   ('Zic3', 10),
#   ('c-Ets-1', 20),
#   ('p54', 10),
#   ('c-Ets-1(p54)', 10),
#   ('c-Ets-2', 10),
#   ('c-Myb', 10),
#   ('c-Myc', 10),
#   ('c-Rel', 10),
#   ('core-binding', 10),
#   ('deltaEF1', 6),
#   ('dlx3', 10),
#   ('dlx5', 10),
#   ('hbp1', 10),
#   ('hoxa9', 10),
#   ('ipf1', 10),
#   ('isx', 10),
#   ('lhx6.1', 2),
#   ('lmx1b', 10),
#   ('myogenin', 20),
#   ('p300', 10),
#   ('p63', 10),
#   ('pax6', 10),
#   ('rax', 10),
#   ('six4', 10)],
#  'missing': ['ATF2:c-Jun',
#   'AhR:Arnt',
#   'Arnt::Ahr',
#   'Barhl-1',
#   'CACCC-binding',
#   'CHOP:C/EBPalpha',
#   'CLOCK:BMAL',
#   'COMP1',
#   '1',
#   'Dobox4',
#   'Dobox5',
#   'Ebox',
#   '1',
#   'FXR/RXR-alpha',
#   'GABP-alpha',
#   'GATA-X',
#   'GTF2IRD1-isoform2',
#   'IY',
#   '1',
#   'Hand1::Tcfe2a',
#   'Hand1:E47',
#   'Ik-2',
#   '(Tcfcp211)',
#   'LMAF',
#   '4',
#   'MEIS1A:HOXA9',
#   'MEIS1B:HOXA9',
#   'NKX22',
#   'NKX25',
#   'NRSE',
#   'OCT-x',
#   '1',
#   'PPARG::RXRA',
#   'PPARalpha:RXRalpha',
#   'PPARgamma:RXRalpha',
#   'PPARgamma:RXRalpha',
#   'RUSH-1alpha',
#   'RXR:LXR-beta',
#   'SMM',
#   'SMM_as_activator',
#   'SMM_as_activator_with_spacer',
#   'SMM_brkOnly',
#   'SMM_from_Brk_Gsb_Bam',
#   'SMM_from_consensus',
#   '(homotetramer)',
#   'STATx',
#   'TCF11:MafG',
#   'TERALPHA',
#   'Tal1::Gata1',
#   'Tax/CREB',
#   'VDR:RXR',
#   'Vax-1',
#   'Vax-2',
#   'aMEF-2',
#   'c-Myc:Max',
#   '/'],
#  'out':         HGNC                 _id     _score notfound        symbol
#  query
#  AFP1     NaN             2847518  73.748085      NaN          afp1
#  AFP1     NaN              843257  69.848260      NaN          AFP1
#  AFP1     NaN           108840814   8.728746      NaN  LOC108840814
#  AFP1     NaN            11440732   5.038149      NaN  MTR_3g025970
#  AFP1     NaN           108827246   4.760823      NaN  LOC108827246
#  AFP1     NaN           109132705   4.577127      NaN  LOC109132705
#  AFP1     NaN           103831324   4.574373      NaN  LOC103831324
#  AFP1     NaN           108202855   4.574373      NaN  LOC108202855
#  AFP1     NaN           100265755   4.569742      NaN  LOC100265755
#  AFP1     NaN            25494667   4.569742      NaN  MTR_5g045370
#  AIRE     360                 326  74.945470      NaN          AIRE
#  AIRE     NaN               11634  66.941760      NaN          Aire
#  AIRE     NaN              294328  59.077710      NaN          Aire
#  AIRE     NaN           103086904  58.191100      NaN          AIRE
#  AIRE     NaN           108239629  58.191100      NaN          aire
#  AIRE     NaN           102263368  58.191100      NaN          AIRE
#  AIRE     NaN           102342265  58.191100      NaN          AIRE
#  AIRE     NaN           107510160  58.191100      NaN          AIRE
#  AIRE     NaN           102859512  58.191100      NaN          AIRE
#  AIRE     NaN           109372106  58.191100      NaN          AIRE
#  ALX-3    449                 257   6.006139      NaN          ALX3
#  ALX-3    NaN              365900   4.262422      NaN          Alx3
#  ALX-3    NaN  ENSRNOG00000018290   4.153141      NaN          Alx3
#  ALX-3    NaN           101979352   4.032034      NaN          Alx3
#  ALX-3    NaN           102065307   4.032034      NaN          ALX3
#  ALX-3    NaN           106946538   4.032034      NaN          alx3
#  ALX-3    NaN              700927   4.032034      NaN          ALX3
#  ALX-3    NaN           102298792   4.032034      NaN          alx3
#  ALX-3    NaN           101932400   4.032034      NaN          ALX3
#  ALX-3    NaN           105531931   4.032034      NaN          ALX3
#  ...      ...                 ...        ...      ...           ...
#  pax6    8620                5080  75.030220      NaN          PAX6
#  pax6     NaN               18508  67.489280      NaN          Pax6
#  pax6     NaN           102967783  59.267002      NaN          PAX6
#  pax6     NaN           105717241  59.267002      NaN          PAX6
#  pax6     NaN           104535095  59.267002      NaN          PAX6
#  pax6     NaN           104166016  59.267002      NaN          PAX6
#  pax6     NaN           101936508  59.267002      NaN          PAX6
#  pax6     NaN           102290754  59.267002      NaN          pax6
#  pax6     NaN           103555272  59.267002      NaN          PAX6
#  pax6     NaN           106498149  59.267002      NaN          PAX6
#  rax    18662               30062  85.361630      NaN           RAX
#  rax      NaN               19434  67.785450      NaN           Rax
#  rax      NaN              114213  58.993546      NaN           Rax
#  rax      NaN           107600943  55.072020      NaN           rax
#  rax      NaN           101519493  55.072020      NaN           RAX
#  rax      NaN           101027736  55.072020      NaN           RAX
#  rax      NaN           101658653  55.072020      NaN           RAX
#  rax      NaN              615339  55.072020      NaN           RAX
#  rax      NaN           100988188  55.072020      NaN           RAX
#  rax      NaN           105073993  55.072020      NaN           RAX
#  six4   10890               51804  87.361370      NaN          SIX4
#  six4     NaN               20474  66.074220      NaN          Six4
#  six4     NaN              299138  60.451546      NaN          Six4
#  six4     NaN           109516052  58.334785      NaN          six4
#  six4     NaN           100221957  58.334785      NaN          SIX4
#  six4     NaN           102265493  58.334785      NaN          SIX4
#  six4     NaN           101612993  58.334785      NaN          Six4
#  six4     NaN              703798  58.334785      NaN          SIX4
#  six4     NaN           109320891  58.334785      NaN          SIX4
#  six4     NaN           108961295  58.334785      NaN          SIX4
#
#  [4590 rows x 5 columns]}

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df
# Out:
#                HGNC  symbol
# AIRE            360    AIRE
# ALX-3           449    ALX3
# AML1          10471   RUNX1
# AP-1           6205    JUNB
# AP-2          11742  TFAP2A
# AP-2rep        6346   KLF12
# AR              644      AR
# ARP-1           304  CRISP1
# ATF1            783    ATF1
# ATF2            784    ATF2
# ATF3            785    ATF3
# ATF4            786    ATF4
# AhR             348     AHR
# Arnt            700    ARNT
# HIF-1          4910   HIF1A
# Alx-4           450    ALX4
# Arx           18060     ARX
# BCL6           1001    BCL6
# BEN           12492   UBE2N
# Bach1           935   BACH1
# Bach2         14078   BACH2
# Barhl2          954  BARHL2
# Barx-2          956   BARX2
# Barx1           955   BARX1
# Brn-2          9215  POU3F2
# Brn-4          9217  POU3F4
# Bsx           20450     BSX
# C/EBP          1833   CEBPA
# CART1         12034   TRAF4
# CDP            2557    CUX1
# ...             ...     ...
# XBP-1         12801    XBP1
# YY1           12856     YY1
# YY2           31684     YY2
# ZBED6         33273   ZBED6
# ZF5           12860  ZBTB14
# Zec           28054  ZNF628
# Zic1          12872    ZIC1
# Zic2          12873    ZIC2
# Zic3          12874    ZIC3
# c-Ets-1        3488    ETS1
# p54           10782  SRSF11
# c-Ets-1(p54)   3488    ETS1
# c-Myb          7545     MYB
# c-Myc          7553     MYC
# c-Rel          9954     REL
# core-binding   1539    CBFB
# deltaEF1      11642    ZEB1
# dlx3           2916    DLX3
# dlx5           2918    DLX5
# hbp1          23200    HBP1
# hoxa9          5109   HOXA9
# isx           28084     ISX
# lhx6.1        21735    LHX6
# lmx1b          6654   LMX1B
# myogenin       7612    MYOG
# p300           3373   EP300
# p63           12640   UVRAG
# pax6           8620    PAX6
# rax           18662     RAX
# six4          10890    SIX4
#
# [366 rows x 2 columns]

# %%
len(df[df.index != df.symbol])
# Out:
# 246

# %%
missing
# Out:
# ['ATF2:c-Jun',
#  'AhR:Arnt',
#  'Arnt::Ahr',
#  'Barhl-1',
#  'CACCC-binding',
#  'CHOP:C/EBPalpha',
#  'CLOCK:BMAL',
#  'COMP1',
#  '1',
#  'Dobox4',
#  'Dobox5',
#  'Ebox',
#  '1',
#  'FXR/RXR-alpha',
#  'GABP-alpha',
#  'GATA-X',
#  'GTF2IRD1-isoform2',
#  'IY',
#  '1',
#  'Hand1::Tcfe2a',
#  'Hand1:E47',
#  'Ik-2',
#  '(Tcfcp211)',
#  'LMAF',
#  '4',
#  'MEIS1A:HOXA9',
#  'MEIS1B:HOXA9',
#  'NKX22',
#  'NKX25',
#  'NRSE',
#  'OCT-x',
#  '1',
#  'PPARG::RXRA',
#  'PPARalpha:RXRalpha',
#  'PPARgamma:RXRalpha',
#  'PPARgamma:RXRalpha',
#  'RUSH-1alpha',
#  'RXR:LXR-beta',
#  'SMM',
#  'SMM_as_activator',
#  'SMM_as_activator_with_spacer',
#  'SMM_brkOnly',
#  'SMM_from_Brk_Gsb_Bam',
#  'SMM_from_consensus',
#  '(homotetramer)',
#  'STATx',
#  'TCF11:MafG',
#  'TERALPHA',
#  'Tal1::Gata1',
#  'Tax/CREB',
#  'VDR:RXR',
#  'Vax-1',
#  'Vax-2',
#  'aMEF-2',
#  'c-Myc:Max',
#  '/']

# %%
motifs = motifs.merge(df, how='left', left_on='motifName', right_index=True)
motifs
# Out:
#          motifName  chrom motifStrand  motifStart   motifEnd  motifScore  \
# 0             ipf1   chr1           +     9199807    9199817         1.0
# 1             ipf1   chr1           +    13140986   13140996         1.0
# 2             ipf1   chr1           -    13352952   13352962         1.0
# 3             ipf1   chr1           -    19764680   19764690         1.0
# 4             ipf1   chr1           +    23167657   23167667         1.0
# 5             ipf1   chr1           +    25983558   25983568         1.0
# 6             ipf1   chr1           +    34351743   34351753         1.0
# 7             ipf1   chr1           +    42779143   42779153         1.0
# 8             ipf1   chr1           +    45549685   45549695         1.0
# 9             ipf1   chr1           +    48337032   48337042         1.0
# 10            ipf1   chr1           -    50972368   50972378         1.0
# 11            ipf1   chr1           +    60142851   60142861         1.0
# 12            ipf1   chr1           +    60975572   60975582         1.0
# 13            ipf1   chr1           -    68483734   68483744         1.0
# 14            ipf1   chr1           +    68708032   68708042         1.0
# 15            ipf1   chr1           -    70786849   70786859         1.0
# 16            ipf1   chr1           +    73323182   73323192         1.0
# 17            ipf1   chr1           +    76733146   76733156         1.0
# 18            ipf1   chr1           +    79256655   79256665         1.0
# 19            ipf1   chr1           -    79672675   79672685         1.0
# 20            ipf1   chr1           +    80394164   80394174         1.0
# 21            ipf1   chr1           +    89743546   89743556         1.0
# 22            ipf1   chr1           +    92649551   92649561         1.0
# 23            ipf1   chr1           +    93958531   93958541         1.0
# 24            ipf1   chr1           -    98286677   98286687         1.0
# 25            ipf1   chr1           +   120341810  120341820         1.0
# 26            ipf1   chr1           -   123189857  123189867         1.0
# 27            ipf1   chr1           +   128581008  128581018         1.0
# 28            ipf1   chr1           -   128467785  128467795         1.0
# 29            ipf1   chr1           -   140657715  140657725         1.0
# ...            ...    ...         ...         ...        ...         ...
# 24892909       Zec   chr7           +    72964449   72964462         1.0
# 24892910       Zec   chr8           +    84926824   84926837         1.0
# 24892911       Zec   chr8           -   121493018  121493031         1.0
# 24892912       Zec   chr9           +    47161277   47161290         1.0
# 24892913       Zec   chr9           -   110634208  110634221         1.0
# 24892914       Zec   chr1           +    77403615   77403628         1.0
# 24892915       Zec  chr11           +     4038827    4038840         1.0
# 24892916       Zec  chr11           -     6894570    6894583         1.0
# 24892917       Zec  chr11           -     7201932    7201945         1.0
# 24892918       Zec  chr11           +    40208256   40208269         1.0
# 24892919       Zec  chr11           +    44699455   44699468         1.0
# 24892920       Zec  chr11           -    68682756   68682769         1.0
# 24892921       Zec  chr11           -    69831175   69831188         1.0
# 24892922       Zec  chr11           +    97826958   97826971         1.0
# 24892923       Zec  chr11           -   121054682  121054695         1.0
# 24892924       Zec  chr12           -    17636491   17636504         1.0
# 24892925       Zec  chr13           -    43178120   43178133         1.0
# 24892926       Zec  chr15           -    98530392   98530405         1.0
# 24892927       Zec   chr2           -   125856328  125856341         1.0
# 24892928       Zec   chr5           +    46413004   46413017         1.0
# 24892929       Zec  chr12           -    91102826   91102839         1.0
# 24892930       Zec  chr13           -    45530405   45530418         1.0
# 24892931       Zec  chr13           -   111309733  111309746         1.0
# 24892932       Zec  chr14           -    71288599   71288612         1.0
# 24892933       Zec  chr17           -    44141039   44141052         1.0
# 24892934       Zec   chr2           +    91239705   91239718         1.0
# 24892935       Zec   chr3           +    12095261   12095274         1.0
# 24892936       Zec   chr3           +    75939196   75939209         1.0
# 24892937       Zec   chr3           -   143326805  143326818         1.0
# 24892938       Zec   chr9           +    85762713   85762726         1.0
#
#            HGNC  symbol
# 0           NaN     NaN
# 1           NaN     NaN
# 2           NaN     NaN
# 3           NaN     NaN
# 4           NaN     NaN
# 5           NaN     NaN
# 6           NaN     NaN
# 7           NaN     NaN
# 8           NaN     NaN
# 9           NaN     NaN
# 10          NaN     NaN
# 11          NaN     NaN
# 12          NaN     NaN
# 13          NaN     NaN
# 14          NaN     NaN
# 15          NaN     NaN
# 16          NaN     NaN
# 17          NaN     NaN
# 18          NaN     NaN
# 19          NaN     NaN
# 20          NaN     NaN
# 21          NaN     NaN
# 22          NaN     NaN
# 23          NaN     NaN
# 24          NaN     NaN
# 25          NaN     NaN
# 26          NaN     NaN
# 27          NaN     NaN
# 28          NaN     NaN
# 29          NaN     NaN
# ...         ...     ...
# 24892909  28054  ZNF628
# 24892910  28054  ZNF628
# 24892911  28054  ZNF628
# 24892912  28054  ZNF628
# 24892913  28054  ZNF628
# 24892914  28054  ZNF628
# 24892915  28054  ZNF628
# 24892916  28054  ZNF628
# 24892917  28054  ZNF628
# 24892918  28054  ZNF628
# 24892919  28054  ZNF628
# 24892920  28054  ZNF628
# 24892921  28054  ZNF628
# 24892922  28054  ZNF628
# 24892923  28054  ZNF628
# 24892924  28054  ZNF628
# 24892925  28054  ZNF628
# 24892926  28054  ZNF628
# 24892927  28054  ZNF628
# 24892928  28054  ZNF628
# 24892929  28054  ZNF628
# 24892930  28054  ZNF628
# 24892931  28054  ZNF628
# 24892932  28054  ZNF628
# 24892933  28054  ZNF628
# 24892934  28054  ZNF628
# 24892935  28054  ZNF628
# 24892936  28054  ZNF628
# 24892937  28054  ZNF628
# 24892938  28054  ZNF628
#
# [24892939 rows x 8 columns]

# %%
motifs.symbol = motifs.symbol.fillna(motifs.motifName)
del motifs['motifName'], motifs['HGNC']
motifs.rename(columns={'symbol': 'motifName'}, inplace=True)
motifs.head()
# Out:
#   chrom motifStrand  motifStart  motifEnd  motifScore motifName
# 0  chr1           +     9199807   9199817         1.0      ipf1
# 1  chr1           +    13140986  13140996         1.0      ipf1
# 2  chr1           -    13352952  13352962         1.0      ipf1
# 3  chr1           -    19764680  19764690         1.0      ipf1
# 4  chr1           +    23167657  23167667         1.0      ipf1

# %%
motifs = motifs[['motifName', 'chrom', 'motifStrand', 'motifStart', 'motifEnd', 'motifScore']]
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
(len(motifs), len(motifs.drop_duplicates()))
# Out:
# (24892939, 24892939)

# %%
motifs.drop_duplicates(inplace=True)

# %%
motifs.to_csv('../example_data/mm9/mm9_motifmap.normalized.cleaned.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part III: Merging genes and motifs

# %%
reference = pd.read_csv('../example_data/mm9/reference.normalized.tsv', sep='\t')
motifs = pd.read_csv('../example_data/mm9/mm9_motifmap.normalized.cleaned.tsv', sep='\t')

# %%
reference.head()
# Out:
#     geneName chrom geneStrand  geneStart  geneEnd
# 0  mKIAA1889  chr1          -    3195984  3205713
# 1       XKR4  chr1          -    3204562  3661579
# 2   AK149000  chr1          -    3638391  3648985
# 3        RP1  chr1          -    4280926  4399322
# 4        RP1  chr1          -    4333587  4350395

# %%
motifs.head()
# Out:
#   motifName chrom motifStrand  motifStart  motifEnd  motifScore
# 0      ipf1  chr1           +     9199807   9199817         1.0
# 1      ipf1  chr1           +    13140986  13140996         1.0
# 2      ipf1  chr1           -    13352952  13352962         1.0
# 3      ipf1  chr1           -    19764680  19764690         1.0
# 4      ipf1  chr1           +    23167657  23167667         1.0

# %%
reference = group_by_chromosome(reference)
motifs = group_by_chromosome(motifs)

# %%
options = {'upstream_window': 10000, 'downstream_window': 10000, 'tss': False}
reference = {chrom: IntervalTree_from_reference(genes, options) for chrom, genes in reference.items()}
motifs = {chrom: IntervalTree_from_motifs(chromosome_motifs) for chrom, chromosome_motifs in motifs.items()}

# %%
motifs_with_associated_genes = intersection_of_dict_of_intervaltree(motifs, reference)
# Out:
# 02:51:42 - GarNet: INFO - Computing intersection operation of IntervalTrees for each chromosome...

# %%
motifs_and_genes = [{**motif, **gene} for motif, gene in motifs_with_associated_genes]
motifs_and_genes = pd.DataFrame.from_records(motifs_and_genes)
motifs_and_genes.head()
# Out:
#          chrom  geneEnd geneName  geneStart geneStrand  motifEnd motifName  \
# 0  chrX_random   594813  Gm15093     395346          -    398121     FOSL1
# 1  chrX_random   594813  Gm15093     395346          -    522820     Dbx-2
# 2  chrX_random   594813  Gm15093     395346          -    522820     Msx-3
# 3  chrX_random   594813  Gm15093     395346          -    522820      PAX6
# 4  chrX_random   594813  Gm15093     395346          -    522820      En-1
#
#    motifScore  motifStart motifStrand
# 0    0.442020      398113           +
# 1    0.660888      522804           -
# 2    0.698805      522804           -
# 3    0.732189      522804           +
# 4    0.787059      522804           -

# %%
motifs_and_genes = motifs_and_genes[['chrom','motifName','motifStrand','motifStart','motifEnd','motifScore','geneName','geneStart','geneEnd','geneStrand']]
motifs_and_genes
# Out:
#                 chrom  motifName motifStrand  motifStart   motifEnd  \
# 0         chrX_random      FOSL1           +      398113     398121
# 1         chrX_random      Dbx-2           -      522804     522820
# 2         chrX_random      Msx-3           -      522804     522820
# 3         chrX_random       PAX6           +      522804     522820
# 4         chrX_random       En-1           -      522804     522820
# 5         chrX_random       ipf1           +     1136248    1136254
# 6         chrX_random       ipf1           +     1136248    1136254
# 7         chrX_random       PDX1           -      100524     100530
# 8         chrX_random       MYOG           +      392512     392520
# 9         chrX_random      MYEF2           +       14267      14289
# 10        chrX_random  alpha-CP1           -      537644     537655
# 11        chrX_random       CTCF           -      555230     555250
# 12        chrX_random       CTCF           -      555230     555250
# 13        chrX_random     NKX2-5           -      177819     177826
# 14        chrX_random   Tax/CREB           +      110238     110253
# 15        chrX_random       ipf1           +     1125535    1125541
# 16        chrX_random       ARNT           +      521711     521717
# 17        chrX_random      STAT1           +      111462     111483
# 18        chrX_random      STAT3           +      111462     111483
# 19        chrX_random       ETS2           -     1121961    1121968
# 20        chrX_random         ER           +     1141831    1141850
# 21        chrX_random       ESX1           -     1406311    1406328
# 22        chrX_random       En-2           +     1406311    1406328
# 23        chrX_random       LHX2           +     1406311    1406328
# 24        chrX_random       LH-2           +     1406311    1406328
# 25        chrX_random       EMX2           +     1406311    1406328
# 26        chrX_random      SOX17           +      402974     402980
# 27        chrX_random      STAT6           +      414872     414880
# 28        chrX_random     NKX3-2           +      110168     110174
# 29        chrX_random       ipf1           +     1125976    1125982
# ...               ...        ...         ...         ...        ...
# 33391183         chr4       E2F1           +   102486409  102486417
# 33391184         chr4        CRX           -     3674052    3674058
# 33391185         chr4       HNF4           -   117665732  117665738
# 33391186         chr4       HNF4           -   117665732  117665738
# 33391187         chr4       ipf1           +   106434500  106434506
# 33391188         chr4       ipf1           +   106434500  106434506
# 33391189         chr4         ER           -   153851386  153851397
# 33391190         chr4       IRF8           +   124918518  124918525
# 33391191         chr4       ETS2           -    49421046   49421053
# 33391192         chr4       ipf1           +   110272631  110272637
# 33391193         chr4       ipf1           +   110272631  110272637
# 33391194         chr4       ipf1           +   110272631  110272637
# 33391195         chr4       SPI1           +   110810299  110810307
# 33391196         chr4       SPI1           +   110810299  110810307
# 33391197         chr4       SPI1           +   110810299  110810307
# 33391198         chr4      KLF12           +   101926239  101926246
# 33391199         chr4      KLF12           +   101926239  101926246
# 33391200         chr4      KLF12           +   101926239  101926246
# 33391201         chr4      TEAD3           -    21721019   21721025
# 33391202         chr4      TEAD3           -    21721019   21721025
# 33391203         chr4      TEAD3           -    21721019   21721025
# 33391204         chr4        DBP           +    87871461   87871468
# 33391205         chr4        DBP           +    87871461   87871468
# 33391206         chr4      Obox6           -    84187461   84187476
# 33391207         chr4      Obox6           -    84187461   84187476
# 33391208         chr4      Obox6           -    84187461   84187476
# 33391209         chr4       PDX1           -    36364638   36364644
# 33391210         chr4       PDX1           -    36364638   36364644
# 33391211         chr4       TFEC           +    84214040   84214048
# 33391212         chr4       TFEC           +    84214040   84214048
#
#           motifScore  geneName  geneStart    geneEnd geneStrand
# 0           0.442020   Gm15093     395346     594813          -
# 1           0.660888   Gm15093     395346     594813          -
# 2           0.698805   Gm15093     395346     594813          -
# 3           0.732189   Gm15093     395346     594813          -
# 4           0.787059   Gm15093     395346     594813          -
# 5           0.981493  AK185910    1141891    1144819          -
# 6           0.981493  MIR138-2    1126526    1126597          -
# 7           1.000000     SPRY3     101351     106392          -
# 8           0.159941   Gm15093     395346     594813          -
# 9           0.909253     VAMP7      10737      39148          -
# 10          0.656406   Gm15093     395346     594813          -
# 11          0.068323     RBM15     562213     602417          -
# 12          0.068323   Gm15093     395346     594813          -
# 13          1.000000     TMLHE     159646     334187          +
# 14          1.000000     SPRY3     101351     106392          -
# 15          1.000000  MIR138-2    1126526    1126597          -
# 16          1.000000   Gm15093     395346     594813          -
# 17          0.409076     SPRY3     101351     106392          -
# 18          0.771388     SPRY3     101351     106392          -
# 19          0.202599  MIR138-2    1126526    1126597          -
# 20          0.515583  AK185910    1141891    1144819          -
# 21          0.696372    Gm1993    1375832    1397989          +
# 22          0.626880    Gm1993    1375832    1397989          +
# 23          0.624950    Gm1993    1375832    1397989          +
# 24          0.477562    Gm1993    1375832    1397989          +
# 25          0.561050    Gm1993    1375832    1397989          +
# 26          1.000000   Gm15093     395346     594813          -
# 27          0.712952   Gm15093     395346     594813          -
# 28          1.000000     SPRY3     101351     106392          -
# 29          1.000000  MIR138-2    1126526    1126597          -
# ...              ...       ...        ...        ...        ...
# 33391183    1.000000     SGIP1  102432967  102643782          +
# 33391184    1.000000       LYN    3605267    3718759          +
# 33391185    0.289945   ST3GAL3  117604757  117807495          -
# 33391186    0.289945   ST3GAL3  117604757  117807519          -
# 33391187    1.000000    ACOT11  106417165  106472436          -
# 33391188    1.000000    ACOT11  106417165  106429939          -
# 33391189    0.221129    PRDM16  153690233  154010982          -
# 33391190    0.741554  AK006677  124905840  124919296          +
# 33391191    0.208356    Acnat2   49392716   49421023          -
# 33391192    1.000000     AGBL4  110070395  111239615          +
# 33391193    1.000000     AGBL4  110070395  111330115          +
# 33391194    1.000000     AGBL4  110070395  111335629          +
# 33391195    0.772857     AGBL4  110070395  111239615          +
# 33391196    0.772857     AGBL4  110070395  111330115          +
# 33391197    0.772857     AGBL4  110070395  111335629          +
# 33391198    0.376842     PDE4B  101760345  102230202          +
# 33391199    0.376842     PDE4B  101927346  102279867          +
# 33391200    0.376842     PDE4B  101927346  102228529          +
# 33391201    1.000000     USP45   21703416   21711987          +
# 33391202    1.000000     USP45   21703416   21725527          +
# 33391203    1.000000     USP45   21703416   21765019          +
# 33391204    1.000000  BC057079   87740533   88056915          +
# 33391205    1.000000  BC057079   87767173   88056915          +
# 33391206    1.000000      BNC2   83918445   84320990          -
# 33391207    1.000000      BNC2   84034586   84320990          -
# 33391208    1.000000      BNC2   83918445   84192309          -
# 33391209    1.000000    LINGO2   35653896   36898777          -
# 33391210    1.000000    LINGO2   35653896   36665996          -
# 33391211    0.759370      BNC2   83918445   84320990          -
# 33391212    0.759370      BNC2   84034586   84320990          -
#
# [33391213 rows x 10 columns]

# %%
motifs_and_genes['motif_to_gene_distance'] = motifs_and_genes['motifStart'] - motifs_and_genes['geneStart']
motifs_and_genes.head()
# Out:
#          chrom motifName motifStrand  motifStart  motifEnd  motifScore  \
# 0  chrX_random     FOSL1           +      398113    398121    0.442020
# 1  chrX_random     Dbx-2           -      522804    522820    0.660888
# 2  chrX_random     Msx-3           -      522804    522820    0.698805
# 3  chrX_random      PAX6           +      522804    522820    0.732189
# 4  chrX_random      En-1           -      522804    522820    0.787059
#
#   geneName  geneStart  geneEnd geneStrand  motif_to_gene_distance
# 0  Gm15093     395346   594813          -                    2767
# 1  Gm15093     395346   594813          -                  127458
# 2  Gm15093     395346   594813          -                  127458
# 3  Gm15093     395346   594813          -                  127458
# 4  Gm15093     395346   594813          -                  127458

# %%
motifs_and_genes.to_csv('../example_data/mm9/intersection.tsv', sep='\t', header=True, index=False)

# %% [markdown]
# # Part IV: Building and exporting IntervalTrees: constructing the "GarNet File"

# %%
motifs_and_genes = pd.read_csv('../example_data/mm9/intersection.tsv', sep='\t')

# %%
motifs_and_genes = group_by_chromosome(motifs_and_genes)

# %%
motifs_and_genes = {chrom: IntervalTree_from_motifs(chromosome_motifs_and_genes) for chrom, chromosome_motifs_and_genes in motifs_and_genes.items()}

# %%
save_as_pickled_object(motifs_and_genes, '../example_data/mm9/', 'garnet.pickle')
