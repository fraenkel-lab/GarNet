# %% [markdown]
# # GarNet
#
# There are two steps to GarNet:
# - **mapping** a BED file of peaks to TF motif/gene complexes
# - **regressing** those motifs' binding affinities against gene expression.

# %%
#!/usr/bin/env python3

from GarNet import map_peaks, TF_regression

garnet_file = "../example_data/hg19/hg19.garnet.pickle"

peaks = "../example_data/example_peaks/wgEncodeUWDukeDnaseA549.fdr01peaks.hg19.bed"
# peaks = "../example/example_peaks/A549_FOXA1_broadPeak.bed"
# peaks = "../example/example_peaks/JUNB_ChIP_A549.bed"
# peaks = "../example/example_peaks/CTCF_ChIP_A549.bed"
# peaks = ["../example/example_peaks/A549_FOXA1_broadPeak.bed", "../example/example_peaks/JUNB_ChIP_A549.bed", "../example/example_peaks/CTCF_ChIP_A549.bed"]

# %% [markdown]
# ## Map Peaks

# %%
df = map_peaks(peaks, garnet_file)
# Out:
# 02:10:32 - GarNet: INFO - Mapping peaks against genome from garnet-file ../example_data/hg19/hg19.garnet.pickle
# 02:10:32 - GarNet: INFO - Unpacking garnet file (this can take a while)...
# 02:48:14 - GarNet: INFO - Constructing representation of peaks file ../example_data/example_peaks/wgEncodeUWDukeDnaseA549.fdr01peaks.hg19.bed...
# 02:48:14 - GarNet: INFO -   - Peaks file does not seem to have been generated by pickle, proceeding to parse...
# 02:48:15 - GarNet: INFO -   - Parse complete, constructing IntervalTrees...
# 02:48:23 - GarNet: INFO - Computing intersection of peaks with reference...
# 02:48:23 - GarNet: INFO - Computing intersection operation of IntervalTrees for each chromosome...

# %%
df.head()
# Out:
#   chrom  motifStart  motifEnd motifName  motifScore geneName  geneStart  \
# 0  chrX    10009681  10009687  MZF1_1-4    0.395137     WWC3    9983794
# 1  chrX    25039141  25039160      REST    0.015574      ARX   25021812
# 2  chrX    25039207  25039218      EBF1    0.029736      ARX   25021812
# 3  chrX    25039140  25039161      NRSE    0.019347      ARX   25021812
# 4  chrX    25039140  25039161      REST    0.029062      ARX   25021812
#
#     geneEnd peakName
# 0  10112518        .
# 1  25034065        .
# 2  25034065        .
# 3  25034065        .
# 4  25034065        .

# %%
df.to_csv("../example_data/temp.tsv", sep='\t', header=True, index=False)

# %% [markdown]
# ## TF Regression

# %%
import pandas as pd 

expression = "../example_data/expression/Tgfb_exp.tsv"
df = pd.read_csv('../example_data/temp.tsv', sep='\t')
df.head()
# Out:
#   chrom  motifStart  motifEnd motifName  motifScore geneName  geneStart  \
# 0  chrX    10009681  10009687  MZF1_1-4    0.395137     WWC3    9983794
# 1  chrX    25039141  25039160      REST    0.015574      ARX   25021812
# 2  chrX    25039207  25039218      EBF1    0.029736      ARX   25021812
# 3  chrX    25039140  25039161      NRSE    0.019347      ARX   25021812
# 4  chrX    25039140  25039161      REST    0.029062      ARX   25021812
#
#     geneEnd peakName
# 0  10112518        .
# 1  25034065        .
# 2  25034065        .
# 3  25034065        .
# 4  25034065        .

# %%
tfs = TF_regression(df, expression)
# Out:
# 10:36:24 - GarNet: INFO - Performing linear regression for 422 transcription factor expression profiles...
# /Users/alex/Documents/GarNet/venv/lib/python3.6/site-packages/statsmodels/base/model.py:1036: RuntimeWarning: invalid value encountered in true_divide
#   return self.params / self.bse
# /Users/alex/Documents/GarNet/venv/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Users/alex/Documents/GarNet/venv/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Users/alex/Documents/GarNet/venv/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %% [markdown]
# ### Occasionally, the motifScore might be 0, causing a divide by 0, causing the error above. Not to worry...

# %%
tfs
# Out:
#      Transcription Factor       Slope   P-Value  \
# 0                     AHR   67.850000  0.375410
# 1                    ALX4    0.744295  0.717978
# 2                     AML  -22.553067  0.094280
# 3              AP-2alphaA    6.296716  0.313251
# 4                      AR   -2.922142  0.414332
# 5                    ARNT    2.214483  0.366826
# 6                    ATF1   11.183138  0.056749
# 7                    ATF2   -0.847601  0.434626
# 8              ATF2:c-Jun    0.666818  0.603021
# 9                    ATF3    0.000000       NaN
# 10                   ATF4    0.000000       NaN
# 11                   ATF6    1.495629  0.356684
# 12                 ATF7IP    0.047312  0.960364
# 13       AhR, Arnt, HIF-1   -0.213785  0.886023
# 14               AhR:Arnt    0.183235  0.262017
# 15                  BACH1   -1.979023  0.682020
# 16                  BACH2    5.444122  0.235522
# 17                 BARHL2   47.857580  0.952938
# 18                   BCL6 -104.446206  0.008102
# 19                  BRCA1  -12.109023  0.018054
# 20              C/EBPbeta   -1.246900  0.965713
# 21   CACCC-binding factor   -1.993438  0.827798
# 22                  CAMK4    0.594027  0.734611
# 23                   CD40   -8.665116  0.282167
# 24             CLOCK:BMAL   -2.296575  0.291624
# 25   COUP direct repeat 1    5.019377  0.484541
# 26         COUP-TF, HNF-4   25.516363  0.292103
# 27                 COUPTF   -5.587996  0.190432
# 28         CP2/LBP-1c/LSF    7.715133  0.127056
# 29              CREB, ATF    0.482868  0.511274
# ..                    ...         ...       ...
# 305                 TRAF4    1.374116  0.619034
# 306        Tal-1alpha:E47    8.569764  0.468968
# 307         Tal-1beta:E47   17.358153  0.259242
# 308       Tal-1beta:ITF-2   20.268218  0.145046
# 309              Tax/CREB    0.018529  0.908595
# 310                 UBE2N    1.265527  0.838831
# 311                  UBP1  -19.611580  0.045062
# 312                   USF    0.251857  0.771035
# 313                  USF1  -27.953699  0.065788
# 314                  USF2   -0.175186  0.892555
# 315                  VBP1  -15.375917  0.028936
# 316               VDR:RXR    1.773976  0.754148
# 317                  VSX2   11.191874  0.425080
# 318                 Vax-2  -11.300377  0.409760
# 319                  XBP1   -1.477603  0.491771
# 320                   YY1   -2.515648  0.052368
# 321                 ZBTB4    2.554212  0.470766
# 322                 ZBTB6   -6.036790  0.115113
# 323                  ZEB1   -0.008059  0.998240
# 324                ZNF143    0.915891  0.885765
# 325                ZNF217    0.071786  0.720319
# 326                ZNF350   -8.416167  0.221235
# 327               ZNF354C   -3.305146  0.190166
# 328                ZNF423    0.526428  0.930360
# 329                ZNF513   -1.999460  0.773651
# 330             alpha-CP1    5.858812  0.267957
# 331           c-Ets-1 p54  -18.157554  0.105383
# 332             c-Myc:Max    0.858400  0.540763
# 333       myogenin / NF-1   30.746536  0.079158
# 334           p53 decamer  413.647555  0.934799
#
#                                                Targets
# 0    [SPTBN2, EFEMP2, SYT7, STARD10, MPZL2, NRG1, S...
# 1    [PRSS23, LSR, PFKFB3, SLC9A3R1, ACLY, ST3GAL5,...
# 2    [FHL1, LIMS1, PDGFC, GLIS3, EPB41L4B, SPDEF, L...
# 3    [IRX5, PKP3, ERF, TGFB1, IL11, VIM, NRG1, TYRO...
# 4    [PARD6A, CTNND1, TLN2, SPINT1, RHOV, PMP22, EP...
# 5    [AP1S2, CPT1A, EFEMP2, STARD10, ERF, CRB3, PPP...
# 6    [CYLD, FA2H, PARD6A, MPZL2, ERF, GEM, MYC, TYR...
# 7    [CYLD, AKTIP, RELA, MPZL2, ERF, IL11, CRLF1, T...
# 8    [CYLD, PARD6A, CCND1, MPZL2, ERF, CRLF1, TMEM5...
# 9    [CDH1, CYLD, FA2H, PARD6A, CLCF1, ERF, ITGB1, ...
# 10   [ERF, PRDX2, GEM, MYC, SPINT1, RHOV, NEDD4, JU...
# 11   [IRX3, SYT7, ERF, LYN, DUSP4, MYH9, CHSY1, PRK...
# 12   [ACSL4, CYLD, IRX3, PARD6A, CTNND1, SYT7, TAGL...
# 13   [SPTBN2, EFEMP2, SYT7, STARD10, LSR, AP1M2, CD...
# 14   [ACSL4, AXL, TGFB1, NFKB2, NRG1, BMF, SUZ12, A...
# 15   [CDH11, PPL, PLLP, ETS1, PLEKHA7, CD44, AHNAK,...
# 16   [CDH11, PPL, PLLP, SLC22A18, ETS1, AHNAK, SPTB...
# 17            [RAB11FIP1, ZNF608, KITLG, LIMA1, FOXA2]
# 18                    [SRPX, TGFB1, VCAN, NFIB, FOXN3]
# 19   [STS, SRPX, IL1RAPL1, DLG3, LOC440335, RRAD, S...
# 20            [CDH1, EPAS1, PALLD, BNC2, RUNX2, ACOT7]
# 21   [AHNAK, TCF7L2, MAFF, ELL3, TOB1, PMP22, FN1, ...
# 22   [PRSS33, SYTL2, CTNND1, PRSS23, EHF, CCND1, RA...
# 23   [CYLD, RRAD, SORL1, RAB38, PRDX2, NFKB2, NRG1,...
# 24   [AP1S2, EFEMP2, MUC5B, EHF, CCND1, STARD10, CT...
# 25   [CLCF1, BCAM, TCF7L2, NRG1, TPD52, SEPT9, DBN1...
# 26   [CLCF1, TCF7L2, SEPT9, SHROOM3, NFIB, BNC2, TU...
# 27     [AHNAK, STARD10, MKNK2, SEPT9, TRERF1, CAMK2N1]
# 28   [AHNAK, BMF, HBEGF, ZNF608, P4HA2, BTC, FOXA1,...
# 29   [CYLD, IRX3, PARD6A, SYT7, CCND1, RNF141, MPZL...
# ..                                                 ...
# 305  [LSR, KCTD15, DKK1, TLN2, ACLY, ABR, CCNB1, LA...
# 306  [ACSL4, MVP, SYT7, PRSS23, GADD45B, KCNMA1, NR...
# 307  [ACSL4, ST3GAL2, SYT7, GADD45B, KCNMA1, STAU2,...
# 308  [ACSL4, ST3GAL2, KCNMA1, NRG1, STAU2, TOX, BMP...
# 309  [CYLD, IRX3, PPL, ETS1, PKP3, RNF141, LSR, ERF...
# 310  [CCNF, ETS1, PLEKHA7, SPTBN2, ARNTL, MUC5B, SE...
# 311  [IDH3G, MAGED2, SYNGR3, CDH1, MVP, FA2H, CCNF,...
# 312  [AP1S2, SBK1, CPT1A, ETS1, EFEMP2, LRP5, EXPH5...
# 313  [AP1S2, TCEAL8, CPT1A, EFEMP2, MUC5B, EHF, CCN...
# 314  [AP1S2, TCEAL8, SLC9A3R2, CPT1A, SLC22A18, ETS...
# 315                  [SAT1, AKTIP, ERF, SSPN, FILIP1L]
# 316  [SBK1, PKP3, HIF3A, ITGB3, COL1A1, SATB2, SLC2...
# 317  [PFKFB3, TLN2, PPM1H, BCAT1, SERPINB5, ELF3, Z...
# 318     [KCTD15, GGT1, TLN2, ABR, SYNPO, TLE4, ZBTB38]
# 319  [SYT7, SCAMP2, PRKAR1A, SEPT9, CLDN7, CCNYL1, ...
# 320  [AP1S2, DIAPH2, FHL1, SRPX, NRK, CDH1, CYLD, M...
# 321  [SYTL2, CD44, PRSS23, TCF7L2, ITGB1, CGNL1, TH...
# 322  [EFEMP2, AXL, PTK2B, TOM1L1, NRCAM, LRBA, EPB4...
# 323  [FA2H, IRX3, RRAD, TGFB1I1, PLLP, ETS1, CTNND1...
# 324  [CTNND1, EFEMP2, SSH3, LMTK3, ERF, CRLF1, TMEM...
# 325  [SLC9A3R2, CTSC, ERF, DMPK, ZFPM2, LOXL2, ANGP...
# 326  [LRP5, TCF7L2, GRB7, PDLIM4, LAMB1, SCUBE3, QK...
# 327  [SAT1, IDH3G, ACSL4, DLG3, SYNGR3, CDH1, MVP, ...
# 328  [MAGED2, CCND1, STARD10, MIF4GD, EFNB3, FOSL2,...
# 329  [SNAI2, BMP1, MRC2, SEPT9, COL1A1, PDGFC, TNFA...
# 330  [SAT1, DLG3, TGFB1I1, MLKL, AHNAK, H19, TM7SF2...
# 331  [MAGED2, AXL, CRB3, RAB11FIP1, TOX, LRRC49, SL...
# 332  [AP1S2, CPT1A, EFEMP2, CCND1, STARD10, CTSF, E...
# 333         [AHNAK, TCF7L2, ACLY, DLX2, ANXA6, POU3F2]
# 334  [CD44, SORBS3, SPINT1, RHOV, EPAS1, S100A10, L...
#
# [335 rows x 4 columns]

# %% [markdown]
# ### If you provide an output_dir to `TF_regression`, you can see each of the scatterplots.
