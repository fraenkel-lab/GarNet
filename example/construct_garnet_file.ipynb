# %% [markdown]
# # Constructing a GarNetDB file
#
# The goal here is to construct a file in which all of the gene and transcription factor names exist in the same namespace. We use mygene.info's API to map all the gene names to a common namespace. It isn't clear that they have the most "canonical" namespace but at present they correlate best with genecards, and seems to be more consistent than all other namespaces I know of.

# %%
# %pylab inline
import sys
import os
import pickle
import sqlite3
import numpy as np
import pandas as pd

known_genes_file = '../data/ucsc_hg19_knownGenes.tsv'
kgXref_file = '../data/ucsc_hg19_kgXref.tsv'
motifs_file = '../example_data/motifmap.normalized.tsv'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Part I: Constructing a reference file
#
# We use UCSC's [known genes](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=refGene&hgta_regionType=genome&position=chr21%3A33031597-33041570&hgta_outputType=primaryTable&hgta_outFileName=) and [Cross Reference (kgXref) file](http://genome.ucsc.edu/cgi-bin/hgTables?hgsid=590772967_aCXvu74nAfyUAYeUksjLuUk1eBz3&clade=mammal&org=Human&db=hg19&hgta_group=genes&hgta_track=refGene&hgta_table=kgXref&hgta_regionType=genome&position=chr21%3A33%2C031%2C597-33%2C041%2C570&hgta_outputType=primaryTable&hgta_outFileName=) as our foundation.

# %%
def parse_known_genes_file(known_genes_file, kgXref_file):
    """
    Parse the RefSeq known genes file into a pandas dataframe

    The known genes file format is the following:
    http://hgdownload.cse.ucsc.edu/goldenPath/hg19/database/knownGene.sql

    Arguments:
        known_genes_file (string or FILE): file procured from RefSeq with full list of genes in genome
        kgXref_file (string or FILE): additional "Cross Reference" file with more details on those genes

    Returns:
        dataframe: known genes dataframe
    """

    known_genes_fieldnames = ["name","chrom","strand","txStart","txEnd","cdsStart","cdsEnd","exonCount","exonStarts","exonEnds","proteinID","alignID"]

    known_genes_dataframe = pd.read_csv(known_genes_file, delimiter='\t', names=known_genes_fieldnames)

    known_genes_dataframe.rename(index=str, columns={"txStart":"geneStart", "txEnd":"geneEnd", "name":"geneName","strand":"geneStrand"}, inplace=True)

    if kgXref_file:

        kgXref_fieldnames = ["kgID","mRNA","spID","spDisplayID","geneSymbol","refseq","protAcc","description"]
        kgXref_dataframe = pd.read_csv(kgXref_file, delimiter='\t', names=kgXref_fieldnames)

        known_genes_dataframe = known_genes_dataframe.merge(kgXref_dataframe, left_on='geneName', right_on='kgID', how='left')
        known_genes_dataframe.rename(index=str, columns={"geneName":"ucID", "geneSymbol":"geneName"}, inplace=True)

    return known_genes_dataframe

# %%
reference = parse_known_genes_file(known_genes_file, kgXref_file)
reference.head()
# Out:
#          ucID chrom geneStrand  geneStart  geneEnd  cdsStart  cdsEnd  \
# 0  uc001aaa.3  chr1          +      11873    14409     11873   11873
# 1  uc010nxr.1  chr1          +      11873    14409     11873   11873
# 2  uc010nxq.1  chr1          +      11873    14409     12189   13639
# 3  uc009vis.3  chr1          -      14361    16765     14361   14361
# 4  uc009vjc.1  chr1          -      16857    17751     16857   16857
#
#    exonCount                exonStarts                  exonEnds proteinID  \
# 0          3        11873,12612,13220,        12227,12721,14409,       NaN
# 1          3        11873,12645,13220,        12227,12697,14409,       NaN
# 2          3        11873,12594,13402,        12227,12721,14409,    B7ZGX9
# 3          4  14361,14969,15795,16606,  14829,15038,15942,16765,       NaN
# 4          2              16857,17232,              17055,17751,       NaN
#
#       alignID        kgID       mRNA    spID   spDisplayID geneName  \
# 0  uc001aaa.3  uc001aaa.3  NR_046018     NaN           NaN  DDX11L1
# 1  uc010nxr.1  uc010nxr.1   AM992878     NaN           NaN  DDX11L1
# 2  uc010nxq.1  uc010nxq.1   AM992880  B7ZGX9  B7ZGX9_HUMAN  DDX11L1
# 3  uc009vis.3  uc009vis.3   BC047449     NaN           NaN   WASH7P
# 4  uc009vjc.1  uc009vjc.1   AK291582     NaN           NaN   WASH7P
#
#       refseq protAcc                                        description
# 0  NR_046018     NaN  Homo sapiens DEAD/H (Asp-Glu-Ala-Asp/His) box ...
# 1        NaN     NaN  Homo sapiens DEAD/H (Asp-Glu-Ala-Asp/His) box ...
# 2        NaN     NaN  Homo sapiens DEAD/H (Asp-Glu-Ala-Asp/His) box ...
# 3        NaN     NaN  Homo sapiens WAS protein family homolog 7 pseu...
# 4        NaN     NaN  Homo sapiens WAS protein family homolog 7 pseu...

# %%
reference = reference[['geneName', 'ucID', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#   geneName        ucID chrom geneStrand  geneStart  geneEnd
# 0  DDX11L1  uc001aaa.3  chr1          +      11873    14409
# 1  DDX11L1  uc010nxr.1  chr1          +      11873    14409
# 2  DDX11L1  uc010nxq.1  chr1          +      11873    14409
# 3   WASH7P  uc009vis.3  chr1          -      14361    16765
# 4   WASH7P  uc009vjc.1  chr1          -      16857    17751

# %%
reference[reference.geneName.isnull()]
# Out:
# Empty DataFrame
# Columns: [geneName, ucID, chrom, geneStrand, geneStart, geneEnd]
# Index: []

# %% [markdown]
# ### ...Amazing!

# %%
import mygene
mg = mygene.MyGeneInfo()
df = mg.querymany(np.unique(reference.geneName.values).tolist(), scopes=['symbol', 'name', 'alias'], fields=["HGNC", "symbol"], species="human", as_dataframe=True, returnall=True)
df
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-25000...done.
# querying 25001-26000...done.
# querying 26001-27000...done.
# querying 27001-28000...done.
# querying 28001-28517...done.
# Finished.
# 4228 input query terms found dup hits:
# 	[('5S_rRNA', 10), ('5_8S_rRNA', 6), ('7SK', 10), ('A1BG', 2), ('A2M', 5), ('A2ML1', 5), ('AADACL2',
# 5242 input query terms found no hit:
# 	['AB000466', 'AB007962', 'AB059369', 'AB062081', 'AB062083', 'AB073649', 'AB074160', 'AB074162', 'AB
# {'dup': [('5S_rRNA', 10),
#   ('5_8S_rRNA', 6),
#   ('7SK', 10),
#   ('A1BG', 2),
#   ('A2M', 5),
#   ('A2ML1', 5),
#   ('AADACL2', 4),
#   ('AARSD1', 2),
#   ('AATK', 2),
#   ('ABCA9', 2),
#   ('ABCC5', 2),
#   ('ABCC6P1', 2),
#   ('ABHD11', 3),
#   ('ABHD14A', 2),
#   ('ABHD15', 3),
#   ('ABHD17A', 3),
#   ('ABO', 2),
#   ('ABP1', 2),
#   ('ABRA', 2),
#   ('ACAD11', 3),
#   ('ACAP2', 3),
#   ('ACAT1', 2),
#   ('ACAT2', 2),
#   ('ACBD3', 2),
#   ('ACBD7', 2),
#   ('ACOXL', 2),
#   ('ACP1', 2),
#   ('ACTA2', 3),
#   ('ACTB', 2),
#   ('ACTG1P4', 2),
#   ('ACTN1', 2),
#   ('ACTR3', 7),
#   ('ACTR3B', 10),
#   ('ACTR3BP2', 2),
#   ('ACTR3BP5', 2),
#   ('ACTR6', 3),
#   ('ACVR2B', 2),
#   ('ACY1', 2),
#   ('AD', 10),
#   ('ADAM18', 2),
#   ('ADAM1A', 2),
#   ('ADAM5', 2),
#   ('ADAMTS19', 2),
#   ('ADAMTS7', 8),
#   ('ADAMTS9', 4),
#   ('ADAMTS9-AS2', 2),
#   ('ADAMTSL4', 2),
#   ('ADARB2', 2),
#   ('ADC', 2),
#   ('ADCY3', 2),
#   ('ADD3', 3),
#   ('ADH4', 2),
#   ('ADIPOQ', 9),
#   ('ADIRF', 3),
#   ('ADNP', 3),
#   ('ADORA2A', 4),
#   ('ADPGK', 2),
#   ('ADRA1A', 2),
#   ('AFAP1', 2),
#   ('AFF1', 2),
#   ('AFF2', 3),
#   ('AFP', 2),
#   ('AGA', 10),
#   ('AGAP1', 2),
#   ('AGAP11', 2),
#   ('AGAP2', 2),
#   ('AGBL1', 2),
#   ('AGBL4', 2),
#   ('AGBL5', 4),
#   ('AGPAT4', 2),
#   ('AGPAT9', 2),
#   ('AGT', 10),
#   ('AHNAK', 2),
#   ('AHRR', 2),
#   ('AIDA', 2),
#   ('AIM1', 3),
#   ('AIP', 8),
#   ('AK3', 2),
#   ('AKAP2', 4),
#   ('AKNA', 2),
#   ('AKNAD1', 2),
#   ('AKR1C6P', 2),
#   ('AKR7A2P1', 3),
#   ('AKR7L', 2),
#   ('AKT1', 2),
#   ('AKT3', 3),
#   ('ALB', 2),
#   ('ALDH1L1', 3),
#   ('ALG1', 3),
#   ('ALG10', 2),
#   ('ALG11', 2),
#   ('ALG13', 3),
#   ('ALG1L9P', 2),
#   ('ALG2', 2),
#   ('ALG3', 3),
#   ('ALG9', 3),
#   ('ALK', 8),
#   ('ALKBH3', 2),
#   ('ALMS1', 4),
#   ('ALOX12', 2),
#   ('ALS2', 2),
#   ('AMACR', 3),
#   ('AMER2', 2),
#   ('AMMECR1', 6),
#   ('AMN', 2),
#   ('ANG', 2),
#   ('ANKHD1', 2),
#   ('ANKRD10', 3),
#   ('ANKRD19P', 2),
#   ('ANKRD20A19P', 2),
#   ('ANKRD20A4', 2),
#   ('ANKRD20A5P', 2),
#   ('ANKRD20A8P', 2),
#   ('ANKRD20A9P', 3),
#   ('ANKRD26P1', 2),
#   ('ANKRD26P3', 2),
#   ('ANKRD30BP2', 2),
#   ('ANKRD30BP3', 4),
#   ('ANKRD33', 2),
#   ('ANKRD33B', 3),
#   ('ANKRD34C', 3),
#   ('ANKRD36C', 2),
#   ('ANKRD44', 2),
#   ('ANKRD62P1-PARP4P3', 2),
#   ('ANO1', 5),
#   ('ANP32A', 2),
#   ('ANP32AP1', 2),
#   ('ANP32C', 2),
#   ('ANXA2P1', 2),
#   ('ANXA2P2', 2),
#   ('ANXA2P3', 2),
#   ('ANXA8', 2),
#   ('AOAH', 2),
#   ('AOX2P', 3),
#   ('AP3S2', 2),
#   ('AP4B1', 2),
#   ('APAF1', 3),
#   ('APC', 10),
#   ('APC2', 3),
#   ('APCDD1L', 2),
#   ('APITD1', 2),
#   ('APOA1', 2),
#   ('APOA2', 2),
#   ('APOBEC1', 2),
#   ('APOBEC3A', 2),
#   ('APOBEC3B', 3),
#   ('APOC2', 3),
#   ('APOL3', 2),
#   ('APP', 4),
#   ('APPL2', 2),
#   ('AQP4', 3),
#   ('AQP4-AS1', 2),
#   ('AQP7P1', 2),
#   ('AQP7P3', 2),
#   ('AR', 7),
#   ('ARAF', 7),
#   ('ARAP1', 5),
#   ('ARC', 8),
#   ('ARF1', 2),
#   ('ARF4', 2),
#   ('ARFGAP1', 2),
#   ('ARFGAP2', 2),
#   ('ARG1', 2),
#   ('ARGFXP2', 2),
#   ('ARHGAP10', 2),
#   ('ARHGAP19', 3),
#   ('ARHGAP19-SLIT1', 2),
#   ('ARHGAP22', 3),
#   ('ARHGAP26', 3),
#   ('ARHGAP31', 2),
#   ('ARHGAP5', 3),
#   ('ARHGAP5-AS1', 2),
#   ('ARHGAP8', 2),
#   ('ARHGEF19', 3),
#   ('ARHGEF26', 2),
#   ('ARHGEF3', 2),
#   ('ARHGEF34P', 2),
#   ('ARHGEF38', 2),
#   ('ARHGEF7', 6),
#   ('ARHGEF9', 2),
#   ('ARID4B', 2),
#   ('ARL1', 2),
#   ('ARL14', 2),
#   ('ARL17A', 3),
#   ('ARL2', 3),
#   ('ARL2-SNX15', 2),
#   ('ARL3', 2),
#   ('ARL5B', 2),
#   ('ARL6', 2),
#   ('ARMC2', 3),
#   ('ARMCX3', 3),
#   ('ARMCX5', 3),
#   ('ARMCX5-GPRASP2', 2),
#   ('ARMCX6', 2),
#   ('ARNT', 2),
#   ('ARNTL2', 2),
#   ('ARPC4', 2),
#   ('ARPP21', 3),
#   ('ARRDC1', 2),
#   ('ARRDC3', 2),
#   ('ARSA', 2),
#   ('ARSB', 2),
#   ('ARSD', 3),
#   ('ART1', 2),
#   ('ARX', 2),
#   ('AS3MT', 2),
#   ('ASAP1', 3),
#   ('ASB16', 2),
#   ('ASB3', 2),
#   ('ASB9P1', 2),
#   ('ASH1L', 5),
#   ('ASH1L-AS1', 2),
#   ('ASIP', 2),
#   ('ASL', 2),
#   ('ASMT', 3),
#   ('ASMTL', 3),
#   ('ASMTL-AS1', 2),
#   ('ASTN2', 2),
#   ('ATE1', 2),
#   ('ATF1', 2),
#   ('ATF2', 2),
#   ('ATG10', 5),
#   ('ATL1', 2),
#   ('ATM', 5),
#   ('ATP11A', 4),
#   ('ATP13A4', 3),
#   ('ATP13A5', 3),
#   ('ATP1A1', 4),
#   ('ATP1B3', 3),
#   ('ATP2A1', 2),
#   ('ATP2B1', 2),
#   ('ATP2B2', 5),
#   ('ATP2C2', 2),
#   ('ATP5E', 2),
#   ('ATP5EP2', 2),
#   ('ATP5J2', 2),
#   ('ATP5S', 2),
#   ('ATP6V0CP3', 2),
#   ('ATP6V0E2', 2),
#   ('ATP6V1B1', 3),
#   ('ATP6V1G2', 3),
#   ('ATP6V1G2-DDX39B', 2),
#   ('ATPAF1', 2),
#   ('ATR', 6),
#   ('ATXN2', 3),
#   ('ATXN3', 2),
#   ('ATXN7', 3),
#   ('ATXN8OS', 2),
#   ('AURKAPS1', 2),
#   ('AUTS2', 2),
#   ('AVP', 3),
#   ('AZI1', 2),
#   ('AZI2', 2),
#   ('AZIN1', 3),
#   ('B3GALT5', 2),
#   ('B3GNT1', 2),
#   ('B3GNT6', 2),
#   ('B3GNT8', 2),
#   ('B4GALT1', 3),
#   ('B4GALT4', 2),
#   ('BAALC', 4),
#   ('BACE1', 3),
#   ('BACE1-AS', 2),
#   ('BACE2', 3),
#   ('BACH1', 9),
#   ('BAD', 2),
#   ('BAGE', 5),
#   ('BAI1', 6),
#   ('BAIAP2', 2),
#   ('BANCR', 2),
#   ('BAP1', 3),
#   ('BARX1', 3),
#   ('BASP1P1', 2),
#   ('BAX', 6),
#   ('BBOX1', 3),
#   ('BCAM', 2),
#   ('BCAS2', 4),
#   ('BCDIN3D', 2),
#   ('BCL2', 10),
#   ('BCL2L1', 2),
#   ('BCL2L2', 2),
#   ('BCL6', 4),
#   ('BCL9', 2),
#   ('BCOR', 2),
#   ('BCR', 7),
#   ('BCRP2', 3),
#   ('BCRP3', 2),
#   ('BDKRB2', 2),
#   ('BDNF', 2),
#   ('BDP1', 2),
#   ('BEAN1', 2),
#   ('BEND3P3', 2),
#   ('BET1', 4),
#   ('BEX1', 2),
#   ('BEX2', 2),
#   ('BFSP2', 2),
#   ('BGLAP', 2),
#   ('BHLHB9', 2),
#   ('BHLHE40', 2),
#   ('BIN3', 2),
#   ('BIRC6', 4),
#   ('BIVM', 3),
#   ('BIVM-ERCC5', 2),
#   ('BLOC1S1', 2),
#   ('BLOC1S5', 5),
#   ('BLOC1S5-TXNDC5', 2),
#   ('BMI1', 4),
#   ('BMP2', 4),
#   ('BMP7', 3),
#   ('BMPR1B', 3),
#   ('BMS1', 10),
#   ('BMS1P4', 2),
#   ('BNC1', 2),
#   ('BOK', 3),
#   ('BOK-AS1', 2),
#   ('BOLA2', 4),
#   ('BOLA3', 2),
#   ('BPI', 10),
#   ('BRAF', 5),
#   ('BRAP', 3),
#   ('BRCA1', 10),
#   ('BRCA2', 7),
#   ('BRCC3', 2),
#   ('BRD2', 7),
#   ('BRD4', 3),
#   ('BRE', 2),
#   ('BRF1', 2),
#   ('BRF2', 2),
#   ('BRI3', 4),
#   ('BRI3BP', 2),
#   ('BRIP1', 2),
#   ('BRMS1', 2),
#   ('BRPF1', 2),
#   ('BRWD1', 5),
#   ('BSCL2', 3),
#   ('BSN', 4),
#   ('BST1', 2),
#   ('BST2', 2),
#   ('BTBD9', 3),
#   ('BTD', 2),
#   ('BTF3', 2),
#   ('BTF3P11', 2),
#   ('BTG3', 2),
#   ('BUB1', 4),
#   ('BUB1B', 2),
#   ('BUB3', 3),
#   ('BUD13', 3),
#   ('BUD31', 5),
#   ('BVES', 2),
#   ('BZRAP1', 2),
#   ('C10orf111', 2),
#   ('C10orf2', 2),
#   ('C10orf25', 2),
#   ('C10orf32', 2),
#   ('C10orf71', 3),
#   ('C10orf91', 2),
#   ('C11orf44', 2),
#   ('C11orf48', 2),
#   ('C12orf29', 2),
#   ('C12orf71', 2),
#   ('C12orf77', 2),
#   ('C13orf45', 2),
#   ('C15orf32', 2),
#   ('C15orf38', 2),
#   ('C15orf54', 2),
#   ('C15orf56', 2),
#   ('C15orf59', 3),
#   ('C16orf52', 2),
#   ('C16orf54', 2),
#   ('C16orf97', 2),
#   ('C17orf100', 2),
#   ('C17orf102', 2),
#   ('C17orf105', 2),
#   ('C17orf112', 2),
#   ('C17orf58', 2),
#   ('C17orf77', 2),
#   ('C17orf82', 2),
#   ('C18orf32', 2),
#   ('C1D', 10),
#   ('C1GALT1', 3),
#   ('C1QTNF1', 2),
#   ('C1QTNF3', 3),
#   ('C1QTNF9', 3),
#   ('C1QTNF9B', 3),
#   ('C1QTNF9B-AS1', 2),
#   ('C1R', 2),
#   ('C1RL', 2),
#   ('C1orf123', 2),
#   ('C1orf145', 2),
#   ('C1orf167', 2),
#   ('C1orf229', 2),
#   ('C2', 10),
#   ('C20orf166', 3),
#   ('C20orf166-AS1', 2),
#   ('C20orf197', 2),
#   ('C20orf203', 2),
#   ('C20orf24', 2),
#   ('C20orf78', 2),
#   ('C21orf59', 2),
#   ('C21orf62', 4),
#   ('C21orf91', 2),
#   ('C22orf24', 2),
#   ('C2CD2', 2),
#   ('C2orf27A', 2),
#   ('C2orf27B', 3),
#   ('C2orf47', 2),
#   ('C2orf48', 2),
#   ('C3', 10),
#   ('C3orf35', 2),
#   ('C3orf49', 2),
#   ('C3orf56', 3),
#   ('C3orf67', 2),
#   ('C3orf79', 2),
#   ('C4A', 7),
#   ('C4B', 4),
#   ('C4B_2', 2),
#   ('C5', 10),
#   ('C5orf56', 2),
#   ('C5orf60', 2),
#   ('C5orf64', 2),
#   ('C6', 6),
#   ('C6orf106', 2),
#   ('C6orf47', 9),
#   ('C6orf99', 2),
#   ('C7', 10),
#   ('C7orf13', 2),
#   ('C7orf55', 2),
#   ('C7orf65', 2),
#   ('C7orf66', 2),
#   ('C7orf69', 2),
#   ('C7orf71', 2),
#   ('C7orf73', 2),
#   ('C8orf31', 3),
#   ('C8orf34', 2),
#   ('C8orf37', 3),
#   ('C8orf44', 2),
#   ('C8orf76', 2),
#   ('C8orf87', 2),
#   ('C9', 6),
#   ('C9orf106', 2),
#   ('C9orf135', 3),
#   ('C9orf139', 2),
#   ('C9orf163', 2),
#   ('C9orf170', 2),
#   ('C9orf173', 2),
#   ('C9orf3', 2),
#   ('C9orf41', 3),
#   ('C9orf62', 2),
#   ('CA11', 2),
#   ('CA2', 10),
#   ('CA3', 2),
#   ('CABP1', 2),
#   ('CABYR', 3),
#   ('CACNA1C', 10),
#   ('CACNA1C-IT3', 2),
#   ('CACNA1G', 2),
#   ('CACNA1I', 2),
#   ('CACNA2D3', 2),
#   ('CACTIN', 2),
#   ('CAD', 6),
#   ('CADM2', 4),
#   ('CADM3', 3),
#   ('CALML3', 3),
#   ('CAMP', 10),
#   ('CAMTA1', 3),
#   ('CAP1', 6),
#   ('CAP2', 2),
#   ('CAPG', 2),
#   ('CAPN10', 3),
#   ('CAPS', 2),
#   ('CAPS2', 2),
#   ('CARD8', 2),
#   ('CARS', 5),
#   ('CASK', 5),
#   ('CASP2', 3),
#   ('CASP8', 2),
#   ('CAST', 4),
#   ('CAT', 10),
#   ('CATSPER2', 2),
#   ('CBL', 6),
#   ('CBLB', 2),
#   ('CBLC', 2),
#   ('CBR3', 2),
#   ('CBS', 6),
#   ('CCAT1', 2),
#   ('CCBP2', 2),
#   ('CCDC13', 2),
#   ('CCDC144CP', 2),
#   ('CCDC144NL', 2),
#   ('CCDC147', 2),
#   ('CCDC148', 2),
#   ('CCDC169', 2),
#   ('CCDC18', 3),
#   ('CCDC37', 2),
#   ('CCDC39', 3),
#   ('CCDC41', 2),
#   ('CCDC74B', 2),
#   ('CCK', 6),
#   ('CCL14', 4),
#   ('CCL15', 4),
#   ('CCL15-CCL14', 3),
#   ('CCL28', 2),
#   ('CCM2', 2),
#   ('CCND2', 4),
#   ('CCNL1', 2),
#   ('CCNT2', 3),
#   ('CCPG1', 2),
#   ('CCR10', 3),
#   ('CCR4', 10),
#   ('CCR9', 2),
#   ('CCRL1', 2),
#   ('CCS', 2),
#   ('CCT3', 2),
#   ('CCT4', 3),
#   ('CCT5', 3),
#   ('CCT6P1', 2),
#   ('CCT7', 3),
#   ('CCT8', 2),
#   ('CCZ1', 2),
#   ('CD14', 2),
#   ('CD163', 2),
#   ('CD164', 2),
#   ('CD177', 3),
#   ('CD1A', 5),
#   ('CD2', 4),
#   ('CD200', 3),
#   ('CD24', 8),
#   ('CD27', 3),
#   ('CD300C', 2),
#   ('CD302', 2),
#   ('CD3E', 2),
#   ('CD3G', 2),
#   ('CD40', 2),
#   ('CD44', 3),
#   ('CD46', 3),
#   ('CD5', 2),
#   ('CD53', 2),
#   ('CD79A', 10),
#   ('CD81', 2),
#   ('CD83', 3),
#   ('CD84', 2),
#   ('CD8B', 2),
#   ('CD99', 4),
#   ('CDA', 2),
#   ('CDC14B', 2),
#   ('CDC14C', 2),
#   ('CDC37L1', 2),
#   ('CDC42', 10),
#   ('CDC42P3', 2),
#   ('CDH1', 2),
#   ('CDH16', 2),
#   ('CDH18', 2),
#   ('CDH19', 2),
#   ('CDH20', 2),
#   ('CDH23', 3),
#   ('CDH24', 2),
#   ('CDH3', 2),
#   ('CDH7', 3),
#   ('CDIPT', 2),
#   ('CDK2', 2),
#   ('CDK3', 3),
#   ('CDK5', 8),
#   ('CDKN1A', 6),
#   ('CDKN2A', 10),
#   ('CDKN2B', 4),
#   ('CDR1', 3),
#   ('CDR3', 2),
#   ('CDRT15P1', 2),
#   ('CDRT15P2', 2),
#   ('CDRT4', 2),
#   ('CDS1', 2),
#   ('CDV3', 3),
#   ('CEACAM18', 2),
#   ('CEACAM22P', 2),
#   ('CEACAM3', 2),
#   ('CEBPA', 2),
#   ('CEBPB', 3),
#   ('CEBPZ', 3),
#   ('CECR5', 2),
#   ('CELF2', 4),
#   ('CELF2-AS2', 2),
#   ('CELP', 2),
#   ('CELSR3', 2),
#   ('CENPB', 3),
#   ('CEP170P1', 2),
#   ('CER1', 2),
#   ('CERS3', 3),
#   ('CERS5', 2),
#   ('CERS6', 2),
#   ('CES1P2', 2),
#   ('CES2', 2),
#   ('CES5AP1', 3),
#   ('CETN4P', 2),
#   ('CFC1B', 2),
#   ('CFD', 2),
#   ('CFL1', 2),
#   ('CFLAR', 2),
#   ('CGA', 6),
#   ('CGB', 3),
#   ('CGB5', 2),
#   ('CGB7', 2),
#   ('CGB8', 2),
#   ('CHAT', 2),
#   ('CHD2', 2),
#   ('CHD5', 4),
#   ('CHKB', 4),
#   ('CHKB-CPT1B', 2),
#   ('CHL1', 5),
#   ('CHM', 5),
#   ('CHMP3', 2),
#   ('CHMP4A', 2),
#   ('CHMP4B', 2),
#   ('CHODL', 3),
#   ('CHODL-AS1', 2),
#   ('CHP1', 2),
#   ('CHPF', 2),
#   ('CHRFAM7A', 3),
#   ('CHRM3', 3),
#   ('CHRNA7', 3),
#   ('CHST9', 2),
#   ('CHURC1', 2),
#   ('CIC', 2),
#   ('CIDECP', 2),
#   ('CIR1', 2),
#   ('CIRBP', 3),
#   ('CIRBP-AS1', 2),
#   ('CIT', 5),
#   ('CKB', 4),
#   ('CKLF', 10),
#   ('CKMT2', 2),
#   ('CLC', 10),
#   ('CLDN10', 2),
#   ('CLEC12A', 2),
#   ('CLEC2B', 2),
#   ('CLEC4GP1', 2),
#   ('CLGN', 2),
#   ('CLIP1', 3),
#   ('CLIP4', 2),
#   ('CLK1', 3),
#   ('CLK2', 2),
#   ('CLK4', 2),
#   ('CLOCK', 9),
#   ('CLP1', 3),
#   ('CLPTM1', 2),
#   ('CLPTM1L', 3),
#   ('CLRN1', 5),
#   ('CLRN1-AS1', 3),
#   ('CLSTN2', 2),
#   ('CLYBL', 4),
#   ('CMAHP', 2),
#   ('CMC1', 2),
#   ('CMPK2', 2),
#   ('CMTM1', 2),
#   ('CNIH', 4),
#   ('CNOT10', 3),
#   ('CNP', 2),
#   ('CNPY3', 2),
#   ('CNR1', 3),
#   ('CNR2', 2),
#   ('CNTF', 3),
#   ('CNTFR', 3),
#   ('CNTN4', 4),
#   ('COG8', 2),
#   ('COIL', 10),
#   ('COL18A1', 3),
#   ('COL1A2', 2),
#   ('COL4A2', 4),
#   ('COL5A1', 2),
#   ('COL6A4P2', 2),
#   ('COMMD3', 2),
#   ('COPG2', 2),
#   ('COPS7B', 2),
#   ('CORO7', 2),
#   ('CORT', 2),
#   ('COX10', 2),
#   ('COX11', 3),
#   ('COX16', 3),
#   ('COX17', 3),
#   ('COX20', 5),
#   ('CP', 6),
#   ('CPA3', 2),
#   ('CPA6', 2),
#   ('CPB2', 2),
#   ('CPD', 2),
#   ('CPE', 6),
#   ('CPEB1', 2),
#   ('CPEB2', 2),
#   ('CPEB3', 2),
#   ('CPN1', 3),
#   ('CPN2', 3),
#   ('CPO', 2),
#   ('CPS1', 4),
#   ('CPSF1', 2),
#   ('CPT1B', 3),
#   ('CREB3', 3),
#   ('CREBBP', 2),
#   ('CRH', 2),
#   ('CRHR1', 3),
#   ('CRHR1-IT1', 2),
#   ('CRIP1', 2),
#   ('CRK', 2),
#   ('CROCCP2', 2),
#   ('CRP', 4),
#   ('CRTC3', 2),
#   ('CRYAA', 2),
#   ('CRYM', 3),
#   ('CRYM-AS1', 2),
#   ('CS', 8),
#   ('CSAG2', 2),
#   ('CSE1L', 2),
#   ('CSK', 2),
#   ('CSMD2', 2),
#   ('CSN2', 2),
#   ('CSN3', 2),
#   ('CSNK1A1P1', 2),
#   ('CSNK1E', 2),
#   ('CSNK1G2', 2),
#   ('CSNK2A1', 2),
#   ('CSNK2A3', 2),
#   ('CSRP2BP', 2),
#   ('CST6', 2),
#   ('CSTF3', 2),
#   ('CT64', 2),
#   ('CTAGE10P', 2),
#   ('CTAGE11P', 2),
#   ('CTAGE7P', 2),
#   ('CTBP1', 4),
#   ('CTCF', 2),
#   ('CTGF', 2),
#   ('CTH', 2),
#   ('CTNNBIP1', 2),
#   ('CTNND1', 3),
#   ('CTSO', 2),
#   ('CTTNBP2', 2),
#   ('CUZD1', 2),
#   ('CWC22', 3),
#   ('CWH43', 2),
#   ('CXADR', 2),
#   ('CXADRP2', 3),
#   ('CXADRP3', 2),
#   ('CXCR2P1', 2),
#   ('CXXC11', 2),
#   ('CXXC4', 2),
#   ('CXorf49B', 2),
#   ('CYC1', 2),
#   ('CYMP', 2),
#   ('CYP17A1', 2),
#   ('CYP1B1', 2),
#   ('CYP21A1P', 5),
#   ('CYP2C8', 2),
#   ('CYP2C9', 2),
#   ('CYP2D6', 2),
#   ('CYP3A5', 2),
#   ('CYP3A7', 2),
#   ('CYP4A22', 3),
#   ('CYP4F2', 2),
#   ('CYP4F24P', 2),
#   ('CYP51A1', 2),
#   ('DAB1', 4),
#   ('DAB2', 2),
#   ('DACT3', 2),
#   ('DAO', 2),
#   ('DAOA', 5),
#   ('DAP', 9),
#   ('DAP3', 2),
#   ('DAPK1', 3),
#   ('DARS', 3),
#   ('DBC1', 2),
#   ('DBF4', 6),
#   ('DBH', 6),
#   ('DBI', 3),
#   ('DBIL5P', 2),
#   ('DBNDD2', 3),
#   ('DBP', 6),
#   ('DCAF13P3', 2),
#   ('DCC', 4),
#   ('DCPS', 2),
#   ('DCST1', 2),
#   ('DCTN1', 2),
#   ('DCUN1D2', 3),
#   ('DDB1', 10),
#   ('DDC', 2),
#   ('DDR1', 8),
#   ('DDX11', 2),
#   ('family', 10),
#   ('member', 10),
#   ('DDX11L1', 2),
#   ('DDX11L2', 2),
#   ('DDX11L5', 2),
#   ('DDX12P', 2),
#   ('DDX21', 2),
#   ('DDX24', 2),
#   ('DDX26B', 2),
#   ('DDX31', 2),
#   ('DDX39B', 4),
#   ('DDX53', 2),
#   ('DDX6', 2),
#   ('DEC1', 2),
#   ('DEF6', 2),
#   ('DEFA1', 2),
#   ('DEFA11P', 2),
#   ('DEFB109P1', 2),
#   ('DEFB136', 2),
#   ('DEFT1P', 2),
#   ('DENND5B', 2),
#   ('DENND6A', 3),
#   ('DEPDC1', 2),
#   ('DES', 2),
#   ('DESI1', 2),
#   ('DESI2', 2),
#   ('DET1', 3),
#   ('DEXI', 3),
#   ('DFFA', 6),
#   ('DGCR10', 2),
#   ('DGCR2', 2),
#   ('DGCR5', 2),
#   ('DGCR6', 3),
#   ('DGUOK', 2),
#   ('DHRS4', 2),
#   ('DHRS4L1', 2),
#   ('DHRSX', 3),
#   ('DIAPH2', 2),
#   ('DIAPH3', 3),
#   ('DICER1', 2),
#   ('DIO1', 2),
#   ('DIO2', 2),
#   ('DIO3', 2),
#   ('DIP2A', 2),
#   ('DIRC3', 4),
#   ('DIS3', 5),
#   ('DISC1', 6),
#   ('DISC2', 2),
#   ('DLC1', 3),
#   ('DLD', 3),
#   ('DLEU1', 3),
#   ('DLEU2', 2),
#   ('DLEU2L', 2),
#   ('DLEU7', 2),
#   ('DLG1', 2),
#   ('DLG2', 5),
#   ('DLG3', 3),
#   ('DLG4', 2),
#   ('DLG5', 4),
#   ('DLG5-AS1', 3),
#   ('DLGAP1', 9),
#   ('DLGAP1-AS1', 2),
#   ('DLGAP1-AS5', 2),
#   ('DLGAP2', 2),
#   ('DLGAP4', 2),
#   ('DLX2', 2),
#   ('DLX6', 4),
#   ('DLX6-AS1', 2),
#   ('DMC1', 2),
#   ('DMD', 4),
#   ('DMP1', 2),
#   ('DMPK', 2),
#   ('DMRT2', 2),
#   ('DMRTC1', 2),
#   ('DMTN', 2),
#   ('DNAH17', 3),
#   ('DNAH17-AS1', 2),
#   ('DNAJA1P5', 2),
#   ('DNAJB3', 2),
#   ('DNAJB4', 2),
#   ('DNAJB5', 2),
#   ('DNAJB8', 2),
#   ('DNAJC25', 2),
#   ('DNAJC27', 2),
#   ('DNAJC3', 2),
#   ('DNAJC9', 2),
#   ('DNM1P34', 2),
#   ('DNM1P35', 2),
#   ('DNM1P41', 2),
#   ('DNM3', 3),
#   ('DNMBP', 3),
#   ('DNMBP-AS1', 2),
#   ('DNMT1', 3),
#   ('DOC2GP', 2),
#   ('DOCK4', 2),
#   ('DOCK9', 4),
#   ('DOK1', 2),
#   ('DPH3P1', 2),
#   ('DPH6', 2),
#   ('DPP10', 6),
#   ('DPP9', 3),
#   ('DPPA2', 2),
#   ('DPPA2P3', 2),
#   ('DPRXP4', 2),
#   ('DPY19L1', 5),
#   ('DPY19L1P1', 2),
#   ('DPY19L1P2', 2),
#   ('DPY19L2', 9),
#   ('DPY19L2P1', 2),
#   ('DPY19L2P2', 2),
#   ('DPY30', 3),
#   ('DPYD', 5),
#   ('DR1', 3),
#   ('DRC1', 2),
#   ('DRG1', 3),
#   ('DRP2', 2),
#   ('DSC1', 4),
#   ('DSC2', 3),
#   ('DSC3', 2),
#   ('DSCAM', 3),
#   ('DSCR3', 2),
#   ('DSCR4', 3),
#   ('DSG1', 2),
#   ('DSG2', 3),
#   ('DSP', 3),
#   ('DTL', 2),
#   ('DTX2', 3),
#   ('DUSP1', 2),
#   ('DUSP23', 2),
#   ('DUSP26', 2),
#   ('DUSP27', 2),
#   ('DUSP5P1', 2),
#   ('DUT', 2),
#   ('DUX4', 3),
#   ('DUX4L2', 2),
#   ('DUX4L3', 2),
#   ('DUX4L4', 2),
#   ('DUX4L5', 2),
#   ('DUX4L6', 2),
#   ('DVL1', 2),
#   ('DYNLL1', 2),
#   ('DYNLRB2', 2),
#   ('DYRK1A', 3),
#   ('DYX1C1', 2),
#   ('DZANK1', 2),
#   ('E2F1', 3),
#   ('E2F3', 3),
#   ('E2F6', 3),
#   ('EAF1', 4),
#   ('EAF2', 2),
#   ('EBF3', 2),
#   ('EBP', 10),
#   ('ECD', 2),
#   ('EDA', 3),
#   ('EDAR', 2),
#   ('EDNRB', 3),
#   ('EEF1DP3', 2),
#   ('EEF1E1', 3),
#   ('EEF2', 2),
#   ('EFCAB10', 2),
#   ('EFCAB14', 2),
#   ('EFCAB6', 3),
#   ('EFCAB6-AS1', 2),
#   ('EFTUD1P1', 2),
#   ('EGF', 10),
#   ('EGFEM1P', 2),
#   ('EGFL8', 3),
#   ('EGFLAM', 8),
#   ('EGFLAM-AS2', 2),
#   ('EGFR', 6),
#   ('EGLN2', 3),
#   ('EGLN3', 3),
#   ('EGR1', 3),
#   ('EHD4', 3),
#   ('EHHADH', 2),
#   ('EHMT1', 2),
#   ('EHMT2', 3),
#   ('EI24', 10),
#   ('EIF1AX', 3),
#   ('EIF1B', 2),
#   ('EIF2A', 2),
#   ('EIF2AK1', 2),
#   ('EIF2AK2', 3),
#   ('EIF2B5', 5),
#   ('EIF3A', 2),
#   ('EIF3CL', 2),
#   ('EIF3J', 3),
#   ('EIF3J-AS1', 2),
#   ('EIF4E', 2),
#   ('EIF4EBP3', 2),
#   ('ELF1', 2),
#   ('ELF3', 2),
#   ('ELFN1', 2),
#   ('ELK1', 5),
#   ('ELK2AP', 3),
#   ('ELK3', 2),
#   ('ELL', 10),
#   ('ELMO1', 2),
#   ('ELOVL2', 3),
#   ('ELOVL2-AS1', 2),
#   ('EMB', 4),
#   ('EMC3', 3),
#   ('EMCN', 4),
#   ('EMG1', 2),
#   ('EMILIN3', 2),
#   ('EML2', 2),
#   ('EMX2', 2),
#   ('ENAH', 2),
#   ('ENC1', 2),
#   ('ENO1', 4),
#   ('ENOX1', 5),
#   ('ENTPD1', 2),
#   ('ENTPD3', 2),
#   ('ENY2', 2),
#   ('EP300', 7),
#   ('EP400', 3),
#   ...],
#  'missing': ['AB000466',
#   'AB007962',
#   'AB059369',
#   'AB062081',
#   'AB062083',
#   'AB073649',
#   'AB074160',
#   'AB074162',
#   'AB074166',
#   'AB074188',
#   'AB075489',
#   'AB075492',
#   'AB209061',
#   'AB209185',
#   'AB209315',
#   'AB209621',
#   'AB231702',
#   'AB231703',
#   'AB231705',
#   'AB231710',
#   'AB231711',
#   'AB231721',
#   'AB231722',
#   'AB231723',
#   'AB231724',
#   'AB231729',
#   'AB231731',
#   'AB231739',
#   'AB231741',
#   'AB231742',
#   'AB231761',
#   'AB231779',
#   'AB231784',
#   'AB240015',
#   'AB372727',
#   'AB429224',
#   'AB488780',
#   'AB586698',
#   '1',
#   'ADV21S1A1N',
#   'AF007147',
#   'AF020763',
#   'AF035281',
#   'AF047486',
#   'AF055024',
#   'AF063596',
#   'AF070569',
#   'AF070581',
#   'AF072097',
#   'AF075036',
#   'AF075112',
#   'AF079515',
#   'AF085962',
#   'AF085995',
#   'AF086102',
#   'AF086125',
#   'AF086126',
#   'AF086132',
#   'AF086154',
#   'AF086165',
#   'AF086184',
#   'AF086203',
#   'AF086219',
#   'AF086258',
#   'AF086285',
#   'AF086288',
#   'AF086294',
#   'AF086303',
#   'AF086346',
#   'AF086351',
#   'AF086476',
#   'AF088041',
#   'AF090102',
#   'AF090939',
#   'AF116693',
#   'AF119915',
#   'AF131837',
#   'AF143870',
#   'AF143871',
#   'AF157115',
#   'AF161365',
#   'AF161442',
#   'AF188711',
#   'AF198444',
#   'AF216583',
#   'AF258550',
#   'AF258560',
#   'AF268386',
#   'AF279775',
#   'AF279780',
#   'AF279782',
#   'AF289551',
#   'AF339801',
#   'AF339817',
#   'AF380582',
#   'AF387615',
#   'AF397448',
#   'AF401214',
#   'AF420437',
#   'AF508906',
#   'AF508907',
#   'AF520419',
#   'AF520792',
#   'AF520793',
#   'AF532840',
#   'AF548120',
#   'AJ004954',
#   'AJ011378',
#   'AJ011981',
#   'AJ276246',
#   'AJ297365',
#   'AJ420422',
#   'AJ420489',
#   'AJ420595',
#   'AJ515158',
#   'AJ606316',
#   'AJ606328',
#   'AJ606330',
#   'AJ606331',
#   'AK000154',
#   'AK000451',
#   'AK000470',
#   'AK000798',
#   'AK000807',
#   'AK000840',
#   'AK000953',
#   'AK001057',
#   'AK001351',
#   'AK001394',
#   'AK001533',
#   'AK001558',
#   'AK001582',
#   'AK001928',
#   'AK001975',
#   'AK002090',
#   'AK021537',
#   'AK021551',
#   'AK021563',
#   'AK021570',
#   'AK021664',
#   'AK021739',
#   'AK021804',
#   'AK021876',
#   'AK021888',
#   'AK021933',
#   'AK021977',
#   'AK022030',
#   'AK022382',
#   'AK022787',
#   'AK022793',
#   'AK022898',
#   'AK022914',
#   'AK022915',
#   'AK022993',
#   'AK022997',
#   'AK023033',
#   'AK023040',
#   'AK023159',
#   'AK023178',
#   'AK023304',
#   'AK023417',
#   'AK023457',
#   'AK023507',
#   'AK023515',
#   'AK023548',
#   'AK023566',
#   'AK023614',
#   'AK023627',
#   'AK023809',
#   'AK024092',
#   'AK024119',
#   'AK024134',
#   'AK024141',
#   'AK024242',
#   'AK024243',
#   'AK024248',
#   'AK024535',
#   'AK024736',
#   'AK024936',
#   'AK024998',
#   'AK025061',
#   'AK025117',
#   'AK025127',
#   'AK025140',
#   'AK025288',
#   'AK025321',
#   'AK025511',
#   'AK025664',
#   'AK025726',
#   'AK025793',
#   'AK025975',
#   'AK026244',
#   'AK026379',
#   'AK026392',
#   'AK026502',
#   'AK026512',
#   'AK026714',
#   'AK026736',
#   'AK026758',
#   'AK026777',
#   'AK026905',
#   'AK027091',
#   'AK027145',
#   'AK027190',
#   'AK027252',
#   'AK027257',
#   'AK027332',
#   'AK027541',
#   'AK027840',
#   'AK054623',
#   'AK054635',
#   'AK054708',
#   'AK054710',
#   'AK054726',
#   'AK054749',
#   'AK054753',
#   'AK054837',
#   'AK054845',
#   'AK054905',
#   'AK054921',
#   'AK054970',
#   'AK054972',
#   'AK054988',
#   'AK054990',
#   'AK055017',
#   'AK055055',
#   'AK055145',
#   'AK055197',
#   'AK055250',
#   'AK055254',
#   'AK055257',
#   'AK055260',
#   'AK055267',
#   'AK055272',
#   'AK055323',
#   'AK055332',
#   'AK055351',
#   'AK055364',
#   'AK055368',
#   'AK055370',
#   'AK055384',
#   'AK055386',
#   'AK055408',
#   'AK055458',
#   'AK055459',
#   'AK055533',
#   'AK055550',
#   'AK055570',
#   'AK055601',
#   'AK055623',
#   'AK055631',
#   'AK055656',
#   'AK055694',
#   'AK055712',
#   'AK055772',
#   'AK055785',
#   'AK055803',
#   'AK055811',
#   'AK055849',
#   'AK055853',
#   'AK055856',
#   'AK055876',
#   'AK055890',
#   'AK055910',
#   'AK055918',
#   'AK055932',
#   'AK055957',
#   'AK055967',
#   'AK055974',
#   'AK055980',
#   'AK055981',
#   'AK056073',
#   'AK056077',
#   'AK056081',
#   'AK056098',
#   'AK056105',
#   'AK056135',
#   'AK056182',
#   'AK056196',
#   'AK056211',
#   'AK056228',
#   'AK056246',
#   'AK056252',
#   'AK056253',
#   'AK056267',
#   'AK056351',
#   'AK056368',
#   'AK056396',
#   'AK056431',
#   'AK056432',
#   'AK056485',
#   'AK056486',
#   'AK056490',
#   'AK056505',
#   'AK056524',
#   'AK056584',
#   'AK056618',
#   'AK056623',
#   'AK056625',
#   'AK056657',
#   'AK056686',
#   'AK056689',
#   'AK056780',
#   'AK056817',
#   'AK056897',
#   'AK056973',
#   'AK056982',
#   'AK057177',
#   'AK057187',
#   'AK057188',
#   'AK057218',
#   'AK057259',
#   'AK057304',
#   'AK057316',
#   'AK057317',
#   'AK057321',
#   'AK057332',
#   'AK057379',
#   'AK057438',
#   'AK057448',
#   'AK057451',
#   'AK057455',
#   'AK057471',
#   'AK057473',
#   'AK057513',
#   'AK057515',
#   'AK057519',
#   'AK057554',
#   'AK057596',
#   'AK057604',
#   'AK057657',
#   'AK057681',
#   'AK057689',
#   'AK057719',
#   'AK057766',
#   'AK057873',
#   'AK057887',
#   'AK057897',
#   'AK057978',
#   'AK058136',
#   'AK058177',
#   'AK074396',
#   'AK074469',
#   'AK074476',
#   'AK074615',
#   'AK075019',
#   'AK075337',
#   'AK090553',
#   'AK090593',
#   'AK090604',
#   'AK090674',
#   'AK090681',
#   'AK090688',
#   'AK090700',
#   'AK090736',
#   'AK090788',
#   'AK090844',
#   'AK090854',
#   'AK090895',
#   'AK090904',
#   'AK090973',
#   'AK091028',
#   'AK091070',
#   'AK091102',
#   'AK091265',
#   'AK091275',
#   'AK091365',
#   'AK091593',
#   'AK091624',
#   'AK091688',
#   'AK091729',
#   'AK091866',
#   'AK091889',
#   'AK091906',
#   'AK091996',
#   'AK092048',
#   'AK092080',
#   'AK092087',
#   'AK092098',
#   'AK092135',
#   'AK092150',
#   'AK092251',
#   'AK092313',
#   'AK092331',
#   'AK092380',
#   'AK092451',
#   'AK092541',
#   'AK092589',
#   'AK092619',
#   'AK092965',
#   'AK093002',
#   'AK093026',
#   'AK093107',
#   'AK093114',
#   'AK093124',
#   'AK093193',
#   'AK093203',
#   'AK093205',
#   'AK093214',
#   'AK093219',
#   'AK093256',
#   'AK093264',
#   'AK093299',
#   'AK093301',
#   'AK093356',
#   'AK093362',
#   'AK093363',
#   'AK093370',
#   'AK093381',
#   'AK093403',
#   'AK093412',
#   'AK093416',
#   'AK093443',
#   'AK093513',
#   'AK093519',
#   'AK093525',
#   'AK093534',
#   'AK093551',
#   'AK093552',
#   'AK093555',
#   'AK093600',
#   'AK093758',
#   'AK093892',
#   'AK093898',
#   'AK093940',
#   'AK094117',
#   'AK094156',
#   'AK094188',
#   'AK094196',
#   'AK094280',
#   'AK094325',
#   'AK094342',
#   'AK094343',
#   'AK094352',
#   'AK094413',
#   'AK094462',
#   'AK094480',
#   'AK094525',
#   'AK094561',
#   'AK094577',
#   'AK094599',
#   'AK094611',
#   'AK094621',
#   'AK094639',
#   'AK094644',
#   'AK094674',
#   'AK094692',
#   'AK094733',
#   'AK094786',
#   'AK094818',
#   'AK094859',
#   'AK094909',
#   'AK094915',
#   'AK094916',
#   'AK094929',
#   'AK094934',
#   'AK094945',
#   'AK094963',
#   'AK094985',
#   'AK094990',
#   'AK095045',
#   'AK095057',
#   'AK095081',
#   'AK095112',
#   'AK095132',
#   'AK095151',
#   'AK095179',
#   'AK095187',
#   'AK095210',
#   'AK095221',
#   'AK095242',
#   'AK095267',
#   'AK095285',
#   'AK095310',
#   'AK095335',
#   'AK095365',
#   'AK095366',
#   'AK095439',
#   'AK095498',
#   'AK095546',
#   'AK095583',
#   'AK095618',
#   'AK095621',
#   'AK095633',
#   'AK095699',
#   'AK095700',
#   'AK095721',
#   'AK095988',
#   'AK096023',
#   'AK096066',
#   'AK096159',
#   'AK096219',
#   'AK096230',
#   'AK096233',
#   'AK096249',
#   'AK096291',
#   'AK096314',
#   'AK096329',
#   'AK096335',
#   'AK096379',
#   'AK096395',
#   'AK096475',
#   'AK096499',
#   'AK096549',
#   'AK096592',
#   'AK096622',
#   'AK096718',
#   'AK096766',
#   'AK096792',
#   'AK096803',
#   'AK096834',
#   'AK096898',
#   'AK096932',
#   'AK096976',
#   'AK096982',
#   'AK096987',
#   'AK096995',
#   'AK097012',
#   'AK097119',
#   'AK097142',
#   'AK097143',
#   'AK097161',
#   'AK097184',
#   'AK097190',
#   'AK097193',
#   'AK097242',
#   'AK097288',
#   'AK097289',
#   'AK097351',
#   'AK097370',
#   'AK097428',
#   'AK097432',
#   'AK097447',
#   'AK097453',
#   'AK097472',
#   'AK097493',
#   'AK097500',
#   'AK097527',
#   'AK097571',
#   'AK097585',
#   'AK097590',
#   'AK097618',
#   'AK097622',
#   'AK097624',
#   'AK097625',
#   'AK097658',
#   'AK097686',
#   'AK097694',
#   'AK097701',
#   'AK097702',
#   'AK097706',
#   'AK097722',
#   'AK097759',
#   'AK097787',
#   'AK097791',
#   'AK097794',
#   'AK097803',
#   'AK097814',
#   'AK097816',
#   'AK097829',
#   'AK097836',
#   'AK097853',
#   'AK097866',
#   'AK097878',
#   'AK097902',
#   'AK097910',
#   'AK097921',
#   'AK097934',
#   'AK097952',
#   'AK097957',
#   'AK098012',
#   'AK098067',
#   'AK098095',
#   'AK098198',
#   'AK098263',
#   'AK098303',
#   'AK098333',
#   'AK098438',
#   'AK098481',
#   'AK098491',
#   'AK098548',
#   'AK098560',
#   'AK098570',
#   'AK098656',
#   'AK098665',
#   'AK098705',
#   'AK098727',
#   'AK098763',
#   'AK098769',
#   'AK098783',
#   'AK122764',
#   'AK123067',
#   'AK123141',
#   'AK123177',
#   'AK123181',
#   'AK123263',
#   'AK123292',
#   'AK123298',
#   'AK123300',
#   'AK123314',
#   'AK123332',
#   'AK123393',
#   'AK123416',
#   'AK123440',
#   'AK123450',
#   'AK123459',
#   'AK123543',
#   'AK123582',
#   'AK123584',
#   'AK123617',
#   'AK123632',
#   'AK123654',
#   'AK123675',
#   'AK123758',
#   'AK123771',
#   'AK123816',
#   'AK123826',
#   'AK123834',
#   'AK123868',
#   'AK123872',
#   'AK123878',
#   'AK123889',
#   'AK123891',
#   'AK123934',
#   'AK123947',
#   'AK123976',
#   'AK123998',
#   'AK124056',
#   'AK124066',
#   'AK124121',
#   'AK124130',
#   'AK124131',
#   'AK124179',
#   'AK124194',
#   'AK124197',
#   'AK124226',
#   'AK124233',
#   'AK124262',
#   'AK124272',
#   'AK124308',
#   'AK124326',
#   'AK124327',
#   'AK124399',
#   'AK124433',
#   'AK124439',
#   'AK124465',
#   'AK124484',
#   'AK124523',
#   'AK124578',
#   'AK124673',
#   'AK124680',
#   'AK124682',
#   'AK124806',
#   'AK124820',
#   'AK124832',
#   'AK124857',
#   'AK124930',
#   'AK124939',
#   'AK124950',
#   'AK124970',
#   'AK124973',
#   'AK125001',
#   'AK125040',
#   'AK125051',
#   'AK125078',
#   'AK125128',
#   'AK125157',
#   'AK125212',
#   'AK125237',
#   'AK125257',
#   'AK125288',
#   'AK125301',
#   'AK125311',
#   'AK125333',
#   'AK125397',
#   'AK125412',
#   'AK125437',
#   'AK125463',
#   'AK125489',
#   'AK125500',
#   'AK125516',
#   'AK125532',
#   'AK125558',
#   'AK125594',
#   'AK125598',
#   'AK125599',
#   'AK125676',
#   'AK125684',
#   'AK125686',
#   'AK125699',
#   'AK125701',
#   'AK125726',
#   'AK125727',
#   'AK125737',
#   'AK125749',
#   'AK125759',
#   'AK125769',
#   'AK125821',
#   'AK125858',
#   'AK125860',
#   'AK125871',
#   'AK125955',
#   'AK125960',
#   'AK125994',
#   'AK126042',
#   'AK126075',
#   'AK126080',
#   'AK126180',
#   'AK126213',
#   'AK126225',
#   'AK126251',
#   'AK126253',
#   'AK126266',
#   'AK126278',
#   'AK126286',
#   'AK126307',
#   'AK126318',
#   'AK126334',
#   'AK126351',
#   'AK126380',
#   'AK126532',
#   'AK126539',
#   'AK126616',
#   'AK126635',
#   'AK126693',
#   'AK126717',
#   'AK126744',
#   'AK126852',
#   'AK127026',
#   'AK127048',
#   'AK127087',
#   'AK127120',
#   'AK127124',
#   'AK127179',
#   'AK127183',
#   'AK127190',
#   'AK127191',
#   'AK127224',
#   'AK127270',
#   'AK127309',
#   'AK127339',
#   'AK127378',
#   'AK127380',
#   'AK127400',
#   'AK127443',
#   'AK127472',
#   'AK127555',
#   'AK127557',
#   'AK127609',
#   'AK127697',
#   'AK127787',
#   'AK127846',
#   'AK127888',
#   'AK127919',
#   'AK127963',
#   'AK127966',
#   'AK127969',
#   'AK127974',
#   'AK128013',
#   'AK128059',
#   'AK128153',
#   'AK128202',
#   'AK128216',
#   'AK128252',
#   'AK128346',
#   'AK128361',
#   'AK128400',
#   'AK128414',
#   'AK128439',
#   'AK128486',
#   'AK128525',
#   'AK128534',
#   'AK128559',
#   'AK128563',
#   'AK128569',
#   'AK128593',
#   'AK128619',
#   'AK128652',
#   'AK128656',
#   'AK128673',
#   'AK128697',
#   'AK128707',
#   'AK128708',
#   'AK128734',
#   'AK128777',
#   'AK128833',
#   'AK128837',
#   'AK128880',
#   'AK129567',
#   'AK129672',
#   'AK129879',
#   'AK129926',
#   'AK129935',
#   'AK130076',
#   'AK130110',
#   'AK130294',
#   'AK130329',
#   'AK130400',
#   'AK130481',
#   'AK130486',
#   'AK130759',
#   'AK130765',
#   'AK130824',
#   'AK130852',
#   'AK130904',
#   'AK130911',
#   'AK131020',
#   'AK131021',
#   'AK131224',
#   'AK131325',
#   'AK131337',
#   'AK131347',
#   'AK131516',
#   'AK131520',
#   'AK172755',
#   'AK289390',
#   'AK291164',
#   'AK291611',
#   'AK291701',
#   'AK293020',
#   'AK293147',
#   'AK294004',
#   'AK294743',
#   'AK294819',
#   'AK294973',
#   'AK295617',
#   'AK295707',
#   'AK296065',
#   'AK296146',
#   'AK296148',
#   'AK296276',
#   'AK296947',
#   'AK297683',
#   'AK297919',
#   'AK298056',
#   'AK298119',
#   'AK298300',
#   'AK298596',
#   'AK299432',
#   'AK299452',
#   'AK299501',
#   'AK300387',
#   'AK300656',
#   'AK300962',
#   'AK301093',
#   'AK301549',
#   'AK301666',
#   'AK301968',
#   'AK302092',
#   'AK302306',
#   'AK302451',
#   'AK302511',
#   'AK302545',
#   'AK302694',
#   'AK302879',
#   'AK303207',
#   'AK303572',
#   'AK303607',
#   'AK304483',
#   'AK304759',
#   'AK304826',
#   'AK307150',
#   'AK307172',
#   'AK307192',
#   'AK307207',
#   'AK307233',
#   'AK307246',
#   'AK307275',
#   'AK307870',
#   'AK308309',
#   'AK308439',
#   'AK308544',
#   'AK308561',
#   'AK308605',
#   'AK308652',
#   'AK308704',
#   'AK308867',
#   'AK308944',
#   'AK308965',
#   'AK309109',
#   'AK309215',
#   'AK309255',
#   'AK309441',
#   'AK309476',
#   'AK309533',
#   'AK309717',
#   'AK309744',
#   'AK309896',
#   'AK309922',
#   'AK309988',
#   'AK310013',
#   'AK310030',
#   'AK310041',
#   'AK310046',
#   'AK310094',
#   'AK310146',
#   'AK310226',
#   'AK310228',
#   'AK310237',
#   'AK310239',
#   'AK310350',
#   'AK310441',
#   'AK310471',
#   'AK310472',
#   'AK310493',
#   'AK310526',
#   'AK310634',
#   'AK310665',
#   'AK310751',
#   'AK310794',
#   'AK310876',
#   'AK311005',
#   'AK311108',
#   'AK311113',
#   'AK311120',
#   'AK311131',
#   'AK311167',
#   'AK311212',
#   'AK311213',
#   'AK311257',
#   'AK311282',
#   'AK311291',
#   'AK311342',
#   'AK311356',
#   'AK311374',
#   'AK311380',
#   'AK311383',
#   'AK311445',
#   'AK311458',
#   'AK311497',
#   'AK311558',
#   'AK311573',
#   'AK311578',
#   'AK311660',
#   'AK313893',
#   'AK316092',
#   'AK316321',
#   'AL049415',
#   'AL049935',
#   'AL049948',
#   'AL050000',
#   'AL050085',
#   'AL050132',
#   'AL050141',
#   'AL109706',
#   'AL109718',
#   'AL109792',
#   'AL110171',
#   'AL110181',
#   'AL117485',
#   'AL122050',
#   'AL133568',
#   'AL137445',
#   'AL137522',
#   'AL137535',
#   'AL137551',
#   'AL137655',
#   'AL137752',
#   'AL157440',
#   'AL162052',
#   'AL355711',
#   'AL355732',
#   'AL357213',
#   'AL360260',
#   'AL389983',
#   'AL390170',
#   'AL831889',
#   'AL831948',
#   'AL831977',
#   'AL832007',
#   'AL832096',
#   'AL832163',
#   'AL832184',
#   'AL832212',
#   'AL832252',
#   'AL832378',
#   'AL832384',
#   'AL832439',
#   'AL832447',
#   'AL832593',
#   'AL832615',
#   'AL832737',
#   'AL832797',
#   'AL832891',
#   'AL832909',
#   'AL832937',
#   'AL833139',
#   'AL833150',
#   'AL833181',
#   'AL833346',
#   'AL833455',
#   'AL833634',
#   'AL953854.2-002',
#   'AV1S4A1N1T',
#   'AV25S1',
#   'AV2S1A1',
#   'AV30S1',
#   'AV4S1',
#   'AV8S2',
#   'AV8S2A1N1T',
#   ...],
#  'out':             HGNC              _id     _score notfound       symbol
#  query
#  5S_rRNA      NaN  ENSG00000201285  31.696995      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000274408  31.696995      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000278457  31.671925      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000266653  31.671925      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000266726  31.521670      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000280646  31.521670      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000274097  31.463816      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000265816  31.463816      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000263418  31.455236      NaN      5S_rRNA
#  5S_rRNA      NaN  ENSG00000212595  31.455236      NaN      5S_rRNA
#  5_8S_rRNA    NaN  ENSG00000276871  73.668076      NaN    5_8S_rRNA
#  5_8S_rRNA    NaN  ENSG00000283274  73.265080      NaN    5_8S_rRNA
#  5_8S_rRNA    NaN  ENSG00000275877  72.656235      NaN    5_8S_rRNA
#  5_8S_rRNA    NaN  ENSG00000278294  72.044655      NaN    5_8S_rRNA
#  5_8S_rRNA    NaN  ENSG00000283291  72.044655      NaN    5_8S_rRNA
#  5_8S_rRNA    NaN  ENSG00000283568  71.479256      NaN    5_8S_rRNA
#  6M1-18      8176            26531  11.998318      NaN       OR11A1
#  7M1-2       8246            26211   2.118735      NaN        OR2F1
#  7SK          NaN  ENSG00000276626  44.729320      NaN          7SK
#  7SK          NaN  ENSG00000266263  44.729320      NaN          7SK
#  7SK          NaN  ENSG00000264415  44.729320      NaN          7SK
#  7SK          NaN  ENSG00000274303  43.825180      NaN          7SK
#  7SK          NaN  ENSG00000202198  40.966156      NaN          7SK
#  7SK          NaN  ENSG00000271394  40.933556      NaN          7SK
#  7SK          NaN  ENSG00000265903  40.882088      NaN          7SK
#  7SK          NaN  ENSG00000265255  40.817700      NaN          7SK
#  7SK          NaN  ENSG00000275933  40.817700      NaN          7SK
#  7SK          NaN  ENSG00000274262  40.817700      NaN          7SK
#  A1BG           5                1  85.361480      NaN         A1BG
#  A1BG       37133           503538  10.995089      NaN     A1BG-AS1
#  ...          ...              ...        ...      ...          ...
#  fusion      6586            10186   2.972987      NaN         LHFP
#  fusion     10025             6018   2.962899      NaN          RLF
#  fusion     29568           375323   2.498242      NaN       LHFPL4
#  fusion     21253           222662   2.498242      NaN       LHFPL5
#  fusion     28539           284359   2.477489      NaN       IZUMO1
#  fusion      6587           340596   2.470477      NaN       LHFPL1
#  fusion      6588            10184   2.469083      NaN       LHFPL2
#  svRNAa       NaN              NaN        NaN     True          NaN
#  tRNA        7475             4553  89.609010      NaN         TRNA
#  tRNA       33249        100009601   8.182926      NaN   TRY-GTA7-1
#  tRNA       12348             7234   7.901629      NaN   TRU-TCA1-1
#  tRNA       33250        100009602   5.819855      NaN   TRY-GTA5-4
#  tRNA       16293            23437   5.098542      NaN   TRS-AGA2-3
#  tRNA        7490             4567   2.799941      NaN        TRNL1
#  tRNA        7479             4556   2.777072      NaN         TRNE
#  tRNA        7496             4573   2.765913      NaN         TRNR
#  tRNA        7481             4558   2.765913      NaN         TRNF
#  tRNA        7498             4575   2.765913      NaN        TRNS2
#  Pro        12298             7200   8.926896      NaN          TRH
#  Pro         7999            10718   8.284494      NaN         NRG3
#  Pro         9240             5473   3.338001      NaN         PPBP
#  Pro         9109             5367   3.301579      NaN         PMCH
#  Pro         8614             5074   3.091809      NaN         PAWR
#  Pro        34698        100189136   2.902789      NaN   TRP-AGG2-7
#  Pro        34734        100189172   2.902789      NaN   TRP-CGG2-1
#  Pro        34648        100189088   2.859354      NaN   TRP-TGG3-2
#  Pro        34852        100189286   2.785304      NaN   TRP-TGG1-1
#  Pro        34903        100189335   2.785304      NaN   TRP-TGG3-3
#  unknown      NaN           664629   2.618688      NaN    LOC664629
#  unknown      NaN        100093698   2.513961      NaN  GS1-600G8.3
#
#  [37031 rows x 5 columns]}

# %%
dup = df['dup']
missing = df['missing']
df = df['out']
df = df[["HGNC", "symbol"]].dropna()
df = df.reset_index().drop_duplicates(subset='query', keep='first').set_index('query').rename_axis(None)
df
# Out:
#               HGNC       symbol
# 6M1-18        8176       OR11A1
# 7M1-2         8246        OR2F1
# A1BG             5         A1BG
# A1BG-AS1     37133     A1BG-AS1
# A1CF         24086         A1CF
# A2M              7          A2M
# A2M-AS1      27057      A2M-AS1
# A2ML1        23336        A2ML1
# A2MP1            8        A2MP1
# A3GALT2      30005      A3GALT2
# A4GALT       18149       A4GALT
# A4GNT        17968        A4GNT
# AAAS         13666         AAAS
# AACS         21298         AACS
# AACSP1       18226       AACSP1
# AADAC           17        AADAC
# AADACL2      24427      AADACL2
# AADACL3      32037      AADACL3
# AADACL4      32038      AADACL4
# AADAT        17929        AADAT
# AAED1        16881        AAED1
# AAGAB        25662        AAGAB
# AAK1         19679         AAK1
# AAMDC        30205        AAMDC
# AAMP            18         AAMP
# AANAT           19        AANAT
# AAR2         15886         AAR2
# AARD         33842         AARD
# AARS            20         AARS
# AARS2        21022        AARS2
# ...            ...          ...
# ZZZ3         24523         ZZZ3
# cytochrome    7427         CYTB
# P-450         2640       CYP3A7
# (P-450AROM)   2594      CYP19A1
# open         25900     C1orf198
# reading      11171        SNURF
# frame        11171        SNURF
# contactin     2173        CNTN3
# endogenous   39060       ERV9-1
# retrovirus   39060       ERV9-1
# epsilon       2234         COPE
# IgE           5522         IGHE
# hADV14S1     12110    TRAV14DV4
# hADV29S1     12127    TRAV29DV5
# hADV36S1     12135    TRAV36DV7
# hADV38S2     12138  TRAV38-2DV8
# hCPE-R        2046        CLDN4
# hDV102S1     12263        TRDV2
# hDV103S1     12264        TRDV3
# constant...   8678      PCDHACT
# heavy         7737         NEFH
# intersectin   6184        ITSN2
# long         43984      HELLPAR
# mir-133b     31759      MIR133B
# mir-223      31603       MIR223
# mir-34       31635       MIR34A
# pp9284       11876      TMPRSS2
# septin        7729        SEPT2
# tRNA          7475         TRNA
# Pro          12298          TRH
#
# [22686 rows x 2 columns]

# %%
len(df[df.index != df.symbol])
# Out:
# 1025

# %%
missing
# Out:
# ['AB000466',
#  'AB007962',
#  'AB059369',
#  'AB062081',
#  'AB062083',
#  'AB073649',
#  'AB074160',
#  'AB074162',
#  'AB074166',
#  'AB074188',
#  'AB075489',
#  'AB075492',
#  'AB209061',
#  'AB209185',
#  'AB209315',
#  'AB209621',
#  'AB231702',
#  'AB231703',
#  'AB231705',
#  'AB231710',
#  'AB231711',
#  'AB231721',
#  'AB231722',
#  'AB231723',
#  'AB231724',
#  'AB231729',
#  'AB231731',
#  'AB231739',
#  'AB231741',
#  'AB231742',
#  'AB231761',
#  'AB231779',
#  'AB231784',
#  'AB240015',
#  'AB372727',
#  'AB429224',
#  'AB488780',
#  'AB586698',
#  '1',
#  'ADV21S1A1N',
#  'AF007147',
#  'AF020763',
#  'AF035281',
#  'AF047486',
#  'AF055024',
#  'AF063596',
#  'AF070569',
#  'AF070581',
#  'AF072097',
#  'AF075036',
#  'AF075112',
#  'AF079515',
#  'AF085962',
#  'AF085995',
#  'AF086102',
#  'AF086125',
#  'AF086126',
#  'AF086132',
#  'AF086154',
#  'AF086165',
#  'AF086184',
#  'AF086203',
#  'AF086219',
#  'AF086258',
#  'AF086285',
#  'AF086288',
#  'AF086294',
#  'AF086303',
#  'AF086346',
#  'AF086351',
#  'AF086476',
#  'AF088041',
#  'AF090102',
#  'AF090939',
#  'AF116693',
#  'AF119915',
#  'AF131837',
#  'AF143870',
#  'AF143871',
#  'AF157115',
#  'AF161365',
#  'AF161442',
#  'AF188711',
#  'AF198444',
#  'AF216583',
#  'AF258550',
#  'AF258560',
#  'AF268386',
#  'AF279775',
#  'AF279780',
#  'AF279782',
#  'AF289551',
#  'AF339801',
#  'AF339817',
#  'AF380582',
#  'AF387615',
#  'AF397448',
#  'AF401214',
#  'AF420437',
#  'AF508906',
#  'AF508907',
#  'AF520419',
#  'AF520792',
#  'AF520793',
#  'AF532840',
#  'AF548120',
#  'AJ004954',
#  'AJ011378',
#  'AJ011981',
#  'AJ276246',
#  'AJ297365',
#  'AJ420422',
#  'AJ420489',
#  'AJ420595',
#  'AJ515158',
#  'AJ606316',
#  'AJ606328',
#  'AJ606330',
#  'AJ606331',
#  'AK000154',
#  'AK000451',
#  'AK000470',
#  'AK000798',
#  'AK000807',
#  'AK000840',
#  'AK000953',
#  'AK001057',
#  'AK001351',
#  'AK001394',
#  'AK001533',
#  'AK001558',
#  'AK001582',
#  'AK001928',
#  'AK001975',
#  'AK002090',
#  'AK021537',
#  'AK021551',
#  'AK021563',
#  'AK021570',
#  'AK021664',
#  'AK021739',
#  'AK021804',
#  'AK021876',
#  'AK021888',
#  'AK021933',
#  'AK021977',
#  'AK022030',
#  'AK022382',
#  'AK022787',
#  'AK022793',
#  'AK022898',
#  'AK022914',
#  'AK022915',
#  'AK022993',
#  'AK022997',
#  'AK023033',
#  'AK023040',
#  'AK023159',
#  'AK023178',
#  'AK023304',
#  'AK023417',
#  'AK023457',
#  'AK023507',
#  'AK023515',
#  'AK023548',
#  'AK023566',
#  'AK023614',
#  'AK023627',
#  'AK023809',
#  'AK024092',
#  'AK024119',
#  'AK024134',
#  'AK024141',
#  'AK024242',
#  'AK024243',
#  'AK024248',
#  'AK024535',
#  'AK024736',
#  'AK024936',
#  'AK024998',
#  'AK025061',
#  'AK025117',
#  'AK025127',
#  'AK025140',
#  'AK025288',
#  'AK025321',
#  'AK025511',
#  'AK025664',
#  'AK025726',
#  'AK025793',
#  'AK025975',
#  'AK026244',
#  'AK026379',
#  'AK026392',
#  'AK026502',
#  'AK026512',
#  'AK026714',
#  'AK026736',
#  'AK026758',
#  'AK026777',
#  'AK026905',
#  'AK027091',
#  'AK027145',
#  'AK027190',
#  'AK027252',
#  'AK027257',
#  'AK027332',
#  'AK027541',
#  'AK027840',
#  'AK054623',
#  'AK054635',
#  'AK054708',
#  'AK054710',
#  'AK054726',
#  'AK054749',
#  'AK054753',
#  'AK054837',
#  'AK054845',
#  'AK054905',
#  'AK054921',
#  'AK054970',
#  'AK054972',
#  'AK054988',
#  'AK054990',
#  'AK055017',
#  'AK055055',
#  'AK055145',
#  'AK055197',
#  'AK055250',
#  'AK055254',
#  'AK055257',
#  'AK055260',
#  'AK055267',
#  'AK055272',
#  'AK055323',
#  'AK055332',
#  'AK055351',
#  'AK055364',
#  'AK055368',
#  'AK055370',
#  'AK055384',
#  'AK055386',
#  'AK055408',
#  'AK055458',
#  'AK055459',
#  'AK055533',
#  'AK055550',
#  'AK055570',
#  'AK055601',
#  'AK055623',
#  'AK055631',
#  'AK055656',
#  'AK055694',
#  'AK055712',
#  'AK055772',
#  'AK055785',
#  'AK055803',
#  'AK055811',
#  'AK055849',
#  'AK055853',
#  'AK055856',
#  'AK055876',
#  'AK055890',
#  'AK055910',
#  'AK055918',
#  'AK055932',
#  'AK055957',
#  'AK055967',
#  'AK055974',
#  'AK055980',
#  'AK055981',
#  'AK056073',
#  'AK056077',
#  'AK056081',
#  'AK056098',
#  'AK056105',
#  'AK056135',
#  'AK056182',
#  'AK056196',
#  'AK056211',
#  'AK056228',
#  'AK056246',
#  'AK056252',
#  'AK056253',
#  'AK056267',
#  'AK056351',
#  'AK056368',
#  'AK056396',
#  'AK056431',
#  'AK056432',
#  'AK056485',
#  'AK056486',
#  'AK056490',
#  'AK056505',
#  'AK056524',
#  'AK056584',
#  'AK056618',
#  'AK056623',
#  'AK056625',
#  'AK056657',
#  'AK056686',
#  'AK056689',
#  'AK056780',
#  'AK056817',
#  'AK056897',
#  'AK056973',
#  'AK056982',
#  'AK057177',
#  'AK057187',
#  'AK057188',
#  'AK057218',
#  'AK057259',
#  'AK057304',
#  'AK057316',
#  'AK057317',
#  'AK057321',
#  'AK057332',
#  'AK057379',
#  'AK057438',
#  'AK057448',
#  'AK057451',
#  'AK057455',
#  'AK057471',
#  'AK057473',
#  'AK057513',
#  'AK057515',
#  'AK057519',
#  'AK057554',
#  'AK057596',
#  'AK057604',
#  'AK057657',
#  'AK057681',
#  'AK057689',
#  'AK057719',
#  'AK057766',
#  'AK057873',
#  'AK057887',
#  'AK057897',
#  'AK057978',
#  'AK058136',
#  'AK058177',
#  'AK074396',
#  'AK074469',
#  'AK074476',
#  'AK074615',
#  'AK075019',
#  'AK075337',
#  'AK090553',
#  'AK090593',
#  'AK090604',
#  'AK090674',
#  'AK090681',
#  'AK090688',
#  'AK090700',
#  'AK090736',
#  'AK090788',
#  'AK090844',
#  'AK090854',
#  'AK090895',
#  'AK090904',
#  'AK090973',
#  'AK091028',
#  'AK091070',
#  'AK091102',
#  'AK091265',
#  'AK091275',
#  'AK091365',
#  'AK091593',
#  'AK091624',
#  'AK091688',
#  'AK091729',
#  'AK091866',
#  'AK091889',
#  'AK091906',
#  'AK091996',
#  'AK092048',
#  'AK092080',
#  'AK092087',
#  'AK092098',
#  'AK092135',
#  'AK092150',
#  'AK092251',
#  'AK092313',
#  'AK092331',
#  'AK092380',
#  'AK092451',
#  'AK092541',
#  'AK092589',
#  'AK092619',
#  'AK092965',
#  'AK093002',
#  'AK093026',
#  'AK093107',
#  'AK093114',
#  'AK093124',
#  'AK093193',
#  'AK093203',
#  'AK093205',
#  'AK093214',
#  'AK093219',
#  'AK093256',
#  'AK093264',
#  'AK093299',
#  'AK093301',
#  'AK093356',
#  'AK093362',
#  'AK093363',
#  'AK093370',
#  'AK093381',
#  'AK093403',
#  'AK093412',
#  'AK093416',
#  'AK093443',
#  'AK093513',
#  'AK093519',
#  'AK093525',
#  'AK093534',
#  'AK093551',
#  'AK093552',
#  'AK093555',
#  'AK093600',
#  'AK093758',
#  'AK093892',
#  'AK093898',
#  'AK093940',
#  'AK094117',
#  'AK094156',
#  'AK094188',
#  'AK094196',
#  'AK094280',
#  'AK094325',
#  'AK094342',
#  'AK094343',
#  'AK094352',
#  'AK094413',
#  'AK094462',
#  'AK094480',
#  'AK094525',
#  'AK094561',
#  'AK094577',
#  'AK094599',
#  'AK094611',
#  'AK094621',
#  'AK094639',
#  'AK094644',
#  'AK094674',
#  'AK094692',
#  'AK094733',
#  'AK094786',
#  'AK094818',
#  'AK094859',
#  'AK094909',
#  'AK094915',
#  'AK094916',
#  'AK094929',
#  'AK094934',
#  'AK094945',
#  'AK094963',
#  'AK094985',
#  'AK094990',
#  'AK095045',
#  'AK095057',
#  'AK095081',
#  'AK095112',
#  'AK095132',
#  'AK095151',
#  'AK095179',
#  'AK095187',
#  'AK095210',
#  'AK095221',
#  'AK095242',
#  'AK095267',
#  'AK095285',
#  'AK095310',
#  'AK095335',
#  'AK095365',
#  'AK095366',
#  'AK095439',
#  'AK095498',
#  'AK095546',
#  'AK095583',
#  'AK095618',
#  'AK095621',
#  'AK095633',
#  'AK095699',
#  'AK095700',
#  'AK095721',
#  'AK095988',
#  'AK096023',
#  'AK096066',
#  'AK096159',
#  'AK096219',
#  'AK096230',
#  'AK096233',
#  'AK096249',
#  'AK096291',
#  'AK096314',
#  'AK096329',
#  'AK096335',
#  'AK096379',
#  'AK096395',
#  'AK096475',
#  'AK096499',
#  'AK096549',
#  'AK096592',
#  'AK096622',
#  'AK096718',
#  'AK096766',
#  'AK096792',
#  'AK096803',
#  'AK096834',
#  'AK096898',
#  'AK096932',
#  'AK096976',
#  'AK096982',
#  'AK096987',
#  'AK096995',
#  'AK097012',
#  'AK097119',
#  'AK097142',
#  'AK097143',
#  'AK097161',
#  'AK097184',
#  'AK097190',
#  'AK097193',
#  'AK097242',
#  'AK097288',
#  'AK097289',
#  'AK097351',
#  'AK097370',
#  'AK097428',
#  'AK097432',
#  'AK097447',
#  'AK097453',
#  'AK097472',
#  'AK097493',
#  'AK097500',
#  'AK097527',
#  'AK097571',
#  'AK097585',
#  'AK097590',
#  'AK097618',
#  'AK097622',
#  'AK097624',
#  'AK097625',
#  'AK097658',
#  'AK097686',
#  'AK097694',
#  'AK097701',
#  'AK097702',
#  'AK097706',
#  'AK097722',
#  'AK097759',
#  'AK097787',
#  'AK097791',
#  'AK097794',
#  'AK097803',
#  'AK097814',
#  'AK097816',
#  'AK097829',
#  'AK097836',
#  'AK097853',
#  'AK097866',
#  'AK097878',
#  'AK097902',
#  'AK097910',
#  'AK097921',
#  'AK097934',
#  'AK097952',
#  'AK097957',
#  'AK098012',
#  'AK098067',
#  'AK098095',
#  'AK098198',
#  'AK098263',
#  'AK098303',
#  'AK098333',
#  'AK098438',
#  'AK098481',
#  'AK098491',
#  'AK098548',
#  'AK098560',
#  'AK098570',
#  'AK098656',
#  'AK098665',
#  'AK098705',
#  'AK098727',
#  'AK098763',
#  'AK098769',
#  'AK098783',
#  'AK122764',
#  'AK123067',
#  'AK123141',
#  'AK123177',
#  'AK123181',
#  'AK123263',
#  'AK123292',
#  'AK123298',
#  'AK123300',
#  'AK123314',
#  'AK123332',
#  'AK123393',
#  'AK123416',
#  'AK123440',
#  'AK123450',
#  'AK123459',
#  'AK123543',
#  'AK123582',
#  'AK123584',
#  'AK123617',
#  'AK123632',
#  'AK123654',
#  'AK123675',
#  'AK123758',
#  'AK123771',
#  'AK123816',
#  'AK123826',
#  'AK123834',
#  'AK123868',
#  'AK123872',
#  'AK123878',
#  'AK123889',
#  'AK123891',
#  'AK123934',
#  'AK123947',
#  'AK123976',
#  'AK123998',
#  'AK124056',
#  'AK124066',
#  'AK124121',
#  'AK124130',
#  'AK124131',
#  'AK124179',
#  'AK124194',
#  'AK124197',
#  'AK124226',
#  'AK124233',
#  'AK124262',
#  'AK124272',
#  'AK124308',
#  'AK124326',
#  'AK124327',
#  'AK124399',
#  'AK124433',
#  'AK124439',
#  'AK124465',
#  'AK124484',
#  'AK124523',
#  'AK124578',
#  'AK124673',
#  'AK124680',
#  'AK124682',
#  'AK124806',
#  'AK124820',
#  'AK124832',
#  'AK124857',
#  'AK124930',
#  'AK124939',
#  'AK124950',
#  'AK124970',
#  'AK124973',
#  'AK125001',
#  'AK125040',
#  'AK125051',
#  'AK125078',
#  'AK125128',
#  'AK125157',
#  'AK125212',
#  'AK125237',
#  'AK125257',
#  'AK125288',
#  'AK125301',
#  'AK125311',
#  'AK125333',
#  'AK125397',
#  'AK125412',
#  'AK125437',
#  'AK125463',
#  'AK125489',
#  'AK125500',
#  'AK125516',
#  'AK125532',
#  'AK125558',
#  'AK125594',
#  'AK125598',
#  'AK125599',
#  'AK125676',
#  'AK125684',
#  'AK125686',
#  'AK125699',
#  'AK125701',
#  'AK125726',
#  'AK125727',
#  'AK125737',
#  'AK125749',
#  'AK125759',
#  'AK125769',
#  'AK125821',
#  'AK125858',
#  'AK125860',
#  'AK125871',
#  'AK125955',
#  'AK125960',
#  'AK125994',
#  'AK126042',
#  'AK126075',
#  'AK126080',
#  'AK126180',
#  'AK126213',
#  'AK126225',
#  'AK126251',
#  'AK126253',
#  'AK126266',
#  'AK126278',
#  'AK126286',
#  'AK126307',
#  'AK126318',
#  'AK126334',
#  'AK126351',
#  'AK126380',
#  'AK126532',
#  'AK126539',
#  'AK126616',
#  'AK126635',
#  'AK126693',
#  'AK126717',
#  'AK126744',
#  'AK126852',
#  'AK127026',
#  'AK127048',
#  'AK127087',
#  'AK127120',
#  'AK127124',
#  'AK127179',
#  'AK127183',
#  'AK127190',
#  'AK127191',
#  'AK127224',
#  'AK127270',
#  'AK127309',
#  'AK127339',
#  'AK127378',
#  'AK127380',
#  'AK127400',
#  'AK127443',
#  'AK127472',
#  'AK127555',
#  'AK127557',
#  'AK127609',
#  'AK127697',
#  'AK127787',
#  'AK127846',
#  'AK127888',
#  'AK127919',
#  'AK127963',
#  'AK127966',
#  'AK127969',
#  'AK127974',
#  'AK128013',
#  'AK128059',
#  'AK128153',
#  'AK128202',
#  'AK128216',
#  'AK128252',
#  'AK128346',
#  'AK128361',
#  'AK128400',
#  'AK128414',
#  'AK128439',
#  'AK128486',
#  'AK128525',
#  'AK128534',
#  'AK128559',
#  'AK128563',
#  'AK128569',
#  'AK128593',
#  'AK128619',
#  'AK128652',
#  'AK128656',
#  'AK128673',
#  'AK128697',
#  'AK128707',
#  'AK128708',
#  'AK128734',
#  'AK128777',
#  'AK128833',
#  'AK128837',
#  'AK128880',
#  'AK129567',
#  'AK129672',
#  'AK129879',
#  'AK129926',
#  'AK129935',
#  'AK130076',
#  'AK130110',
#  'AK130294',
#  'AK130329',
#  'AK130400',
#  'AK130481',
#  'AK130486',
#  'AK130759',
#  'AK130765',
#  'AK130824',
#  'AK130852',
#  'AK130904',
#  'AK130911',
#  'AK131020',
#  'AK131021',
#  'AK131224',
#  'AK131325',
#  'AK131337',
#  'AK131347',
#  'AK131516',
#  'AK131520',
#  'AK172755',
#  'AK289390',
#  'AK291164',
#  'AK291611',
#  'AK291701',
#  'AK293020',
#  'AK293147',
#  'AK294004',
#  'AK294743',
#  'AK294819',
#  'AK294973',
#  'AK295617',
#  'AK295707',
#  'AK296065',
#  'AK296146',
#  'AK296148',
#  'AK296276',
#  'AK296947',
#  'AK297683',
#  'AK297919',
#  'AK298056',
#  'AK298119',
#  'AK298300',
#  'AK298596',
#  'AK299432',
#  'AK299452',
#  'AK299501',
#  'AK300387',
#  'AK300656',
#  'AK300962',
#  'AK301093',
#  'AK301549',
#  'AK301666',
#  'AK301968',
#  'AK302092',
#  'AK302306',
#  'AK302451',
#  'AK302511',
#  'AK302545',
#  'AK302694',
#  'AK302879',
#  'AK303207',
#  'AK303572',
#  'AK303607',
#  'AK304483',
#  'AK304759',
#  'AK304826',
#  'AK307150',
#  'AK307172',
#  'AK307192',
#  'AK307207',
#  'AK307233',
#  'AK307246',
#  'AK307275',
#  'AK307870',
#  'AK308309',
#  'AK308439',
#  'AK308544',
#  'AK308561',
#  'AK308605',
#  'AK308652',
#  'AK308704',
#  'AK308867',
#  'AK308944',
#  'AK308965',
#  'AK309109',
#  'AK309215',
#  'AK309255',
#  'AK309441',
#  'AK309476',
#  'AK309533',
#  'AK309717',
#  'AK309744',
#  'AK309896',
#  'AK309922',
#  'AK309988',
#  'AK310013',
#  'AK310030',
#  'AK310041',
#  'AK310046',
#  'AK310094',
#  'AK310146',
#  'AK310226',
#  'AK310228',
#  'AK310237',
#  'AK310239',
#  'AK310350',
#  'AK310441',
#  'AK310471',
#  'AK310472',
#  'AK310493',
#  'AK310526',
#  'AK310634',
#  'AK310665',
#  'AK310751',
#  'AK310794',
#  'AK310876',
#  'AK311005',
#  'AK311108',
#  'AK311113',
#  'AK311120',
#  'AK311131',
#  'AK311167',
#  'AK311212',
#  'AK311213',
#  'AK311257',
#  'AK311282',
#  'AK311291',
#  'AK311342',
#  'AK311356',
#  'AK311374',
#  'AK311380',
#  'AK311383',
#  'AK311445',
#  'AK311458',
#  'AK311497',
#  'AK311558',
#  'AK311573',
#  'AK311578',
#  'AK311660',
#  'AK313893',
#  'AK316092',
#  'AK316321',
#  'AL049415',
#  'AL049935',
#  'AL049948',
#  'AL050000',
#  'AL050085',
#  'AL050132',
#  'AL050141',
#  'AL109706',
#  'AL109718',
#  'AL109792',
#  'AL110171',
#  'AL110181',
#  'AL117485',
#  'AL122050',
#  'AL133568',
#  'AL137445',
#  'AL137522',
#  'AL137535',
#  'AL137551',
#  'AL137655',
#  'AL137752',
#  'AL157440',
#  'AL162052',
#  'AL355711',
#  'AL355732',
#  'AL357213',
#  'AL360260',
#  'AL389983',
#  'AL390170',
#  'AL831889',
#  'AL831948',
#  'AL831977',
#  'AL832007',
#  'AL832096',
#  'AL832163',
#  'AL832184',
#  'AL832212',
#  'AL832252',
#  'AL832378',
#  'AL832384',
#  'AL832439',
#  'AL832447',
#  'AL832593',
#  'AL832615',
#  'AL832737',
#  'AL832797',
#  'AL832891',
#  'AL832909',
#  'AL832937',
#  'AL833139',
#  'AL833150',
#  'AL833181',
#  'AL833346',
#  'AL833455',
#  'AL833634',
#  'AL953854.2-002',
#  'AV1S4A1N1T',
#  'AV25S1',
#  'AV2S1A1',
#  'AV30S1',
#  'AV4S1',
#  'AV8S2',
#  'AV8S2A1N1T',
#  ...]

# %%
reference = reference.merge(df, how='left', left_on='geneName', right_index=True)
reference.head()
# Out:
#   geneName        ucID chrom geneStrand  geneStart  geneEnd   HGNC   symbol
# 0  DDX11L1  uc001aaa.3  chr1          +      11873    14409  37102  DDX11L1
# 1  DDX11L1  uc010nxr.1  chr1          +      11873    14409  37102  DDX11L1
# 2  DDX11L1  uc010nxq.1  chr1          +      11873    14409  37102  DDX11L1
# 3   WASH7P  uc009vis.3  chr1          -      14361    16765  38034   WASH7P
# 4   WASH7P  uc009vjc.1  chr1          -      16857    17751  38034   WASH7P

# %%
reference.symbol = reference.symbol.fillna(reference.geneName)

# %%
del reference['geneName']
reference.rename(columns={'symbol': 'geneName'}, inplace=True)
reference.head()
# Out:
#          ucID chrom geneStrand  geneStart  geneEnd   HGNC geneName
# 0  uc001aaa.3  chr1          +      11873    14409  37102  DDX11L1
# 1  uc010nxr.1  chr1          +      11873    14409  37102  DDX11L1
# 2  uc010nxq.1  chr1          +      11873    14409  37102  DDX11L1
# 3  uc009vis.3  chr1          -      14361    16765  38034   WASH7P
# 4  uc009vjc.1  chr1          -      16857    17751  38034   WASH7P

# %%
reference = reference[['geneName', 'chrom', 'geneStrand', 'geneStart', 'geneEnd']]
reference.head()
# Out:
#   geneName chrom geneStrand  geneStart  geneEnd
# 0  DDX11L1  chr1          +      11873    14409
# 1  DDX11L1  chr1          +      11873    14409
# 2  DDX11L1  chr1          +      11873    14409
# 3   WASH7P  chr1          -      14361    16765
# 4   WASH7P  chr1          -      16857    17751

# %%
len(reference)
# Out:
# 82960

# %%
len(reference.drop_duplicates())
# Out:
# 60840

# %%
reference.drop_duplicates(inplace=True)
# Out:
# /Users/alex/Documents/GarNet/venv/lib/python3.6/site-packages/pandas/util/decorators.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return func(*args, **kwargs)

# %%
reference.to_csv('../example_data/reference.normalized.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part II: Constructing a motifs file
#
# Important! I've already normalized the MotifMap file, so I won't do it here. If you're running this again, make sure to normalize first, or use the normalized file I created!

# %%
def parse_motifs_file(motifs_file):
    """
    Parse the MotifMap BED file listing Transcription Factor Binding Motifs in the genome

    Arguments:
        motifs_file (string or FILE): file procured from MotifMap with full list of TF binding sites in the genome

    Returns:
        dataframe: motif dataframe
    """

    motif_fieldnames = ["ZScore","FDR_lower","name","orientation","chrom","LOD","strand","start","realhits","cid","FDR","NLOD","BBLS","stop","medianhits","accession","FDR_upper","BLS","stdevhits"]

    motif_dataframe = pd.read_csv(motifs_file, delimiter='\t', names=motif_fieldnames)

    motif_dataframe.rename(index=str, columns={"start":"motifStart", "stop":"motifEnd", "FDR":"motifScore", "strand":"motifStrand", "name":"motifName"}, inplace=True)

    return motif_dataframe

# %%
motifs = parse_motifs_file(motifs_file)
motifs.head()
# Out:
#      ZScore  FDR_lower motifName  orientation  chrom        LOD motifStrand  \
# 0  6.434480        0.0      RFX1            1  chr17  29.355633           +
# 1  6.430004        0.0      RFX1           -1  chr17  29.320824           -
# 2  6.368495        0.0      RFX1           -1   chr5  28.842535           -
# 3  6.364415        0.0      RFX1            1   chr5  28.810813           +
# 4  6.353193        0.0      RFX1            1   chr7  28.723547           +
#
#    motifStart  realhits  cid  motifScore      NLOD      BBLS   motifEnd  \
# 0    58239126         1    1         0.0  0.992106  1.763390   58239144
# 1    58239126         2    2         0.0  0.991646  1.763377   58239144
# 2    63404689         3    3         0.0  0.985325  0.635808   63404707
# 3    63404689         4    4         0.0  0.984906  0.635796   63404707
# 4   128800229         2    5         0.0  0.983752  1.815382  128800247
#
#    medianhits accession  FDR_upper       BLS  stdevhits
# 0         0.0  LM1_RFX1        0.0  3.349127        0.0
# 1         0.0  LM1_RFX1        0.0  3.349127        0.0
# 2         0.0  LM1_RFX1        0.0  2.725784        0.0
# 3         0.0  LM1_RFX1        0.0  2.725784        0.0
# 4         0.0  LM1_RFX1        0.0  4.027027        0.0

# %%
motifs = motifs[['motifName', 'chrom', 'motifStrand', 'motifStart', 'motifEnd', 'motifScore']]
motifs.head()
# Out:
#   motifName  chrom motifStrand  motifStart   motifEnd  motifScore
# 0      RFX1  chr17           +    58239126   58239144         0.0
# 1      RFX1  chr17           -    58239126   58239144         0.0
# 2      RFX1   chr5           -    63404689   63404707         0.0
# 3      RFX1   chr5           +    63404689   63404707         0.0
# 4      RFX1   chr7           +   128800229  128800247         0.0

# %%
len(motifs)
# Out:
# 17309990

# %%
len(motifs.drop_duplicates())
# Out:
# 17301513

# %%
motifs = motifs.drop_duplicates()

# %%
motifs.to_csv('../example_data/motifmap.normalized.cleaned.tsv', sep='\t', index=False, header=True)

# %% [markdown]
# # Part III: Merging genes and motifs

# %%
reference = pd.read_csv('../example_data/reference.normalized.tsv', sep='\t')
motifs = pd.read_csv('../example_data/motifmap.normalized.cleaned.tsv', sep='\t')

# %%
reference.head()
# Out:
#   geneName chrom geneStrand  geneStart  geneEnd
# 0  DDX11L1  chr1          +      11873    14409
# 1   WASH7P  chr1          -      14361    16765
# 2   WASH7P  chr1          -      16857    17751
# 3   WASH7P  chr1          -      15795    18061
# 4   WASH7P  chr1          -      14361    19759

# %%
motifs.head()
# Out:
#   motifName  chrom motifStrand  motifStart   motifEnd  motifScore
# 0      RFX1  chr17           +    58239126   58239144         0.0
# 1      RFX1  chr17           -    58239126   58239144         0.0
# 2      RFX1   chr5           -    63404689   63404707         0.0
# 3      RFX1   chr5           +    63404689   63404707         0.0
# 4      RFX1   chr7           +   128800229  128800247         0.0

# %%
import sys
sys.path.append("/Users/alex/Documents/GarNet/src/")
from garnet import *

# %%
reference = group_by_chromosome(reference)
motifs = group_by_chromosome(motifs)

# %%
options = {'upstream_window': 10000, 'downstream_window': 10000, 'tss': False}
reference = {chrom: IntervalTree_from_reference(genes, options) for chrom, genes in reference.items()}
motifs = {chrom: IntervalTree_from_motifs(chromosome_motifs) for chrom, chromosome_motifs in motifs.items()}

# %%
motifs_with_associated_genes = intersection_of_dict_of_intervaltree(motifs, reference)
# Out:
# 10:33:07 - GarNet: INFO - Computing intersection operation of IntervalTrees for each chromosome...

# %%
motifs_and_genes = [{**motif, **gene} for motif, gene in motifs_with_associated_genes]
motifs_and_genes = pd.DataFrame.from_records(motifs_and_genes)
motifs_and_genes.head()
# Out:
#   chrom   geneEnd geneName  geneStart geneStrand  motifEnd motifName  \
# 0  chrY   5610264  PCDH11Y    4924130          +   5409966    HMG IY
# 1  chrY  15592550      UTY   15360258          -  15522705      IRF8
# 2  chrY  15592550      UTY   15434981          -  15522705      IRF8
# 3  chrY  15592550      UTY   15435434          -  15522705      IRF8
# 4  chrY  15592550      UTY   15409388          -  15522705      IRF8
#
#    motifScore  motifStart motifStrand
# 0    0.216509     5409959           +
# 1    0.379428    15522698           -
# 2    0.379428    15522698           -
# 3    0.379428    15522698           -
# 4    0.379428    15522698           -

# %%
motifs_and_genes = motifs_and_genes[['chrom','motifName','motifStrand','motifStart','motifEnd','motifScore','geneName','geneStart','geneEnd','geneStrand']]
motifs_and_genes
# Out:
#          chrom   motifName motifStrand  motifStart   motifEnd  motifScore  \
# 0         chrY      HMG IY           +     5409959    5409966    0.216509
# 1         chrY        IRF8           -    15522698   15522705    0.379428
# 2         chrY        IRF8           -    15522698   15522705    0.379428
# 3         chrY        IRF8           -    15522698   15522705    0.379428
# 4         chrY        IRF8           -    15522698   15522705    0.379428
# 5         chrY        IRF8           -    15522698   15522705    0.379428
# 6         chrY        IRF8           -    15522698   15522705    0.379428
# 7         chrY        IRF8           -    15522698   15522705    0.379428
# 8         chrY        IRF8           -    15522698   15522705    0.379428
# 9         chrY        IRF8           -    15522698   15522705    0.379428
# 10        chrY        IRF1           +      548885     548892    0.667866
# 11        chrY        IRF1           +      548885     548892    0.667866
# 12        chrY       CAMK4           +     5411345    5411353    0.108441
# 13        chrY        HBP1           -     4901961    4901970    0.818505
# 14        chrY        HBP1           -     4901961    4901970    0.818505
# 15        chrY        TCF3           -     5382222    5382230    0.003906
# 16        chrY        TCF3           -     5382222    5382230    0.003906
# 17        chrY        LEF1           -     5315753    5315759    0.395595
# 18        chrY        PDX1           +     7609895    7609901    1.000000
# 19        chrY         DBP           +    59273958   59273965    0.882641
# 20        chrY        SPIB           -    59217774   59217781    0.778836
# 21        chrY       NR4A2           +     5336647    5336654    0.068197
# 22        chrY    MZF1_1-4           +    59330167   59330173    0.586514
# 23        chrY    MZF1_1-4           +    59330167   59330173    0.586514
# 24        chrY        LEF1           -     5139562    5139568    0.407063
# 25        chrY        PDX1           -     5398506    5398512    1.000000
# 26        chrY  GABP-alpha           +     5409415    5409421    0.632016
# 27        chrY         CRX           +    14884943   14884949    1.000000
# 28        chrY         CRX           +    14884943   14884949    1.000000
# 29        chrY        ETS1           +     5409415    5409421    1.000000
# ...        ...         ...         ...         ...        ...         ...
# 28318761  chr5        MAFB           +    78122577   78122583    0.512043
# 28318762  chr5    MZF1_1-4           -    49976417   49976423    0.516799
# 28318763  chr5    MZF1_1-4           -    49976417   49976423    0.516799
# 28318764  chr5    MZF1_1-4           +   113774161  113774167    0.403301
# 28318765  chr5    MZF1_1-4           +   113774161  113774167    0.403301
# 28318766  chr5    MZF1_1-4           +   113774161  113774167    0.403301
# 28318767  chr5        PDX1           -    59118788   59118794    1.000000
# 28318768  chr5        PDX1           -    59118788   59118794    1.000000
# 28318769  chr5         CRX           -    90003641   90003647    1.000000
# 28318770  chr5         CRX           -    90003641   90003647    1.000000
# 28318771  chr5         TBP           -   134426597  134426604    1.000000
# 28318772  chr5         SRF           -    58502271   58502285    0.301541
# 28318773  chr5         SRF           -    58502271   58502285    0.301541
# 28318774  chr5         SRF           -    58502271   58502285    0.301541
# 28318775  chr5         SRF           -    58502271   58502285    0.301541
# 28318776  chr5         SRF           -    58502271   58502285    0.301541
# 28318777  chr5         SRF           -    58502271   58502285    0.301541
# 28318778  chr5         SRF           -    58502271   58502285    0.301541
# 28318779  chr5         SRF           -    58502271   58502285    0.301541
# 28318780  chr5      HMG IY           +   109210113  109210120    0.114498
# 28318781  chr5      HMG IY           +   109210113  109210120    0.114498
# 28318782  chr5         TBP           +   156133889  156133896    1.000000
# 28318783  chr5         TBP           +   156133889  156133896    1.000000
# 28318784  chr5      NFATC1           -    88082945   88082952    0.286907
# 28318785  chr5      NFATC1           -    88082945   88082952    0.286907
# 28318786  chr5      NFATC1           -    88082945   88082952    0.286907
# 28318787  chr5     Neuro D           -    75948382   75948388    0.007722
# 28318788  chr5     Neuro D           -    75948382   75948388    0.007722
# 28318789  chr5     Neuro D           -    75948382   75948388    0.007722
# 28318790  chr5     Neuro D           -    75948382   75948388    0.007722
#
#               geneName    geneEnd  geneStart geneStrand
# 0              PCDH11Y    5610264    4924130          +
# 1                  UTY   15592550   15360258          -
# 2                  UTY   15592550   15434981          -
# 3                  UTY   15592550   15435434          -
# 4                  UTY   15592550   15409388          -
# 5                  UTY   15522993   15434913          -
# 6                  UTY   15592550   15447442          -
# 7                  UTY   15592550   15434913          -
# 8                  UTY   15592550   15434947          -
# 9                  UTY   15582109   15434913          -
# 10                SHOX     570146     535078          +
# 11                SHOX     557558     535078          +
# 12             PCDH11Y    5610264    4924130          +
# 13             PCDH11Y    4973485    4868266          +
# 14             PCDH11Y    4968748    4868266          +
# 15             PCDH11Y    5610264    4924130          +
# 16            CS706497    5378339    5378252          +
# 17             PCDH11Y    5610264    4924130          +
# 18            BC041884    7677302    7610635          -
# 19               VAMP7   59276439   59213948          +
# 20               VAMP7   59276439   59213948          +
# 21             PCDH11Y    5610264    4924130          +
# 22                IL9R   59343488   59330251          +
# 23                IL9R   59340490   59330251          +
# 24             PCDH11Y    5610264    4924130          +
# 25             PCDH11Y    5610264    4924130          +
# 26             PCDH11Y    5610264    4924130          +
# 27               USP9Y   14972768   14821320          +
# 28               USP9Y   14972768   14813159          +
# 29             PCDH11Y    5610264    4924130          +
# ...                ...        ...        ...        ...
# 28318761          ARSB   78281766   78111333          -
# 28318762         PARP8   50142356   49961732          +
# 28318763         PARP8   50142356   49962771          +
# 28318764         KCNN2  113832197  113769226          +
# 28318765         KCNN2  113832197  113698015          +
# 28318766      AK097686  113805508  113783114          -
# 28318767         PDE4D   59783925   58264865          -
# 28318768         PDE4D   59189621   58264865          -
# 28318769        ADGRV1   90460033   89854616          +
# 28318770        ADGRV1   90055782   89989706          +
# 28318771  LOC100996485  134680370  134368969          +
# 28318772         PDE4D   59783925   58264865          -
# 28318773         PDE4D   59189621   58264865          -
# 28318774         PDE4D   59064438   58264865          -
# 28318775         PDE4D   58652727   58264865          -
# 28318776         PDE4D   58511794   58289198          -
# 28318777         PDE4D   58571945   58264865          -
# 28318778         PDE4D   59064438   58452920          -
# 28318779         PDE4D   58882324   58264865          -
# 28318780  LOC100289673  109221200  109218882          +
# 28318781        MAN2A1  109203429  109025155          +
# 28318782          SGCD  156185070  155753766          +
# 28318783          SGCD  156194798  155753766          +
# 28318784         MEF2C   88199922   88014057          -
# 28318785         MEF2C   88119744   88014057          -
# 28318786         MEF2C   88179283   88014057          -
# 28318787        IQGAP2   76003957   75699148          +
# 28318788        IQGAP2   76003957   75904919          +
# 28318789        IQGAP2   76003957   75904943          +
# 28318790        IQGAP2   75967808   75904919          +
#
# [28318791 rows x 10 columns]

# %%
motifs_and_genes['motif_to_gene_distance'] = motifs_and_genes['motifStart'] - motifs_and_genes['geneStart']
motifs_and_genes.head()
# Out:
#   chrom motifName motifStrand  motifStart  motifEnd  motifScore geneName  \
# 0  chrY    HMG IY           +     5409959   5409966    0.216509  PCDH11Y
# 1  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 2  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 3  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 4  chrY      IRF8           -    15522698  15522705    0.379428      UTY
#
#     geneEnd  geneStart geneStrand  motif_to_gene_distance
# 0   5610264    4924130          +                  485829
# 1  15592550   15360258          -                  162440
# 2  15592550   15434981          -                   87717
# 3  15592550   15435434          -                   87264
# 4  15592550   15409388          -                  113310

# %%
motifs_and_genes.to_csv('../example_data/intersection.tsv', sep='\t', header=True, index=False)

# %% [markdown]
# # Part IV: Constructing a database

# %%
motifs_and_genes = pd.read_csv('../example_data/intersection.tsv', sep='\t')
motifs_and_genes.head()
# Out:
#   chrom motifName motifStrand  motifStart  motifEnd  motifScore geneName  \
# 0  chrY    HMG IY           +     5409959   5409966    0.216509  PCDH11Y
# 1  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 2  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 3  chrY      IRF8           -    15522698  15522705    0.379428      UTY
# 4  chrY      IRF8           -    15522698  15522705    0.379428      UTY
#
#    geneStart   geneEnd geneStrand  motif_to_gene_distance
# 0    4924130   5610264          +                  485829
# 1   15360258  15592550          -                  162440
# 2   15434981  15592550          -                   87717
# 3   15435434  15592550          -                   87264
# 4   15409388  15592550          -                  113310

# %%
GarNetDB = sqlite3.connect('../example_data/garnetDB.sql')
motifs_and_genes.to_sql('garnetdb', GarNetDB, if_exists="replace")

# %%
GarNetDB.execute("CREATE INDEX chr_start_stop on garnetdb(chrom, motifStart, motifEnd);")

GarNetDB.commit()
GarNetDB.close()

# %% [markdown]
# # Part V: Test if it works

# %%
GarNetDB = sqlite3.connect('../example_data/garnetDB.sql')

# %%
peaks = parse_peaks_file('/Users/alex/Documents/GarNet/example_data/A549_FOXA1_broadPeak.bed')
peaks.head()
# Out:
#   chrom  peakStart  peakEnd peakName  peakScore peakStrand  thickStart  \
# 0  chr1    4709051  4709736    peak1        114          .      188.76
# 1  chr1    5507616  5507816    peak2         65          .      107.70
# 2  chr1    7363480  7363851    peak3        224          .      370.93
# 3  chr1    7777806  7778092    peak4         79          .      130.74
# 4  chr1    8064603  8065661    peak5        164          .      272.40
#
#    thickEnd  itemRgb  blockCount  blockSizes  blockStarts
# 0        -1       -1         NaN         NaN          NaN
# 1        -1       -1         NaN         NaN          NaN
# 2        -1       -1         NaN         NaN          NaN
# 3        -1       -1         NaN         NaN          NaN
# 4        -1       -1         NaN         NaN          NaN

# %%
peaks = peaks[['peakName', 'chrom', 'peakStart', 'peakEnd', 'peakScore']]
peaks.head()
# Out:
#   peakName chrom  peakStart  peakEnd  peakScore
# 0    peak1  chr1    4709051  4709736        114
# 1    peak2  chr1    5507616  5507816         65
# 2    peak3  chr1    7363480  7363851        224
# 3    peak4  chr1    7777806  7778092         79
# 4    peak5  chr1    8064603  8065661        164

# %%
peaks.to_sql('peaks', GarNetDB, if_exists="replace")

# %%
overlaps = pd.read_sql_query("""
    SELECT garnetdb.*
    FROM garnetdb
    JOIN peaks ON garnetdb.chrom      == peaks.chrom
              AND garnetdb.motifStart <= peaks.peakEnd
              AND garnetdb.motifEnd   >= peaks.peakStart;
    """, GarNetDB)

# %%
overlaps
# Out:
#           index  chrom           motifName motifStrand  motifStart   motifEnd  \
# 0          7815  chr19                ETS2           -     8420716    8420723
# 1          7816  chr19                ETS2           -     8420716    8420723
# 2          8274  chr19                MAFB           +     8420676    8420682
# 3          8275  chr19                MAFB           +     8420676    8420682
# 4         13821  chr19                USF2           +    45657939   45657945
# 5         13822  chr19                USF2           +    45657939   45657945
# 6         13823  chr19                USF2           +    45657939   45657945
# 7         13824  chr19                USF2           +    45657939   45657945
# 8         13825  chr19                USF2           -    45657939   45657945
# 9         13826  chr19                USF2           -    45657939   45657945
# 10        13827  chr19                USF2           -    45657939   45657945
# 11        13828  chr19                USF2           -    45657939   45657945
# 12        20829  chr19                  AR           +    46804318   46804333
# 13        20830  chr19                  AR           +    46804318   46804333
# 14        20831  chr19                  AR           +    46804318   46804333
# 15        20832  chr19                  AR           +    46804318   46804333
# 16        20833  chr19                  AR           +    46804318   46804333
# 17        20834  chr19                  AR           +    46804318   46804333
# 18        20835  chr19                  AR           +    46804318   46804333
# 19        20836  chr19                  AR           +    46804318   46804333
# 20        20837  chr19                  AR           +    46804318   46804333
# 21        20838  chr19                  AR           +    46804318   46804333
# 22        20844  chr19                  AR           +    46804318   46804333
# 23        20845  chr19                  AR           +    46804318   46804333
# 24        20846  chr19                  AR           +    46804318   46804333
# 25        20847  chr19                  AR           +    46804318   46804333
# 26        20848  chr19                  AR           +    46804318   46804333
# 27        20849  chr19                  AR           +    46804318   46804333
# 28        20850  chr19                  AR           +    46804318   46804333
# 29        20851  chr19                  AR           +    46804318   46804333
# ...         ...    ...                 ...         ...         ...        ...
# 35521  28297018   chr5            MZF1_1-4           +   172296089  172296095
# 35522  28297019   chr5            MZF1_1-4           +   172296089  172296095
# 35523  28298645   chr5               GATA3           -    58887948   58887954
# 35524  28298646   chr5               GATA3           -    58887948   58887954
# 35525  28298647   chr5               GATA3           -    58887948   58887954
# 35526  28298648   chr5               GATA3           -    58887948   58887954
# 35527  28298649   chr5               GATA3           -    58887948   58887954
# 35528  28310838   chr5                  AR           -   158202626  158202641
# 35529  28310839   chr5                  AR           -   158202626  158202641
# 35530  28310840   chr5                  AR           -   158202626  158202641
# 35531  28310841   chr5                  AR           -   158202626  158202641
# 35532  28311958   chr5                 DBP           -     6505352    6505359
# 35533  28312086   chr5  PPARalpha:RXRalpha           -    95193174   95193194
# 35534  28312345   chr5               BRCA1           +    40798867   40798874
# 35535  28314111   chr5              NKX3-2           +    14305105   14305111
# 35536  28314112   chr5              NKX3-2           +    14305105   14305111
# 35537  28314113   chr5              NKX3-2           +    14305105   14305111
# 35538  28316795   chr5                LEF1           +    58879390   58879396
# 35539  28316796   chr5                LEF1           +    58879390   58879396
# 35540  28316797   chr5                LEF1           +    58879390   58879396
# 35541  28316798   chr5                LEF1           +    58879390   58879396
# 35542  28316799   chr5                LEF1           +    58879390   58879396
# 35543  28318772   chr5                 SRF           -    58502271   58502285
# 35544  28318773   chr5                 SRF           -    58502271   58502285
# 35545  28318774   chr5                 SRF           -    58502271   58502285
# 35546  28318775   chr5                 SRF           -    58502271   58502285
# 35547  28318776   chr5                 SRF           -    58502271   58502285
# 35548  28318777   chr5                 SRF           -    58502271   58502285
# 35549  28318778   chr5                 SRF           -    58502271   58502285
# 35550  28318779   chr5                 SRF           -    58502271   58502285
#
#        motifScore   geneName  geneStart    geneEnd geneStrand  \
# 0        0.077690    ANGPTL4    8429010    8439257          +
# 1        0.077690    ANGPTL4    8429039    8439257          +
# 2        0.529717    ANGPTL4    8429010    8439257          +
# 3        0.529717    ANGPTL4    8429039    8439257          +
# 4        0.644043   TRAPPC6A   45666185   45681501          -
# 5        0.644043    PPP1R37   45596430   45650543          +
# 6        0.644043      NKPD1   45653007   45663408          -
# 7        0.644043      NKPD1   45655160   45657110          -
# 8        0.644043   TRAPPC6A   45666185   45681501          -
# 9        0.644043    PPP1R37   45596430   45650543          +
# 10       0.644043      NKPD1   45653007   45663408          -
# 11       0.644043      NKPD1   45655160   45657110          -
# 12       0.289109      HIF3A   46801632   46828896          +
# 13       0.289109      HIF3A   46800302   46846690          +
# 14       0.289109      HIF3A   46800302   46834770          +
# 15       0.289109      HIF3A   46807105   46841797          +
# 16       0.289109      HIF3A   46800302   46815969          +
# 17       0.289109      HIF3A   46801632   46841797          +
# 18       0.289109      HIF3A   46801632   46838243          +
# 19       0.289109   RNU6-66P   46720994   46809806          -
# 20       0.289109      HIF3A   46801632   46846690          +
# 21       0.289109      HIF3A   46806855   46846690          +
# 22       0.313871      HIF3A   46801632   46828896          +
# 23       0.313871      HIF3A   46800302   46846690          +
# 24       0.313871      HIF3A   46800302   46834770          +
# 25       0.313871      HIF3A   46807105   46841797          +
# 26       0.313871      HIF3A   46800302   46815969          +
# 27       0.313871      HIF3A   46801632   46841797          +
# 28       0.313871      HIF3A   46801632   46838243          +
# 29       0.313871   RNU6-66P   46720994   46809806          -
# ...           ...        ...        ...        ...        ...
# 35521    0.477378   BX648961  172293439  172299820          +
# 35522    0.477378     ERGIC1  172261222  172379688          +
# 35523    1.000000      PDE4D   58264865   59783925          -
# 35524    1.000000      PDE4D   58264865   59189621          -
# 35525    1.000000      PDE4D   58264865   59064438          -
# 35526    1.000000      PDE4D   58452920   59064438          -
# 35527    1.000000      PDE4D   58264865   58882324          -
# 35528    0.309720       EBF1  158122922  158523614          -
# 35529    0.309720       EBF1  158122922  158526788          -
# 35530    0.309301       EBF1  158122922  158523614          -
# 35531    0.309301       EBF1  158122922  158526788          -
# 35532    0.768922    UBE2QL1    6448735    6496834          +
# 35533    0.186207  LINC01554   95187935   95195836          +
# 35534    0.502513     PRKAA1   40759480   40798297          -
# 35535    1.000000       TRIO   14143828   14509458          +
# 35536    1.000000       TRIO   14183906   14399509          +
# 35537    1.000000       TRIO   14293120   14489274          +
# 35538    0.228148      PDE4D   58264865   59783925          -
# 35539    0.228148      PDE4D   58264865   59189621          -
# 35540    0.228148      PDE4D   58264865   59064438          -
# 35541    0.228148      PDE4D   58452920   59064438          -
# 35542    0.228148      PDE4D   58264865   58882324          -
# 35543    0.301541      PDE4D   58264865   59783925          -
# 35544    0.301541      PDE4D   58264865   59189621          -
# 35545    0.301541      PDE4D   58264865   59064438          -
# 35546    0.301541      PDE4D   58264865   58652727          -
# 35547    0.301541      PDE4D   58289198   58511794          -
# 35548    0.301541      PDE4D   58264865   58571945          -
# 35549    0.301541      PDE4D   58452920   59064438          -
# 35550    0.301541      PDE4D   58264865   58882324          -
#
#        motif_to_gene_distance
# 0                       -8294
# 1                       -8323
# 2                       -8334
# 3                       -8363
# 4                       -8246
# 5                       61509
# 6                        4932
# 7                        2779
# 8                       -8246
# 9                       61509
# 10                       4932
# 11                       2779
# 12                       2686
# 13                       4016
# 14                       4016
# 15                      -2787
# 16                       4016
# 17                       2686
# 18                       2686
# 19                      83324
# 20                       2686
# 21                      -2537
# 22                       2686
# 23                       4016
# 24                       4016
# 25                      -2787
# 26                       4016
# 27                       2686
# 28                       2686
# 29                      83324
# ...                       ...
# 35521                    2650
# 35522                   34867
# 35523                  623083
# 35524                  623083
# 35525                  623083
# 35526                  435028
# 35527                  623083
# 35528                   79704
# 35529                   79704
# 35530                   79704
# 35531                   79704
# 35532                   56617
# 35533                    5239
# 35534                   39387
# 35535                  161277
# 35536                  121199
# 35537                   11985
# 35538                  614525
# 35539                  614525
# 35540                  614525
# 35541                  426470
# 35542                  614525
# 35543                  237406
# 35544                  237406
# 35545                  237406
# 35546                  237406
# 35547                  213073
# 35548                  237406
# 35549                   49351
# 35550                  237406
#
# [35551 rows x 12 columns]
